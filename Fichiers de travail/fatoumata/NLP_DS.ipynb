# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
os.chdir('C:\\Users\\barry\\OneDrive - CSTBGroup\\image_ds\\images')

# %%
X = pd.read_csv('X_train_update.csv',index_col=0)
y = pd.read_csv('Y_train_CVw08PX.csv',index_col=0)

# %%
X['class'] = y

# %% [markdown]
# Travail sur la variable désignation, regroupement par class pour trouver les cohérences :

# %%
var = X[['designation', 'class']]
var
# Out:
#                                              designation  class
# 0      Olivia: Personalisiertes Notizbuch / 150 Seite...     10
# 1      Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...   2280
# 2      Grand Stylet Ergonomique Bleu Gamepad Nintendo...     50
# 3      Peluche Donald - Europe - Disneyland 2000 (Mar...   1280
# 4                                   La Guerre Des Tuques   2705
# ...                                                  ...    ...
# 84911                        The Sims [ Import Anglais ]     40
# 84912  Kit piscine acier NEVADA déco pierre Ø 3.50m x...   2583
# 84913  Journal Officiel De La Republique Francaise N°...   2280
# 84914  Table Basse Bois De Récupération Massif Base B...   1560
# 84915  Gomme De Collection 2 Gommes Pinguin Glace Ver...   2522
#
# [84916 rows x 2 columns]

# %%
var.designation = var.designation.astype(str)
var.designation = var.designation.str.lower()
var = var.drop_duplicates(subset = "designation")
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
var
# Out:
#                                              designation  class
# 0      olivia: personalisiertes notizbuch / 150 seite...     10
# 1      journal des arts (le) n° 133 du 28/09/2001 - l...   2280
# 2      grand stylet ergonomique bleu gamepad nintendo...     50
# 3      peluche donald - europe - disneyland 2000 (mar...   1280
# 4                                   la guerre des tuques   2705
# ...                                                  ...    ...
# 84911                        the sims [ import anglais ]     40
# 84912  kit piscine acier nevada déco pierre ø 3.50m x...   2583
# 84913  journal officiel de la republique francaise n°...   2280
# 84914  table basse bois de récupération massif base b...   1560
# 84915  gomme de collection 2 gommes pinguin glace ver...   2522
#
# [82245 rows x 2 columns]

# %% [markdown]
# Enlever les symboles :

# %%
symbols = [",", "'",  "/", "{", "}", "[", "]","(",")", ":", ";", "°", "-", "_", "ø"]

# %%
for i in symbols :
    try :
        var.replace(i, " ", regex = True, inplace = True)
    except: 
        pass
    

var.replace(".", "",  inplace = True)

var #Remarque fonctionne pas pour tous
# Out:
# C:\Users\barry\Anaconda3\lib\site-packages\pandas\core\frame.py:4379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#                                              designation  class
# 0      olivia  personalisiertes notizbuch   150 seite...     10
# 1      journal des arts (le) n  133 du 28 09 2001   l...   2280
# 2      grand stylet ergonomique bleu gamepad nintendo...     50
# 3      peluche donald   europe   disneyland 2000 (mar...   1280
# 4                                   la guerre des tuques   2705
# ...                                                  ...    ...
# 84911                        the sims [ import anglais       40
# 84912  kit piscine acier nevada déco pierre   3.50m x...   2583
# 84913  journal officiel de la republique francaise n ...   2280
# 84914  table basse bois de récupération massif base b...   1560
# 84915  gomme de collection 2 gommes pinguin glace ver...   2522
#
# [82245 rows x 2 columns]

# %%
var[var['class'] == 1140].head(10).designation.tolist()
# Out:
# ['power rangers rouge force mystic figurine transformable 18 cm',
#  'véhicule star wars a ast5',
#  'magnet europe paris 44',
#  'lampe star wars   lampe neon sabre laser',
#  'it   bobble head pop n  539   beverly with key necklace',
#  'figurine zhu zhu pets   zhu zhu pet dans son panier   happy meal   mcdo 2012',
#  'chopper dragon ball kai x one piece noël edition',
#  'dragon ball soul of hyper figuration figurine chichi version colorisé bandai',
#  'star wars episode vii salière et poivrière bb 8 & r2 d2',
#  'porte clefs   ville d avignon']

# %%
var[var['class'] == 1140].tail(15).designation.tolist()
# Out:
# ['kingdom hearts avatar mascot strap vol. 4 sera',
#  'mezco toys the goon 7¿',
#  'starwars d2 r2 fx tatooine',
#  'gundam zeonography 3010a galbaldy alpha red gelgoog commander type figure',
#  'figurine game of thrones   jaime lannister golden hand pop 10cm',
#  'hot toys mms317   star wars   the force awakens   first order stormtrooper',
#  'coffret deux voitures marvel de marque corgi',
#  'star wars   the empire strikes back   r 3po (hoth evacuation)',
#  'adventure time   t shirt finn full front (m)',
#  'htb nendoroid mascot kigurumi on chan (pvc & abs figure moving pre painted)',
#  'doctor who mug dalek pop',
#  'vintage tenue action man   red devil parachutist',
#  'figurine wintouc   série pocahontas miniature (nestlé 1996)',
#  'figurine "bip   viacom"   dora l exploratrice   lot de 3',
#  'buste dark vador disney']

# %% [markdown]
# CLASSE 10 :

# %%
var10 = var[var['class'] == 40]
var10
# Out:
#                                              designation  class
# 31                                   x men 3   the movie     40
# 34                                 the lord or thé rings     40
# 47          shin masoukishin panzer warfare (import jap)     40
# 50                                jeu pc cd rom   azteca     40
# 101         innercity burnout [import allemand  [jeu pc      40
# ...                                                  ...    ...
# 84817  men in black alien crisis   ensemble complet  ...     40
# 84833               gundam battle online (version japon)     40
# 84841                     timesplitters   future perfect     40
# 84865  câble audio jack steréo 3.5 mm rca mâle access...     40
# 84911                        the sims [ import anglais       40
#
# [2478 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\barry\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Token :

# %%
token = var10.designation.apply(word_tokenize)
token
#Allemand, anglais, français
# Out:
# 31                                 [x, men, 3, the, movie]
# 34                             [the, lord, or, thé, rings]
# 47       [shin, masoukishin, panzer, warfare, (, import...
# 50                              [jeu, pc, cd, rom, azteca]
# 101      [innercity, burnout, [, import, allemand, [, j...
#                                ...
# 84817    [men, in, black, alien, crisis, ensemble, comp...
# 84833       [gundam, battle, online, (, version, japon, )]
# 84841                     [timesplitters, future, perfect]
# 84865    [câble, audio, jack, steréo, 3.5, mm, rca, mâl...
# 84911                      [the, sims, [, import, anglais]
# Name: designation, Length: 2478, dtype: object

# %% [markdown]
# # Stop_words :

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words_french = set(stopwords.words("french"))
stop_words_english = set(stopwords.words("english"))
stop_words_german = set(stopwords.words("german"))

stop_words = stop_words_french.union(stop_words_english) 
stop_words = stop_words.union(stop_words_german )
print(stop_words)
# Out:
# {"you'd", 'seraient', 'who', 'keine', 'tes', 'lui', 'bei', 'können', 'été', 'deinen', 'selbst', 'him', 'welches', 'zum', 'eues', 'l', 'such', "wouldn't", 'eu', 'between', 'not', 'mais', 'sur', 'fut', 'off', 'after', 'derselben', 'zwar', 'eussent', 'by', 'dans', 'wouldn', 'pas', 'leur', 'serions', 'from', 'ont', 'jeden', 'wirst', 'nach', 'hat', 'seinen', 'again', 'toi', 'seriez', 'a', 'ses', 'les', 'indem', 'einen', 'dir', 'welcher', 'how', 'à', 'ce', 'where', 'keinem', 'étiez', 'nous', 's', 'son', 'or', 'furent', 'ta', 'allem', 'his', 'damit', 'kein', 'als', 'nur', 'they', 've', 'me', 'étants', 'ihrem', 'vos', 'sondern', 'aber', 'solchen', 'being', 'jenes', "you're", 'themselves', 'meinen', 'deines', 'fussent', 'ayez', 'denselben', 'einigen', 'are', 'dass', 'au', 'tu', 'sie', 'during', 'eue', 'ich', 'un', 'ait', 'them', 'eurent', 'its', 'was', 'the', 'aus', 'te', 'what', 'anderem', 'aurait', 'seine', 'da', 'don', 'daß', 'mes', 'einem', 'anderr', 'desselben', 'then', "should've", 'waren', 'diese', 'weg', 'pour', 'while', 'anderen', 'until', 'eut', 'fût', 'ihn', "don't", 'étant', 'more', 'welche', 'y', 'solches', 'haven', 'einer', 'if', 'you', "didn't", 'se', 'jenen', 'been', 'einigem', 'était', 'sommes', 'shan', 'that', 'aviez', 'o', 'einmal', 'himself', 'qui', 'hatte', 'have', 'an', 'solche', 'soient', 'meiner', 'würde', 'du', 'nos', 'welchen', 'soll', 'sich', 'aies', 'vous', 'up', 'just', 'ayantes', 'eure', 'par', 'dazu', 'seinem', 'now', 'under', 'aient', 'aura', 'eûtes', 'étées', 'on', 'eus', 'serait', 'unter', 'sa', 'very', 'avez', 'hab', 'le', 'die', 'this', 'any', 'unseren', 'kann', 'viel', 'eurem', 'wollte', 'elle', 'over', 'why', 'ours', 'few', 'most', 'musste', 'eussiez', 'nun', 'jener', 'fus', 'ain', 'für', 'ou', 'own', 'dasselbe', 'anderm', 'weiter', 'seiner', "you've", 'had', 'andere', 'ton', 'anderer', 'étaient', 'demselben', 'be', "hasn't", 'mon', "you'll", 'unsere', 'soit', 'alles', 'könnte', 'eût', "it's", 'während', 'et', 'étante', 'eussions', 'll', 'mightn', 'der', 'ihr', 'aux', 'ayant', 'ob', 'auras', 'mit', 'myself', 'do', 'oder', 'ourselves', 'hinter', 'against', 'eures', 'wir', 'keines', 'serai', 'sois', 'he', 'vom', 'about', 'n', 'weren', 'my', 'fusses', "needn't", 'serez', 'nor', 'we', 'sont', 'wieder', 'i', 'couldn', 'auch', 'jede', 'sein', 'her', 'of', 'seines', 'er', 'eurer', 'aurions', 'ist', 'weil', 'im', 'eûmes', 'avec', 'ils', 'mein', 'que', 'ayante', 'uns', 'mich', 'um', 'solchem', "won't", 'einiges', 'eux', 'yours', 'can', 'fûmes', 'dein', 'eine', 'dessen', 'diesem', 'von', 'keiner', 'fussiez', "weren't", 'warst', 'ayants', 'did', 'alle', 'for', 'solcher', 'würden', 'ai', 'avions', 'above', 'has', 'shouldn', 'once', 'manches', 'meine', 'machen', 'mancher', 'dieselbe', 'dem', 'keinen', 'there', "doesn't", 'notre', 'allen', "that'll", 'jeder', 'man', 'and', 'es', 'but', 'unseres', 'meinem', 'too', 'doch', 'werden', 'avais', 'aurais', 'some', 'étantes', 'bis', 'welchem', 'mir', 'dieser', 'muss', 'noch', 'dann', 'below', 'ihnen', 'jene', 'war', "shan't", 'auront', 'manche', 'votre', 'into', 'am', 'out', 'unserem', 'wie', 'here', 'anders', 'avons', 'ihren', 'bin', 'so', 'herself', 'jedem', 'it', 'etwas', 'bist', 'soyez', 'our', "hadn't", 'ins', 'étais', 'manchen', 'étés', 'dort', 'when', 'werde', 'il', 'with', 'd', "mustn't", 'to', 'zwischen', 'sonst', 'ihre', 'each', 'only', 'einige', 'nicht', 'hier', 'sera', 'she', 'ne', 'dieselben', 'ma', 'avaient', 'yourselves', 'jenem', 'those', 'auraient', 'isn', 'at', 'further', 'eusses', 'will', 'la', 'durch', "isn't", 'je', 'suis', 'und', 'une', 'auriez', 'hadn', 'aller', 'étions', 'having', 'through', 'euren', 'wollen', 'other', 'eines', 'wenn', 'no', 'aren', "couldn't", 'andern', 'their', 'moi', 'wasn', 'diesen', 'einiger', 'hatten', 'needn', 'jedes', "mightn't", 'itself', 'serais', 'das', 'anderes', 'j', 'whom', 'both', 'your', 'down', 'des', 'were', 'jetzt', 'sehr', 'is', 'derselbe', 'aurons', 'de', 'habe', 'doing', 'manchem', 'ander', "aren't", 'hin',  ...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\barry\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Fonction stop_words_filtering :

# %%
def stop_words_filetring(mots) : 
    tokens = []
    for mot in mots:
        if mot not in stop_words:
            tokens.append(mot)
    return tokens

# %%
#Application & check
token = token.apply(stop_words_filetring)


#Enlever les ponctuations

# %% [markdown]
# # Suppression ponctuation :

# %%
import string
list_ponctuation = []
for i in string.punctuation :
    list_ponctuation.append(i)
list_ponctuation    

def stop_ponctuations(mots) : 
    tokens = []
    for mot in mots:
        if mot not in list_ponctuation:
            tokens.append(mot)
    return tokens

# %%
token = token.apply(stop_ponctuations)
token
# Out:
# 31                                      [x, men, 3, movie]
# 34                                      [lord, thé, rings]
# 47       [shin, masoukishin, panzer, warfare, import, jap]
# 50                              [jeu, pc, cd, rom, azteca]
# 101        [innercity, burnout, import, allemand, jeu, pc]
#                                ...
# 84817    [men, black, alien, crisis, ensemble, complet,...
# 84833             [gundam, battle, online, version, japon]
# 84841                     [timesplitters, future, perfect]
# 84865    [câble, audio, jack, steréo, 3.5, mm, rca, mâl...
# 84911                              [sims, import, anglais]
# Name: designation, Length: 2478, dtype: object

# %% [markdown]
# # Stop accent :

# %%
import unicodedata

def strip_accents(text):

    try:
        text = unicode(text, 'utf-8')
    except NameError: # unicode is a default on python 3 
        pass

    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")

    return str(text)

# %%
liste_i = []
liste_a= []

for i in token :
    liste_j = []
    for j in i :
        liste_j.append(strip_accents(j))
    liste_a.append(liste_j)
    
token=pd.Series(liste_a, index = token.index)

# %%
print(token.to_string())
# Out:
# 31                                      [x, men, 3, movie]
# 34                                      [lord, the, rings]
# 47       [shin, masoukishin, panzer, warfare, import, jap]
# 50                              [jeu, pc, cd, rom, azteca]
# 101        [innercity, burnout, import, allemand, jeu, pc]
# 107      [zumba, fitness, rush, jeu, kinect, import, al...
# 142             [pokemon, saphir, alpha, edition, limitee]
# 195                      [king, bounty, armored, princess]
# 204      [cable, adaptateur, audio, stereo, ordinateurs...
# 252                      [guilty, gear, x, version, japon]
# 282                         [world, destruction, lea, jet]
# 332      [magideal, reparation, module, capteur, analog...
# 346      [assassin, creed, brotherhood, assassin, creed...
# 421               [planet, 51, import, allemand, jeu, wii]
# 422      [magideal, coque, console, jeux, video, alumin...
# 476                                          [would, soul]
# 483      [mission, veterinaire, soigne, animaux, famili...
# 506                       [wii, fit, sans, balance, board]
# 556                                [dance, greatest, hits]
# 557                                    [grabbed, ghoulies]
# 669                                     [sky, jaguar, msx]
# 697      [disney, infinity, 3.0, star, wars, pack, dema...
# 727                        [virtua, fighter, 4, evolution]
# 752      [magideal, module, puce, meilleure, qualite, i...
# 829              [remington, bird, hunt, wii, fusil, noir]
# 859        [izzy, quest, olympic, rings, genesis, usa, us]
# 932                 [nba, 2k13, import, anglais, jeu, ps3]
# 944                                   [monde, animaux, 3d]
# 1012       [space, quest, iv, roger, wilco, time, rippers]
# 1039                          [steel, fury, karkhov, 1942]
# 1056     [secrets, dragon, wheel, pc, cd, import, anglais]
# 1152                          [tony, hawk, pro, skater, 3]
# 1169        [world, final, fantasy, us, day, one, edition]
# 1207                          [star, wars, pouvoir, force]
# 1296                          [kirby, 64, crystal, shards]
# 1335     [etuis, telecommand, silicone, compatible, tel...
# 1402                                   [200, jeux, vol, 5]
# 1524     [magideal, 2, pcs, lb, rb, trigger, microsoft,...
# 1528                          [schtroumpfs, fete, foraine]
# 1555     [furi, definitive, edition, limited, run, game...
# 1567          [dingo, dino, dessin, anime, interactif, 3d]
# 1568                                          [passe, bac]
# 1576     [flight, simulator, x, airbus, family, vol, 1,...
# 1724     [fallout, 3, game, year, edition, import, alle...
# 1725                    [code, honneur, legion, etrangere]
# 1806                     [pets, pals, veterinaire, animal]
# 1818                          [mat, hoffman, pro, bmx, nt]
# 1841     [senhor, dos, aneis, batalha, pela, terra, med...
# 1852                                   [fort, boyard, jeu]
# 1868                [enigmes, objets, caches, interpol, 2]
# 1880                        [walking, dead, final, season]
# 1890            [garten, panik, import, allemand, jeu, pc]
# 1977      [hour, victory, ensemble, complet, pc, dvd, win]
# 1988     [magideal, 3d, analogique, joystick, capteur, ...
# 1994     [magideal, vert, boutons, remplacement, access...
# 2056                                [club, animaux, vol.2]
# 2096             [ninja, gaiden, figurine, kureha, 29, cm]
# 2102                         [bugs, bunny, spirale, temps]
# 2132                       [tortuga, pirates, flibustiers]
# 2134                 [goat, simulator, simulateur, chevre]
# 2159                           [world, ends, final, remix]
# 2195                 [witcher, 3, edition, collector, ps4]
# 2225                                  [rambo, video, game]
# 2277                 [coffret, vins, 2000, 2000, recettes]
# 2289                            [act, disque, additionnel]
# 2324           [lego, indiana, jones, trilogie, originale]
# 2328     [prince, persia, ame, guerrier, hits, collection]
# 2384     [stylish, collection, detective, story, kudo, ...
# 2388                           [cd, codes, metroid, prime]
# 2389     [left, right, joy, con, controleurs, jeu, blue...
# 2398     [1pc, autocollant, guitare, notes, carte, etiq...
# 2467                             [heroes, 3, might, magic]
# 2487                     [bioshock, version, royaume, uni]
# 2488     [magideal, sac, rangement, coque, protection, ...
# 2512               [tiger, woods, pga, tour, 07, allemand]
# 2536                            [ghostbusters, jeu, video]
# 2561      [versus, hero, kakutou, e, michi, import, japon]
# 2573                 [dark, parables, jack, royaume, ciel]
# 2608                             [10, pin, bowling, fever]
# 2625                         [cocinar, con, jamie, oliver]
# 2649                               [spider, allie, ennemi]
# 2741      [thunder, storm, fx, mega, cd, import, japonais]
# 2745                                   [petite, sirene, 2]
# 2753                            [sim, city, 2000, classic]
# 2755     [asterix, obelix, xxl, 2, edition, collector, ...
# 2782     [1080p, vga, male, hdmi, femelle, hdtv, adapta...
# 2813                         [one, piece, grand, aventure]
# 2880      [fatal, fury, battle, destiny, import, japonais]
# 2930     [lineage, ii, chaotic, chronicle, chronicle, 3...
# 2963                       [moorhuhn, jump, run, atlantis]
# 3018                [uncharted, nathan, drake, collection]
# 3035              [lara, croft, tomb, raider, anniversary]
# 3161                              [atari, gateway, apshai]
# 3171     [magideal, remplacement, bouton, complet, decl...
# 3216               [knights, merchants, shatters, kingdom]
# 3229                      [tripack, dark, f, rebel, xwing]
# 3231                            [retour, ile, mysterieuse]
# 3235     [dark, tales, schwarze, kater, edgar, allan, p...
# 3247          [cossacks, european, wars, hits, collection]
# 3267                       [commander, conquest, americas]
# 3268     [top, gun, firestorm, nintendo, game, boy, adv...
# 3311     [commutateur, hote, caoutchouc, protection, ha...
# 3320                 [ranma, 1, 2, bakuretsu, rantou, hen]
# 3326         [open, mind, anglais, moyen, avance, vol, 02]
# 3384          [jeu, pc, petit, monde, choupi, des, 2, ans]
# 3389                          [god, 2, edition, platinium]
# 3431                                           [187, ride]
# 3452     [pack, feu, obscur, fortnite, code, telecharge...
# 3496           [wer, millionar, import, allemand, jeu, ds]
# 3501     [ruckkehr, geheimnisvollen, insel, 2, import, ...
# 3544                            [dead, space, 2, platinum]
# 3591                             [medal, honor, frontline]
# 3592     [expanded, slide, pad, console, nintendo, 3ds,...
# 3619                   [sherlock, holmes, devil, daughter]
# 3639                       [wwe, smackdown, vs, raw, 2010]
# 3652     [magideal, plextone, g15, wired, pubg, gaming,...
# 3681                               [overwatch, game, year]
# 3715              [legacy, kain, soul, reaver, 100, malin]
# 3722     [resident, evil, hd, remaster, ps3, biohazard,...
# 3727       [ratchet, clank, 3, import, allemand, jeu, ps2]
# 3783                [attack, pearl, harbor, gold, edition]
# 3791     [2pcs, bord, mousse, souple, haut, parleur, pi...
# 3799                     [nadesico, mission, version, jap]
# 3802                     [uncharted, 3, drakes, deception]
# 3839     [might, magic, clash, heroes, import, allemand...
# 3885                    [final, fantasy, x, 2, import, us]
# 3895     [secret, evangelion, portable, limited, editio...
# 3930     [kohan, ii, kings, ensemble, complet, pc, cd, ...
# 3932     [magideal, set, 2, manettes, jeu, classique, e...
# 3938                    [marvel, vs, capcom, version, jap]
# 4049                      [everquest, 2, edition, limitee]
# 4106                    [grand, theft, auto, v, xbox, 360]
# 4119                    [bulletstorm, full, clip, edition]
# 4125             [lego, star, wars, iii, clone, wars, 3ds]
# 4126     [hikone, castle, plastic, model, doyusha, 1, 2...
# 4141     [divinity, ii, dragon, knight, saga, silver, e...
# 4214                       [mugtail, moose, japan, import]
# 4229                       [nascar, 09, import, americain]
# 4263     [3.5mm, double, jack, audio, splitter, ecouteu...
# 4292     [magideal, analog, stick, l2, r2, trigger, spr...
# 4415                             [odyssee, traces, ulysse]
# 4449     [coffret, english, niveaux, confirme, expert, ...
# 4460     [unite, principale, base, radiateur, ventilate...
# 4559     [magideal, bouton, b, pad, interrupteur, alime...
# 4577                    [quiz, charaokedon, import, japon]
# 4681                             [m47, m48, patton, tanks]
# 4698     [joycon, controleur, gauche, droite, remplacem...
# 4707                      [top, spin, 3, import, japonais]
# 4759     [tom, clancy, rainbow, six, lockdown, hits, co...
# 4777                                 [conduit, import, uk]
# 4782                [nhl, 13, import, republique, tcheque]
# 4789     [beyblade, metal, fusion, cyber, pegasus, jeu,...
# 4790     [magideal, microsoft, xbox, one, controleur, a...
# 4792                            [nosferatu, import, japon]
# 4827     [helicopter, simulator, search, rescue, simula...
# 4846     [bataille, ardennes, air, force, serie, limite...
# 4849                       [honeycomb, beat, nintendo, ds]
# 4851         [hidden, stroke, allied, power, realism, mod]
# 4884     [magideal, kit, filtre, eponge, anti, poussier...
# 4907     [indestructibles, terrible, attaque, demolisseur]
# 5009     [magideal, connecteur, port, charge, prise, ja...
# 5026                         [prokofiev, symphonies, 1, 5]
# 5184             [marc, ecko, getting, contents, pressure]
# 5200                     [history, channel, battles, rome]
# 5207     [2, games, 1, bob, eponge, film, tak, 2, scept...
# 5265                         [robin, bois, roi, hors, loi]
# 5300            [dimmi, di, piu, tell, italien, niveau, 1]
# 5310       [call, duty, 3, marche, vers, paris, platinium]
# 5329     [controleur, jeu, mobile, 4in1, gamepad, tirer...
# 5438     [sims, 4, collection, 5, fitness, jungle, bamb...
# 5477                             [bard, tale, best, gamer]
# 5573     [detective, conan, aoki, houseki, rinbukyoku, ...
# 5619     [seigneur, anneaux, bataille, terre, milieu, e...
# 5642     [magideal, kit, boutons, complets, trigger, pa...
# 5755     [fairly, oddparents, shadow, showdown, pc, cd,...
# 5762           [jewel, match, 2, import, anglais, jeu, pc]
# 5854     [ghost, recon, gold, edition, original, missio...
# 5855     [demolition, company, edition, gold, import, a...
# 5916                          [sims, 2, fun, famille, kit]
# 5928                          [ever, oasis, nintendo, 3ds]
# 5933     [eva, couverture, dure, cas, sac, rangement, e...
# 5967                          [rogue, spear, black, thorn]
# 6026                                    [shogun, 2, total]
# 6059                               [need, speed, prosreet]
# 6140                [dragon, ball, z, ultimate, tenkaichi]
# 6153     [momotarou, densestsu, turbo, hudson, soft, vo...
# 6178                    [enter, matrix, nouvelle, edition]
# 6218                              [army, men, toys, space]
# 6430     [magideal, remplacement, joystick, caps, 4, gr...
# 6451             [hyper, light, drifter, limited, edition]
# 6555                    [saints, row, iv, bijoux, famille]
# 6560              [sonic, sega, stars, racing, import, uk]
# 6571     [magideal, module, camera, infrarouge, droit, ...
# 6614     [magideal, lb, rb, lt, rt, abxy, t8, trigger, ...
# 6700     [tpu, housse, 2, capsules, baton, pouce, 1, pr...
# 6750                        [blonde, retour, ile, oubliee]
# 6780     [pro, cycling, manager, tour, france, 2012, si...
# 6781     [cabela, dangerous, hunts, 2013, fusil, detect...
# 6882                                     [nba, 09, inside]
# 6951                     [monstres, cie, edition, limitee]
# 7085                            [barbie, coeur, princesse]
# 7132     [ace, combat, assault, horizon, import, americ...
# 7207               [colin, mcrae, dirt, classics, edition]
# 7222                            [sethi, tribu, neandertal]
# 7249        [dracula, trilogie, import, allemand, jeu, pc]
# 7276     [remplacement, cable, audio, male, male, xlr, ...
# 7318           [guilty, gear, xrd, sign, limited, edition]
# 7328                [realsports, soccer, atari, 2600, pal]
# 7368     [coffret, 100, action, haunted, hells, reach, ...
# 7399                  [sega, marine, fishing, version, us]
# 7414                [snes, super, f1, circus, 2, japonais]
# 7476                                [100, jeux, volume, 4]
# 7503                 [fallout, 76, tricentennial, edition]
# 7530                     [motorbike, racing, triple, pack]
# 7567     [zumba, fitness, world, party, edition, collec...
# 7575                            [bratz, forever, diamondz]
# 7584                     [tokyo, twilight, ghost, hunters]
# 7594     [magideal, 2pcs, peau, silicone, coque, protec...
# 7627                            [burner, 2, import, japon]
# 7665                           [battlefield, 1942, pc, vf]
# 7698         [atari, classics, evolved, import, americain]
# 7734                              [raf, tornado, fs, 2004]
# 7735                [f1, 2011, import, allemand, jeu, 3ds]
# 7753            [time, crisis, 4, guncon, 3, version, jap]
# 7775     [magideal, puce, decodage, lecture, directe, t...
# 7830     [10pcs, rca, splitter, adaptateur, 1, male, 2,...
# 7849                            [donky, kong, country, us]
# 7875     [call, duty, black, ops, ii, goty, revolution,...
# 7898                          [tribes, 2, xplosiv, pc, uk]
# 7956            [flight, simulator, twin, otter, extended]
# 7991     [survive, bbq, zombie, pack, carte, telecharge...
# 7992                                        [tour, france]
# 7997                            [ready, rumble, boxing, 2]
# 8000                         [tiger, woods, pga, tour, 07]
# 8009     [fifa, soccer, world, championship, playstatio...
# 8092     [rockman, exe, battle, chip, gp, ``, import, j...
# 8133     [magideal, 2, jeux, boutons, garniture, caoutc...
# 8142                        [destination, chine, mongolie]
# 8173                                   [kao, kangourou, 2]
# 8289                                       [livre, jungle]
# 8299     [line, sight, vietnam, best, atari, ensemble, ...
# 8374                                 [want, happya, music]
# 8504         [resident, evil, 7, biohazard, edition, gold]
# 8553                                    [tale, despereaux]
# 8587     [jeu, game, boy, simpsons, bart, vs, juggernauts]
# 8589     [magideal, set, touchpad, boutons, r1, l1, r2,...
# 8628     [cape, femme, homme, echelle, 1, 6, vetements,...
# 8670     [tomb, raider, last, revelation, premier, coll...
# 8682     [magideal, bouton, ruban, carte, circuit, cond...
# 8697                            [coupe, monde, fifa, 2002]
# 8713     [etui, hybride, nintendo, rugged, switch, caou...
# 8748                 [cd, codes, dragon, ball, z, budokai]
# 8770                                 [bugdom, 2, jeu, mac]
# 8815     [jack, cable, adaptateur, jack, stereo, cuivre...
# 8823                       [tiger, woods, pga, tour, golf]
# 8868                       [super, smash, bros., ultimate]
# 8885                          [battle, naboo, jewel, case]
# 8908               [ncaa, football, 09, import, americain]
# 8923     [sticker, sony, playstation, ps4, slim, consol...
# 8925     [pal, version, nintendo, wii, u, tank, tank, t...
# 8931     [module, conseil, meteo, station, meteo, wifi,...
# 8936         [walking, dead, telltale, definitive, series]
# 8989     [thw, simulator, 2012, import, allemand, jeu, pc]
# 9032                       [prototype, 2, radnet, edition]
# 9074     [jeu, sans, fil, bluetooth, gamepad, controlle...
# 9092     [grand, prix, 3, saison, 2000, extension, add,...
# 9096     [mystery, stories, pc, mac, dvd, import, angla...
# 9117                          [diablo, iii, battle, chest]
# 9132     [koisentai, love, peace, p.s.p, regular, editi...
# 9153     [herr, ringe, abenteuer, aragorn, import, alle...
# 9160     [coupe, cable, acier, multifonctionnelle, pinc...
# 9208     [anstoss, 2005, version, 4, ensemble, complet,...
# 9301     [jeu, machine, electronique, virtuel, cyber, e...
# 9306           [assassin, creed, unity, edition, speciale]
# 9316            [vanishing, ethan, carter, import, europe]
# 9355                       [medal, honor, premiere, ligne]
# 9373                        [madden, nfl, 06, version, us]
# 9409                       [commandos, beyond, call, duty]
# 9445           [kohan, 2, kings, import, anglais, jeu, pc]
# 9453     [uefa, euro, 2008, ensemble, complet, playstat...
# 9458                        [jewel, master, craddle, rome]
# 9475     [1, paire, tennis, table, racket, poignee, sup...
# 9571     [naruto, shippuden, ultimate, ninja, storm, re...
# 9580     [3pcs, connecteur, prise, jack, audio, v, soud...
# 9612                     [jeune, styliste, haute, couture]
# 9629     [magideal, coque, protection, housse, etui, pr...
# 9668     [witcher, 2, assassins, kings, enhanced, edition]
# 9686                                      [cirque, seurat]
# 9815     [train, simulator, pro, train, 10, deluxe, imp...
# 9821     [monster, hunter, frontier, online, forward.1,...
# 9888     [8, sets, pointes, haut, parleur, contre, poin...
# 9942     [geheimakte, 2, puritas, cordis, import, allem...
# 10029    [sims, 3, inselparadies, import, allemand, jeu...
# 10037    [world, class, rugby, 2, kokunai, gekitou, hen...
# 10083    [medal, honor, warfighter, limited, edition, i...
# 10097    [nin, commutateur, hdmi, video, converter, bas...
# 10232                  [earthworm, jim, menace, 2, galaxy]
# 10343             [marco, polo, import, allemand, jeu, pc]
# 10457              [dr., house, import, allemand, jeu, pc]
# 10496    [taste, japan, food, fact, fable, people, eat,...
# 10511                                            [gear, 2]
# 10591                             [experts, premeditation]
# 10595                  [petit, dinosaure, aventure, maths]
# 10626                 [wii, party, u, telecommande, noire]
# 10683              [nba, 2k11, import, allemand, jeu, ps3]
# 10784    [mobile, suit, z, gundam, aeug, vs., titans, i...
# 10846    [poignee, usb, controller, adapter, converter,...
# 10923              [kung, zhu, import, allemande, jeu, ds]
# 10931    [2, x, cable, harnais, radio, audio, voiture, ...
# 11010                   [darksiders, ii, edition, limitee]
# 11019    [train, simulator, protrain, 18, berlin, hambu...
# 11094    [1, 100, scale, model, kofukuji, five, storied...
# 11126                   [uefa, champion, league, 2001, 02]
# 11190                                     [children, corn]
# 11216                   [merlin, apprentice, jeu, anglais]
# 11294                      [jake, power, handyman, import]
# 11311             [jeu, xbox, halo, combat, evolve, boite]
# 11436                                  [super, jeux, mots]
# 11442     [dark, parables, malediction, eglantine, gamers]
# 11443                      [true, fear, ames, abandonnees]
# 11458    [prise, stereo, 635, mm, 1, 4, ``, male, cable...
# 11483                                      [age, glace, 2]
# 11590                            [mozart, dernier, secret]
# 11591                      [super, high, impact, football]
# 11658        [call, duty, black, ops, hardened, collector]
# 11746                  [jeu, pc, painkiller, resurrection]
# 11783    [wario, master, disguise, ensemble, complet, n...
# 11860    [disgaea, 2, dark, hero, days, import, americain]
# 11861                       [yume, tsubomi, acacia, shita]
# 11905                         [tales, world, reve, unitia]
# 11913        [silent, hill, homecoming, import, americain]
# 11930    [alimentation, ac, chargeur, adaptateur, ninte...
# 12024                    [dance, wii, 2, import, japonais]
# 12034                         [king, mahjongg, 100, malin]
# 12130    [gaming, sans, fil, bluetooth, controller, gam...
# 12198                                     [souris, hommes]
# 12211            [tsubasa, reservoir, chronicle, tome, 13]
# 12224    [need, speed, run, edition, limitee, import, a...
# 12234                           [paradise, quest, jeu, pc]
# 12308    [magideal, etui, coque, housse, protection, si...
# 12350    [magideal, 2pack, 24, slot, game, cart, cartou...
# 12362             [dea, factory, console, 96, jeux, bleue]
# 12387    [elkrone, atelier, dear, otomate, limited, edi...
# 12396    [michael, jackson, experience, software, pyram...
# 12397                       [devil, crash, megadrive, jap]
# 12414    [wars, warriors, jeanne, arc, ensemble, comple...
# 12421     [island, castaway, 2, import, allemand, jeu, pc]
# 12430                         [virtua, tennis, import, us]
# 12448    [best, tivola, lernerfolg, grundschule, deutsc...
# 12483                 [euro, trucks, 2, platinum, edition]
# 12540    [scooby, doo, nuit, 100, frissons, version, euro]
# 12572              [spider, 3, import, allemand, jeu, ps3]
# 12606    [xlr, adaptateur, cable, xlr, 3pin, 2, male, r...
# 12628                                     [george, jungle]
# 12629                       [kirby, fil, grande, aventure]
# 12633    [magideal, housse, protction, aluminium, consl...
# 12656    [magideal, l2, r2, l1, r1, boutons, rechange, ...
# 12710    [dis, adi, ce2, francais, maths, anglais, scie...
# 12791                     [black, white, ii, ea, classics]
# 12856    [5, paires, bornes, haut, parleur, fiche, bana...
# 12911                    [mario, rabbids, kingdom, battle]
# 12918     [pes, 2008, pro, evolution, soccer, version, us]
# 12923     [dancing, blade, 2, tears, eden, dreamcast, jap]
# 12949             [appartement, 3d, cote, chez, vue, tele]
# 12951                 [micropose, sid, meier, cd, edition]
# 12988            [dj, hero, 2, import, allemand, jeu, ps3]
# 13009                  [dead, rising, 2, zombrex, edition]
# 13034       [section, 8, import, allemand, jeu, xbox, 360]
# 13069                          [spider, frontieres, temps]
# 13101         [tom, clancy, ghost, recon, future, soldier]
# 13102          [pirates, caraibes, legende, jack, sparrow]
# 13137                         [pharaonic, deluxe, edition]
# 13152    [robinson, crusoe, cursed, pirates, import, an...
# 13177                          [colin, mcraye, rally, 2.0]
# 13204                           [fire, chief, compilation]
# 13221     [brave, story, new, traveler, import, americain]
# 13246    [magideal, zl, zr, bouton, boucle, r, verrouil...
# 13358                   [naruto, shippuden, kizuna, drive]
# 13441    [nier, replicant, ultimate, hits, import, japo...
# 13456                 [legend, heroes, ii, eiyu, densetsu]
# 13459                                         [ryse, rome]
# 13495                  [b, movie, invasion, viens, espace]
# 13540                     [mini, ninjas, hits, collection]
# 13562                                  [shining, darkness]
# 13596    [nintendo, ds, hannah, montana, movie, import,...
# 13599                    [x, men, 2, vengeance, wolverine]
# 13602         [mysims, kingdom, import, allemand, jeu, ds]
# 13627                             [settlers, 4, kol, 2002]
# 13646                                [air, missions, hind]
# 13648                          [pokemon, x, import, japon]
# 13678                              [stafy, 2, import, jap]
# 13699    [magideal, 2pcs, 32, 1, jeu, cas, titulaire, c...
# 13733    [magideal, 2, pieces, pistolet, zapper, ninten...
# 13755                   [seabass, fishing, 2, import, jap]
# 13855                                      [zool, 2, zool]
# 13889                         [entraineur, cerebral, kids]
# 13931    [world, soccer, winning, eleven, 2013, import,...
# 13989                      [boite, bidules, oncle, ernest]
# 13994    [toeic, test, koushiki, ds, training, import, ...
# 14015      [forza, motorsport, viva, pinata, double, pack]
# 14055                   [ambitious, bitch, marita, liulia]
# 14106                [thq, juiced, 2, hot, import, nights]
# 14121          [high, school, musical, tous, scene, micro]
# 14143                       [code, route, special, examen]
# 14165    [gothic, anthology, gothic, 1, 2, 3, add, goth...
# 14168    [tom, clancy, splinter, cell, double, agent, i...
# 14208          [kobe, bryant, nba, courtside, version, us]
# 14225    [meilleur, aventure, chevaliers, baphomet, bou...
# 14229           [reversi, sl, jeu, sudoku, offert, pc, vf]
# 14241                             [sim, city, import, usa]
# 14249                      [akiba, beat, edition, limitee]
# 14462    [lock, air, combat, simulation, hits, collection]
# 14465       [neopets, puzzle, adventure, import, allemand]
# 14486    [adaptateur, audio, cable, 3.5mm, casque, micr...
# 14493    [project, gotham, racing, 2, platinum, collect...
# 14537             [dragon, knights, glorious, import, jap]
# 14566                      [young, mods, forgotten, story]
# 14590                            [krom, grand, pays, haut]
# 14622    [manette, sans, fil, bluetooth, gamepad, manet...
# 14642                      [rive, limited, run, games, 68]
# 14698                      [transocean, shipping, company]
# 14699    [adaptateur, sortie, video, 1080p, convertisse...
# 14727    [coffret, edition, limitee, 10, jeux, disney, ...
# 14741         [world, warcraft, version, essai, 14, jours]
# 14742                                 [shrek, super, slam]
# 14787                            [wolfenstein, new, order]
# 14825    [magideal, 2pcs, capsules, poignee, baton, pou...
# 14847    [baldr, force, exe, alchemist, best, import, j...
# 14850               [sid, meier, civilization, revolution]
# 14889                        [god, wars, complete, legend]
# 14899         [sims, 3, super, pouvoirs, edition, limitee]
# 14947                            [sports, jeux, croisiere]
# 14952           [mario, kart, 64, collector, version, jap]
# 14998                   [dragon, quest, 6, version, japon]
# 15002    [1, 6, pipa, luth, zhongruan, modele, instrume...
# 15036                          [wipeout, pure, essentials]
# 15069    [boite, porte, fusible, fonte, calibre, 8, fus...
# 15078    [sherlock, holmes, mystery, osborne, house, ni...
# 15099    [magideal, connecteur, prise, jack, interface,...
# 15102    [magideal, 2, sets, boutons, remplacement, pla...
# 15138    [memories, sorekara, limited, edition, import,...
# 15139                       [days, thunder, version, euro]
# 15143                   [midnight, racing, crazy, highway]
# 15170                         [schtroumpfs, autour, monde]
# 15186                 [pirates, caribbean, 2, dead, chest]
# 15319                         [pro, pinball, bigrace, web]
# 15484                 [tales, hearts, r, import, japonais]
# 15571    [portable, poche, mini, video, console, enfant...
# 15596    [nouveau, remplacement, noir, sonore, stereo, ...
# 15665                 [premiers, aventures, sous, marines]
# 15681               [rayman, legends, definitive, edition]
# 15803    [tom, clancy, ghost, recon, wildlands, import,...
# 15804                     [x3, reunion, version, anglaise]
# 15887              [dirt, 3, ensemble, complet, xbox, 360]
# 15919    [maillot, bain, echelle, 1, 6, figurines, femi...
# 15925                           [bone, collection, argent]
# 15960                                      [call, duty, 3]
# 16003    [fritz, fertig, 2, schach, schwarzen, schloss,...
# 16033                         [monster, 4x4, stunt, racer]
# 16041                          [cloudy, chance, meatballs]
# 16066                         [yu, gi, oh, duel, tenebres]
# 16107              [bokan, ippatsu, doronboo, import, jap]
# 16110                                [grand, louvre, 2001]
# 16168    [magideal, clamp, crab, pince, clip, support, ...
# 16188    [haunted, past, fluch, geister, import, allema...
# 16350                [lego, pirates, caraibes, jeu, video]
# 16382                                [nba, 2k14, xone, uk]
# 16385    [dragon, quest, 3, iii, super, famicom, ninten...
# 16405    [5, tailles, 10a, 15a, 60a, 80a, 100a, line, m...
# 16406    [magideal, 3, set, boutons, controleur, thumbs...
# 16435    [magideal, unite, bloc, alimentation, remplace...
# 16454      [gensou, suikoden, tierkreis, import, japonais]
# 16564                      [colin, mcrae, dirt, steelbook]
# 16584    [35, mm, 1, 8, trrs, 4, poles, femelle, connec...
# 16620                         [oda, nobunaga, import, jap]
# 16690                                     [pilot, jeu, pc]
# 16756                                        [alone, dark]
# 16819                                  [search, rescue, 2]
# 16933      [metal, gear, solid, v, definitive, experience]
# 16967            [club, ensemble, complet, playstation, 3]
# 17002              [metal, gear, solid, 4, guns, patriots]
# 17035    [let, sing, 2018, hits, francais, internationaux]
# 17150                                 [let, dance, mel, b]
# 17229                          [atelier, jeux, toy, story]
# 17241    [alan, wake, ensemble, complet, xbox, 360, dvd...
# 17245    [terrorist, takedown, mogadishu, import, angla...
# 17260    [truck, simulator, complete, edition, software...
# 17296    [yeti, quest, pinguine, raumen, import, allema...
# 17315                        [nes, open, tournament, golf]
# 17321                              [tales, monkey, island]
# 17365    [medal, honor, vanguard, import, allemand, jeu...
# 17368    [600w, module, diviseur, frequence, haute, bas...
# 17381    [1, 6, echelle, vetements, femmes, wrap, poitr...
# 17389                 [naruto, shippuden, 3d, import, jap]
# 17412    [disney, princess, enchanting, storybooks, imp...
# 17444                          [turbo, equipe, cascadeurs]
# 17447    [experience112, collection, premium, ensemble,...
# 17514                      [tennis, masters, series, 2003]
# 17516               [professeur, layton, etrange, village]
# 17523    [10, pieces, connecteur, cable, audio, stereo,...
# 17544                  [pirates, legend, black, buccaneer]
# 17570                        [need, speed, underground, 2]
# 17582            [maternelle, moyenne, section, 4, 5, ans]
# 17762    [nike, kinect, training, import, anglais, jeu,...
# 17947     [far, cry, 2, ensemble, complet, playstation, 3]
# 18016        [dance, dance, revolution, new, moves, tapis]
# 18018        [darksiders, shinpan, toki, import, japonais]
# 18023                      [king, fighter, 2000, japonais]
# 18055                                   [sims, 3, saisons]
# 18072    [xcom, enemy, unknown, import, allemand, jeu, ...
# 18080         [chou, doku, hana, kusari, import, japonais]
# 18110    [suche, amelia, earhart, import, allemand, jeu...
# 18145                      [incredibles, rise, underminer]
# 18212    [60a, boite, fusibles, distribution, puissance...
# 18237            [pro, evolution, soccer, 2014, pes, 2014]
# 18283       [cars, essentials, import, allemand, jeu, psp]
# 18313    [spellforce, platinum, edition, spellforce, 1,...
# 18324                      [midi, monsters, moshling, zoo]
# 18342    [medieval, moves, move, essentials, import, al...
# 18353    [magideal, lentille, appareil, photo, capteur,...
# 18363    [magideal, l1r1, gaming, declencheur, bouton, ...
# 18452    [gyro, tops, gyroscope, metal, fusion, filatur...
# 18471                          [bruce, lee, quest, dragon]
# 18492                            [final, fantasy, viii, 8]
# 18516    [metal, slug, x, register, card, original, neo...
# 18548                          [south, park, stick, truth]
# 18558                [getsuei, gakuen, kou, import, japon]
# 18589                    [lego, star, wars, reveil, force]
# 18592                  [lego, harry, potter, annees, 1, 4]
# 18698             [touchmaster, import, allemand, jeu, ds]
# 18701    [worms, battle, islands, import, allemand, jeu...
# 18752    [d.c., iii, plus, capo, iii, plus, beginners, ...
# 18764    [pes, 2009, pro, evolution, soccer, import, al...
# 18794                           [heroes, might, magic, vi]
# 18800        [club, trouve, tout, plantes, carnivores, 6e]
# 18809    [magideal, coque, protection, piece, complete,...
# 18831              [assassins, creed, 3, special, edition]
# 18848    [magideal, peau, console, controleur, sans, fi...
# 18872                      [confrontation, import, uk, pc]
# 18919                   [assassin, creed, iv, black, flag]
# 18928                     [persona, 5, ps4, japan, import]
# 18931            [terreur, revendre, voyageur, crepuscule]
# 18978    [magideal, 4x, bouton, balle, metal, d\, alumi...
# 18981    [one, piece, unlimited, world, red, day, one, ...
# 18996                         [tonka, camions, cascadeurs]
# 18998       [mud, mx, fim, motocross, world, championship]
# 19043           [chevaliers, baphomet, manuscrit, voynich]
# 19123            [lips, number, one, hits, 2, microphones]
# 19153                     [sos, animaux, mission, afrique]
# 19165                         [pit, fighter, version, usa]
# 19214                        [one, piece, mezase, kaizoku]
# 19290                   [fatal, fury, real, bout, special]
# 19319                   [dead, alive, 4, import, japonais]
# 19321                 [ultra, makaimura, r, japan, import]
# 19326               [prince, persia, ame, guerrier, gamer]
# 19337                  [red, victory, squad, battles, hps]
# 19408    [magideal, remplacement, lb, rb, trigger, bout...
# 19442               [warhammer, 40000, inquisitor, martyr]
# 19455               [soul, calibur, v, edition, collector]
# 19520     [bravely, default, flying, fairy, import, japon]
# 19607              [need, speed, rivals, edition, limitee]
# 19714                            [suikoden, 5, import, us]
# 19729                          [pony, friends, 2, jeu, pc]
# 19730               [hannah, montana, jeu, officiel, film]
# 19826    [battlefield, 3, limited, edition, import, all...
# 19967    [mount, blade, warband, collectors, edition, p...
# 19968              [perfect, dark, zero, import, japonais]
# 20001                  [trainz, railroad, simulator, 2012]
# 20018    [deus, ex, human, revolution, augmented, edition]
# 20042                              [lego, jurassic, world]
# 20056                          [sims, 2, edition, limitee]
# 20075                                    [nhl, face, 2000]
# 20184                                 [tour, france, 2013]
# 20196     [nba, street, homecourt, jeu, ps3, version, jap]
# 20206                                      [total, attila]
# 20244                           [tigalo, champion, poneys]
# 20270    [need, speed, pro, street+shift, double, value...
# 20278    [operation, flashpoint, 3, jeux, pc, cold, cri...
# 20303                   [dungeon, siege, hits, collection]
# 20312          [call, duty, world, ensemble, complet, wii]
# 20349                           [heroes, might, magic, iv]
# 20360    [eurofighter, 2000, tactcom, serie, limitee, l...
# 20363    [prince, persia, forgotten, sands, import, ang...
# 20375    [mouvement, blanc, adaptateur, capteur, extern...
# 20459                [taika, becher, henkel, schwarz, 04l]
# 20601    [cable, hdmi, haute, vitesse, male, male, comp...
# 20612    [cable, rca, 20a, extension, cable, lead, male...
# 20627    [nikoli, sudoku, lite, dai, 4, shuu, import, j...
# 20692                     [dj, hero, 2, platine, dj, hero]
# 20758    [indestructibles, terrible, attaque, demolisseur]
# 20759     [100, courriers, word, 100, applications, excel]
# 20857            [prototype, ensemble, complet, xbox, 360]
# 20863                            [wolfenstein, nex, order]
# 20926                               [5th, dimension, type]
# 20947               [adventure, time, pirates, terre, ooo]
# 21000                       [donkey, kong, mini, classics]
# 21048                  [mario, party, 4, import, japonais]
# 21247                                 [tak, pouvoir, juju]
# 21258                    [dracula, resurrection, ps1, pal]
# 21334                          [disney, best, jeux, video]
# 21424              [nba, 2k11, import, allemand, jeu, wii]
# 21440    [magideal, noire, accessoires, housse, protect...
# 21450    [seitokai, ichizon, ds, suru, seitokai, dx, pa...
# 21457    [metal, slug, 5, japan, version, neo, geo, aes...
# 21469                              [2600, jeux, shareware]
# 21489                   [final, fantasy, xii, zodiac, age]
# 21491    [call, duty, modern, warfare, 2, classics, edi...
# 21516    [hunter, x, hunter, hunter, keifu, import, japon]
# 21523                        [disciples, iii, renaissance]
# 21566      [operation, flashpoint, sold, software, pc, uk]
# 21570                                        [code, route]
# 21623    [coffret, 2, enquetes, nancy, drew, maledictio...
# 21650     [street, fighter, 30th, anniversary, collection]
# 21669                            [dr, mario, version, jap]
# 21691            [shinobi, ii, version, japonaise, gg, ii]
# 21699    [valisette, hobby, soft, tetrix, pinball, pack...
# 21781    [collection, classique, simulation, f22, light...
# 21847                           [tetrix, 10, jeux, tetrix]
# 21855                            [medieval, 2, gold, pack]
# 21881                         [street, fighter, x, tekken]
# 21987                           [age, empires, age, kings]
# 22105      [enlightenus, pc, cd, import, anglais, jeu, pc]
# 22117    [compilation, assassin, creed, 4, black, flag,...
# 22139    [medieval, total, viking, invasion, ensemble, ...
# 22167                                 [act, high, treason]
# 22180                      [serious, sam, next, encounter]
# 22193    [tiger, twin, cobra, us, megadrive, import, ja...
# 22197    [knockout, party, wii, import, anglais, jeu, wii]
# 22348                  [nancy, drew, creature, kapu, cave]
# 22360             [call, duty, black, ops, iii, steelbook]
# 22406                                 [hostel, umd, video]
# 22418                            [fast, furious, showdown]
# 22444           [konami, pes, 2019, ps4, import, allemand]
# 22451         [frozen, synapse, import, allemand, jeu, pc]
# 22465                    [tout, reussir, cm2, 10, 11, ans]
# 22535    [magideal, housse, protection, silicone, soupl...
# 22564    [sorcery, move, erforderlich, import, allemand...
# 22566    [final, fantasy, xiii, 2, import, allemand, je...
# 22643                   [crazy, climber, import, japonais]
# 22709    [version, wasp, x, one, handed, manette, jeu, ...
# 22738                  [gradius, 3, 4, version, japonaise]
# 22795                       [mind, quiz, musclez, cerveau]
# 22847    [fist, north, star, ken, rage, import, alleman...
# 22876                                 [kakko, warui, love]
# 22929                         [world, heroes, 2, japonais]
# 22935                            [kol, 99, redline, racer]
# 22972    [babes, balls, vol.3, gotcha, babes, x, treme,...
# 22978    [metal, slug, 2, japan, version, neo, geo, aes...
# 22987                      [mafia, ii, edition, collector]
# 23023           [g1, jockey, 4, import, anglais, jeu, ps2]
# 23028    [gtr, fia, gt, racing, game, ensemble, complet...
# 23050                 [imo, roi, conte, africain, pc, mac]
# 23091       [def, jam, icon, ensemble, complet, xbox, 360]
# 23105                      [tales, borderlands, xone, mix]
# 23114                   [disgaea, 4, promise, unforgotten]
# 23133          [magical, drop, pocket, version, japonnais]
# 23176          [star, wars, empire, gold, edition, gamers]
# 23179    [magideal, ventilateur, interne, refroidisseme...
# 23197    [aventures, monsieur, curieux, pique, nique, s...
# 23206                       [ghost, recon, silent, weapon]
# 23269    [lunar, silver, star, story, complete, import,...
# 23311    [las, cronicas, narnia, el, principe, caspian,...
# 23357                        [might, magic, clash, heroes]
# 23469            [lego, batman, import, italien, jeu, ps2]
# 23508    [ritter, arthur, trilogie, import, allemand, j...
# 23523    [nouvelles, enquetes, nancy, drew, malediction...
# 23534          [sniper, elite, nazi, zombie, army, gamers]
# 23536                      [overwatch, edition, collector]
# 23590         [star, trek, next, generation, final, unity]
# 23616                       [terre, milieu, ombre, mordor]
# 23630                       [bladestorm, guerre, 100, ans]
# 23711    [paintball, heroes, pc, import, anglais, jeu, pc]
# 23714    [telephone, portable, gaming, controller, grip...
# 23756       [first, kiss, monogatari, 2, import, japonais]
# 23764            [hidden, expedition, smithsonian, castle]
# 23798                        [overclocked, therapie, choc]
# 23913                    [trauma, center, second, opinion]
# 23940    [mobip, 001, little, busters, kamikita, komari...
# 23959    [dragon, ball, revenge, king, piccolo, import,...
# 24019    [usb, universel, type, support, charge, rapide...
# 24124                                 [medal, honor, 2010]
# 24137    [integre, 108, jeux, classiques, 28, pouces, r...
# 24165       [pes, 2008, premium, pack, edition, collector]
# 24175                      [xevious, 3d, g+, version, jap]
# 24182    [dr., jekyll, mr., hyde, import, allemand, jeu...
# 24190                               [sxr, snow, x, racing]
# 24227            [sims, 3, sims, 3, seasons, double, pack]
# 24255                  [toboclic, 99, juillet, aout, 2010]
# 24294                     [singstar, pop, hits, 2, micros]
# 24340             [crazy, frog, collectables, art, school]
# 24343                        [prince, persia, sands, time]
# 24372    [ventilateur, processeur, pc, ventilateur, 2, ...
# 24387    [100, paquets, bouton, commande, potentiometre...
# 24404                           [1st, mini, album, repack]
# 24425                    [might, magic, vii, blood, honor]
# 24436                         [f1, 2013, classic, edition]
# 24449                            [x, bladez, line, skater]
# 24481                       [challenge, brain, puzzles, 2]
# 24545    [gift, prism, limited, edition, import, japonais]
# 24590    [flipper, collector, pinball, award, plus, ali...
# 24729                    [void, import, allemand, jeu, pc]
# 24747        [keiba, navi, uma, suke, 2, import, japonais]
# 24758    [magideal, housse, protection, silicone, conso...
# 24795    [crossword, manabou, chiri, rekishi, import, j...
# 24830    [casper, magischer, spielzeugladen, import, al...
# 24851    [gamepad, tracer, trooper, bluetooth, ps3, tra...
# 24891    [cable, extension, audio, stereo, 3.5, mm, mal...
# 24892             [dark, parables, retour, princesse, sel]
# 24897                             [rugby, league, live, 2]
# 24950    [dead, alive, 5, cross, play, pack, import, ja...
# 25026    [arcade, hits, sonic, wings, special, import, ...
# 25041    [tony, hawk, american, wasteland, ensemble, co...
# 25095         [fifa, 14, import, allemand, jeu, xbox, 360]
# 25102            [meitantei, conan, giwaku, gouka, ressha]
# 25111                            [astro, boy, video, game]
# 25119                      [modnation, racers, essentials]
# 25145                       [littlebigplanet, 2, platinum]
# 25225                 [copains, foret, secours, plus, eau]
# 25230          [bulls, vs, lakers, nba, playoffs, genesis]
# 25237                       [sega, flash, vol.1, 6, demos]
# 25249    [exploitation, agricole, pro, simulator, 2014,...
# 25253          [midnight, club, 3, dub, edition, platinum]
# 25263    [pied, aluminium, pied, clous, antichoc, planc...
# 25271                [hidden, expedition, perle, discorde]
# 25285    [collection, jeux, aventures, historiques, lou...
# 25303                                         [dents, mer]
# 25324    [cinemaware, classics, defender, crown, ensemb...
# 25339    [housse, protection, silicone, nintendo, commu...
# 25351          [shogi, best, collection, import, japonais]
# 25364                        [dragon, dogma, dark, arisen]
# 25372                                      [pac, world, 3]
# 25387                                     [moche, mechant]
# 25467    [sega, megadrive, steel, empire, koutetsu, tei...
# 25498                               [battle, troy, pc, vf]
# 25526    [3, set, abxyz, button, thumbsticks, kit, pad,...
# 25600                   [mystery, legends, fantome, opera]
# 25654         [daigasso, band, brothers, import, japonais]
# 25687                            [g.i, joe, reveil, cobra]
# 25703    [adi, entraineur, anglais, primaire, 7, 11, an...
# 25712                  [next, big, thing, silvre, edition]
# 25725     [ultraleague, ultra, league, moero, soccer, jap]
# 25784    [bleach, soul, carnival, psp, best, import, ja...
# 25821                         [kol, 99, f22, lightning, 2]
# 25844    [transformers, 3, dark, moon, stealth, force, ...
# 25851                    [watch, dogs, vigilante, edition]
# 25932                                     [geants, arcade]
# 25942                      [buzz, music, quizz, 4, buzzer]
# 25950                                    [realms, hauting]
# 25952    [magideal, ventilateur, vertical, multifonctio...
# 25955    [magideal, 1xpaire, housse, protection, joysti...
# 25960                          [virtual, soccer, sbn, occ]
# 25996                [horizon, zero, dawn, playstation, 4]
# 26027                      [finfin, teo, planete, magique]
# 26099                       [pro, evolution, soccer, 2008]
# 26108         [grand, theft, auto, liberty, city, stories]
# 26142    [magideal, ensembles, vis, completes, r, print...
# 26157                       [julia, retour, vers, sixties]
# 26209                 [rayman, origins, import, americain]
# 26255                        [methode, guitare, classique]
# 26326    [square, enix, kingdom, hearts, hd, 1.5+2.5, r...
# 26357                           [elex, edition, collector]
# 26363    [legend, zelda, windwaker, hd, nintendo, selects]
# 26376                                       [ssx, 4, tour]
# 26407    [unsolves, mystery, club, ancient, astronauts,...
# 26418    [3ds, pal+australia, esp, eng, fr, legend, zel...
# 26421    [magideal, 2, 1, cable, alimentation, usb, cha...
# 26443    [magideal, ventilateur, refroidissement, inter...
# 26485    [lupin, iii, lupin, ni, wa, shi, zenigata, ni,...
# 26533      [best, youda, games, import, allemand, jeu, pc]
# 26576    [jojo, bizarre, adventure, star, battle, gold,...
# 26587        [tomb, raider, anniversary, import, japonais]
# 26589                         [overblood, 2, version, jap]
# 26675    [nostradamus, derniere, prophetie, edition, co...
# 26757            [assassin, creed, odyssey, edition, gold]
# 26835                        [art, murder, cards, destiny]
# 26866                             [vie, emma, super, star]
# 27028             [bundle, halo, 3, halo, wars, xbox, 360]
# 27041                      [riglord, saga, 2, mystaria, 2]
# 27047                           [cave, vin, gault, millau]
# 27128                             [2006, fifa, wolrd, cup]
# 27133    [playstation, 4, dragon, quest, heroes, crepus...
# 27139    [bureau, xcom, declassified, import, allemand,...
# 27166    [zoo, tycoon, dinosaur, digs, ensemble, comple...
# 27176               [travaux, forestiers, simulator, 2012]
# 27182    [tomb, raider, trilogy, legend, underworld, an...
# 27239       [alte, agypten, pc, import, allemand, jeu, pc]
# 27242         [destiny, el, rey, los, poseidos, xbox, 360]
# 27299    [cable, stereo, 35, mm, 1, 8, pouce, male, ver...
# 27358      [neverwinter, nights, 2, mask, betrayer, addon]
# 27384    [tom, clancy, h.a.w.x, 2, import, allemand, je...
# 27399            [impossible, creatures, hits, collection]
# 27452       [socom, u.s., navy, seals, fireteam, bravo, 2]
# 27550    [100pc, lp, vinyle, record, interieur, riz, do...
# 27590                     [barbie, styliste, defile, mode]
# 27626    [hana, oboro, sengoku, ranki, sony, ps, vita, ...
# 27647    [magideal, bouton, declenchement, pare, chocs,...
# 27671                                 [tout, jeux, casino]
# 27679    [atv, offroad, fury, 4, import, allemand, jeu,...
# 27717    [ghost, recon, future, soldier, import, allema...
# 27718    [magideal, tv, support, holder, pince, clip, s...
# 27762    [antenne, signal, aerien, hdtv, vhf, televisio...
# 27773    [mini, retro, console, jeu, tetris, etudiants,...
# 27792    [shiseido, beauty, solution, kaihatsu, center,...
# 27793              [siedler, 3, import, allemand, jeu, pc]
# 27813    [resident, evil, 5, gold, edition, jeu, xbox, ...
# 27846                       [x, edge, dash, import, japon]
# 27884                  [spider, web, shadows, version, us]
# 27933                        [terreur, revendre, 13, cles]
# 27976                 [mini, loup, petit, loup, tout, fou]
# 28028              [zen, gardens, kyoto, nature, enclosed]
# 28032                    [3, jeux, cafe, bar, room, games]
# 28040     [veut, gagner, millions, seconde, edition, euro]
# 28047    [magideal, 4x, manette, joystick, analogique, ...
# ...
# 75329    [pirates, caribbean, dead, chest, import, japo...
# 75394    [arcana, heart, 3, import, anglais, jeu, xbox,...
# 75404    [grand, theft, auto, iii, gta, vice, city, ver...
# 75409    [farming, simulator, 17, platinum, expansion, ...
# 75429    [cable, microphone, male, vers, xlr, femelle, ...
# 75485    [modecom, mag, d1, drakkar, full, tower, noir,...
# 75501                    [ranma, 1, 2, toraware, hanayome]
# 75508                           [shanghai, great, moments]
# 75524                   [lapins, cretins, grosse, bagarre]
# 75527                                        [tin, escape]
# 75594    [dragon, quest, heroes, day, one, edition, edi...
# 75699                       [syphon, filter, 3, platinium]
# 75761         [gears, 3, import, allemand, jeu, xbox, 360]
# 75768                   [belmont, revenge, castlevania, 2]
# 75800        [serious, sam, hd, import, allemand, jeu, pc]
# 75858               [fushigi, dungeon, torneko, daibouken]
# 75930    [magideal, housse, protection, couverture, sec...
# 75970                      [microsoft, golf, version, 2.0]
# 76011    [final, fantasy, iv, complete, collection, ff,...
# 76014    [sniper, elite, v2, import, allemand, jeu, xbo...
# 76019                             [hellboy, science, evil]
# 76030                         [tekken, 3d, prime, edition]
# 76066        [nba, 2k12, import, allemand, jeu, xbox, 360]
# 76090    [4games, vol, 9, adrenalin, ocean, dive, champ...
# 76122    [snark, busters, high, society, import, allema...
# 76345    [minna, map, 2, chiikiban, western, japan, imp...
# 76406    [rise, tomb, raider, 20, year, anniversary, ar...
# 76444    [steins, gate, hiyoku, renri, darling, import,...
# 76484    [crayon, shin, chan, 2, ora, wanpaku, gokko, d...
# 76498    [pal, version, nintendo, wii, u, rabbids, land...
# 76526    [shin, sangoku, musou, multi, raid, special, i...
# 76580               [gran, turismo, 5, prologue, platinum]
# 76597    [3pin, xlr, male, femelle, prise, jack, microp...
# 76664                             [dance, 2016, unlimited]
# 76696               [asterix, apprenez, anglais, 2cd, rom]
# 76710    [magideal, cable, adaptateur, embout, manette,...
# 76773                     [seigneurs, dogtown, umd, video]
# 76776         [two, worlds, ii, import, allemand, jeu, pc]
# 76803    [bibi, tina, jump, ride, software, pyramide, i...
# 76806                [far, cry, 2, classics, best, seller]
# 76819               [stardew, valley, collectors, edition]
# 76831                             [need, speed, prostreet]
# 76851    [star, wars, old, rpublic, import, anglais, je...
# 76902    [international, cricket, captain, 2010, pc, cd...
# 76948                 [starwars, old, republic, collector]
# 76990                            [egypte, temps, pharaons]
# 77010    [magideal, 8, 1, jeu, complet, tournevis, nint...
# 77019    [eiken, kakomon, daishuuroku, eiken, ds, 2, de...
# 77021    [earth, defense, force, insect, armageddon, im...
# 77096                       [cate, west, vanishing, files]
# 77203                                    [amour, chiot, 2]
# 77230    [amazing, adventures, around, world, jagd, wel...
# 77237               [super, princess, peach, nintendo, ds]
# 77246       [new, art, academy, import, italien, jeu, 3ds]
# 77251    [might, magic, heroes, vi, import, anglais, je...
# 77273              [new, unou, kids, ds, import, japonais]
# 77355                 [dragon, lair, 3d, special, edition]
# 77368    [magideal, usb, 2.0, bluetooth, v4.0, dongle, ...
# 77385    [princesse, isabella, chateau, ensorcele, prin...
# 77457    [module, prise, murale, 3, ports, femelle, pla...
# 77472                [jurassic, hunted, import, americain]
# 77480                        [ultimate, dungeons, dragons]
# 77615    [elemental, gimmick, gear, e., g., g., import,...
# 77652              [janes, zoo, import, allemand, jeu, pc]
# 77658                       [awakening, reveil, princesse]
# 77663    [1, 6, scale, instrument, musique, sousaphone,...
# 77729                            [rugby, world, cup, 2015]
# 77790              [xevious, famicom, mini, import, japon]
# 77837                           [star, wars, mythe, magie]
# 77856    [speed, grapher, episodi, 13, 24, import, ital...
# 77877    [1, 175, yomeimon, processed, gold, plating, w...
# 77936        [swat, 1, 2, 3, trilogie, edition, collector]
# 78005                  [factory, tycoon, version, benelux]
# 78037    [gpd, pocket, 2, 8, go, ram, orange, 7, mini, ...
# 78048    [1, 3000, tokyo, sky, tree, pink, plastic, model]
# 78069          [hyper, sports, track, field, famicom, jap]
# 78073                             [veut, gagner, millions]
# 78095                   [championship, manager, 5, pc, uk]
# 78182    [chessmaster, edition, grand, maitre, 11eme, e...
# 78208    [resident, evil, 7, biohazard, xbox, one, ital...
# 78255          [lumiere, grands, peintres, coffret, 4, cd]
# 78284                          [cowboy, beebop, film, umd]
# 78346                        [pack, singstar, 80s, micros]
# 78362                     [f.e.a.r, 3, edition, collector]
# 78364            [poker, academy, edition, standard, 2007]
# 78374                                      [prince, ecole]
# 78409                    [dingo, extreme, skate, boarding]
# 78426    [next, revolution, jouhou, security, specialis...
# 78437              [yamasa, digi, world, 4, import, japon]
# 78555         [battle, arena, toshinden, 3, import, japon]
# 78567                         [baby, sitter, metier, reve]
# 78576                  [go, diego, go, secours, dinosaure]
# 78617                 [alone, dark, 5, edition, collector]
# 78654                               [chevaliers, baphomet]
# 78666                 [aventures, tintin, secret, licorne]
# 78683                  [operation, flashpoint, red, river]
# 78773     [enquetes, nancy, drew, 10, kidnapping, bahamas]
# 78841                        [winnie, ourson, arbre, miel]
# 78857    [major, league, baseball, 2k9, import, americain]
# 78870                      [rudolph, red, nosed, reindeer]
# 78914         [13, sai, hello, work, ds, import, japonais]
# 78978                             [driver, san, francisco]
# 79032              [seigneur, anneaux, communaute, anneau]
# 79057                   [assassins, creed, rogue, hd, ps4]
# 79069                      [mind, language, japenese, tbc]
# 79107    [cable, coaxial, repartiteurs, tv, splitter, s...
# 79135                  [samurai, dou, 4, import, japonais]
# 79201                   [burnout, paradise, ultimate, box]
# 79231                            [sims, 2, bonne, affaire]
# 79271                                 [devil, may, cry, 4]
# 79296    [magideal, 2x, coque, protection, housse, tran...
# 79313                    [trauma, center, second, opinion]
# 79339    [classique, console, jeux, video, tv, game, pl...
# 79368                       [glory, roman, empire, silver]
# 79424                          [ile, 2, revanche, casbric]
# 79436    [table, murale, dipole, interieur, hdtv, hd, t...
# 79499                           [sacred, 2, fallen, angel]
# 79508    [samsung, galaxy, trend, s7560, verre, trempa,...
# 79512          [nfl, tour, ps3, import, anglais, jeu, ps3]
# 79571                      [turning, point, fall, liberty]
# 79619          [brian, lara, international, cricket, 2005]
# 79620    [daffy, duck, tresor, canard, version, euro, c...
# 79656             [adibou, initiation, anglais, 4, 7, ans]
# 79735                                        [monde, nemo]
# 79889                [frontline, fields, thunder, jeu, pc]
# 79919               [tiger, woods, pga, tour, 12, masters]
# 79921                        [divinity, ii, ego, draconis]
# 79922    [resident, evil, darkside, chronicles, wii, im...
# 79965                           [adibou, presente, dessin]
# 80001                         [left, 4, dead, 2, classics]
# 80033                           [need, speed, underground]
# 80049    [dead, space, 3, limited, edition, import, all...
# 80067                        [wwf, smackdown, 2, platinum]
# 80085    [bi, pack, forestia, ile, mysterieuse, oncle, ...
# 80118    [telephone, portable, gaming, trigger, poignee...
# 80145    [magideal, carte, bouton, commutateur, mise, s...
# 80150         [roland, garros, french, open, 2001, pc, uk]
# 80157    [silicone, housse, protection, poke, ball, plu...
# 80215                                 [shade, jeu, pc, vf]
# 80231                 [paper, mario, 2, porte, millenaire]
# 80241         [dead, space, 3, essentials, playstation, 3]
# 80272             [petits, debrouillards, decouverte, vie]
# 80287                  [barbie, fashion, show, eye, style]
# 80295    [housse, transport, fibre, carbone, shell, sac...
# 80361    [figurine, lego, dimensions, owen, trooper, ju...
# 80380                            [hertford, loop, jeu, pc]
# 80420                    [wanted, pack, pilgrim, casanova]
# 80436    [mary, kate, ashley, get, clue, game, boy, col...
# 80454    [telephone, mobile, manger, poulet, jeu, cle, ...
# 80457    [resident, evil, 5, edition, steelbox, collect...
# 80490    [2, set, 1, 6, soutien, gorge, jupe, culotte, ...
# 80520                           [geometry, wars, galaxies]
# 80528            [indestructibles, 1, jeu, action, pc, vf]
# 80544          [fifa, 11, import, italien, jeu, xbox, 360]
# 80563    [cable, extension, video, 10m, 15m, camera, st...
# 80569                         [operation, air, assault, 2]
# 80668               [f1, 2011, import, allemand, jeu, ps3]
# 80669    [magideal, porte, cartes, 10, 1, etui, rangeme...
# 80680                               [deep, sea, tycoon, 2]
# 80830    [risen, 2, dark, waters, edition, exclusivite,...
# 80872         [goat, simulator, simulateur, chevre, goaty]
# 80877       [amanda, rose, game, time, version, francaise]
# 80918                       [zanki, zero, last, beginning]
# 80943               [lead, gold, import, anglais, jeu, pc]
# 80958                                 [dj, work, playlist]
# 80967    [coffret, casual, fever, enigmes, objets, cach...
# 81033                           [wii, party, telecommande]
# 81044    [choplifter, hd, rettungshubschrauber, einheit...
# 81061                                    [saw, import, uk]
# 81063                    [guitar, hero, 2, bundle, guitar]
# 81075    [shin, hisui, shizuku, hiiro, kakera, 2, ds, l...
# 81085                    [mickey, mouse, legend, illusion]
# 81111                           [minna, waiwai, spelunker]
# 81262    [elfaria, ii, 2, super, famicom, complet, 159,...
# 81277        [spectral, vs., generation, import, japonais]
# 81293                             [eyepet, eyetoy, camera]
# 81300                   [bob, eponge, razmoket, 2, jeu, 1]
# 81339                   [conflict, desert, storm, classic]
# 81371     [3ds, pal+australia, esp, eng, fr, steel, diver]
# 81449              [return, double, dragon, import, japon]
# 81453                        [monster, high, lycee, enfer]
# 81461                      [codename, panzers, phase, two]
# 81493                    [fool, import, allemand, jeu, pc]
# 81647                      [trials, rising, gold, edition]
# 81769                   [prince, persia, 2, ame, guerrier]
# 81804               [gratte, ciels, simulator, simulation]
# 81821                         [metal, stoker, import, jap]
# 81951                       [whisper, libres, comme, vent]
# 81999    [magideal, 2x, controleur, jeux, mobiles, mane...
# 82002                  [virtua, athlete, 2k, version, jap]
# 82012    [console, xbox, 360, 500, gb, nera, plants, vs...
# 82073                                  [halo, 2, classics]
# 82075    [sid, meier, civilization, iv, beyond, sword, ...
# 82141                               [tt, isle, ride, edge]
# 82157                                  [transformers, jeu]
# 82176                           [shaq, fu, legend, reborn]
# 82190    [femelle, double, xlr, vers, male, rca, 2, fic...
# 82254    [mega, battle, network, 4, blue, moon, ensembl...
# 82258                        [grid, autosport, essentials]
# 82272    [magideal, 5x, 3.5mm, socket, audio, jack, soc...
# 82334    [1, 6, scale, chemise, mini, jupe, culotte, ch...
# 82429    [mythical, warriors, play, import, allemand, j...
# 82442                    [3d, globe, national, geographic]
# 82455    [grand, theft, auto, iv, gta, 4, complete, edi...
# 82479                        [power, mission, import, jap]
# 82507    [cheese, cat, astrophe, starring, speedy, gonz...
# 82522                              [night, journey, dream]
# 82530    [densetsu, ogre, battle, march, black, queen, ...
# 82539    [dragon, quest, monsters, joker, 2, professional]
# 82580                        [marvel, trading, card, game]
# 82632    [magideal, cable, durable, ruban, flexible, ps...
# 82649            [kinnikuman, dream, match, import, japon]
# 82653                            [collection, lara, croft]
# 82720    [solomon, ring, mizu, shou, limited, edition, ...
# 82841                                 [atv, drift, tricks]
# 82843                [cache, carmen, sandiego, version, 2]
# 82945                            [might, magic, x, legacy]
# 82996               [adibou, decouvre, anglais, 4, 8, ans]
# 83094    [silicone, housse, protection, poke, ball, plu...
# 83100    [kirihara, shoten, forest, eigo, ds, best, ver...
# 83109    [magideal, manette, bascule, capteur, analogiq...
# 83117                              [vilain, petit, canard]
# 83139                              [super, mario, bros, 2]
# 83161                          [super, smash, bros, melee]
# 83165    [dragon, ball, z, supersonic, fighter, 2, impo...
# 83207                              [brice, nice, umd, psp]
# 83299    [magideal, housse, protection, manette, coque,...
# 83335    [simple, ds, series, vol, 38, arc, minitsuku, ...
# 83379    [10x, bornier, poussoir, type, connecteur, ter...
# 83417    [dvb, t2, recepteur, dongle, hd, tuner, tv, nu...
# 83471              [gungrave, vr, loaded, coffin, edition]
# 83515             [rise, tomb, raider, edition, collector]
# 83518                [medal, honor, heroes, 2, essentials]
# 83545                           [college, autrement, 6eme]
# 83569    [super, eleves, 3eme, francais, histoire, geog...
# 83596    [playstation, minna, golf, playstation, best, ...
# 83625                          [beach, king, stunt, racer]
# 83707    [coffret, blizzard, diablo, 1, starcraft, warc...
# 83714    [dai, 3, ji, super, robot, taisen, super, fami...
# 83742    [starcraft, ii, legacy, void, edition, collector]
# 83746                        [barkley, jam, version, euro]
# 83777    [might, magic, duel, champions, online, card, ...
# 83807    [housse, universelle, neet, cable, usb, micro,...
# 83818                                   [50, jeux, amuser]
# 83846                      [abenteuer, tierhotel, jeu, pc]
# 83885             [final, fantasy, viii, playstation, jap]
# 83903    [max, payne, 3, special, edition, import, alle...
# 83979                          [self, control, umd, video]
# 84053    [magideal, cable, durable, ruban, flexible, ps...
# 84132                          [bratz, girl, really, rock]
# 84239                                       [hulk, pc, uk]
# 84312                             [japon, decouvrez, pays]
# 84314               [resident, evil, umbrella, chronicles]
# 84317                   [new, international, track, field]
# 84332                          [mat, hoffman, pro, bmx, 2]
# 84422                  [missile, commander, galaxie, 2100]
# 84425    [sims, triple, pack, plus, si, affinites, abra...
# 84464                      [guerilla, jagged, alliance, 2]
# 84639    [magideal, 2pcs, stylet, capacitif, tactile, s...
# 84675                        [oriental, blue, version, us]
# 84695    [aluminium, 10, 1, jeu, cartes, porte, cartouc...
# 84737                   [jupiter, strike, playstation, us]
# 84762    [magideal, l2, r2, l1, r1, bouton, bouchon, th...
# 84780    [alexey, pajitnov, laincroyable, histoire, cre...
# 84797                      [mortal, kombat, mystification]
# 84806                               [dernier, maitre, air]
# 84817    [men, black, alien, crisis, ensemble, complet,...
# 84833             [gundam, battle, online, version, japon]
# 84841                     [timesplitters, future, perfect]
# 84865    [cable, audio, jack, stereo, 3.5, mm, rca, mal...
# 84911                              [sims, import, anglais]

# %%
tokene = pd.DataFrame(token, columns = ['designation'])
from nltk.tokenize.regexp import RegexpTokenizer

tokenizer = RegexpTokenizer(pattern = "\w{4,}")

tokene.designation = tokene.designation.astype(str)
tokene.designation = tokene.designation.apply(tokenizer.tokenize)
tokene
# Out:
#                                              designation
# 31                                               [movie]
# 34                                         [lord, rings]
# 47          [shin, masoukishin, panzer, warfare, import]
# 50                                              [azteca]
# 101               [innercity, burnout, import, allemand]
# ...                                                  ...
# 84817  [black, alien, crisis, ensemble, complet, play...
# 84833           [gundam, battle, online, version, japon]
# 84841                   [timesplitters, future, perfect]
# 84865  [cable, audio, jack, stereo, male, accessoires...
# 84911                            [sims, import, anglais]
#
# [2478 rows x 1 columns]

# %% [markdown]
# # STEMMER :

# %%
#Version française
from nltk.stem.snowball import FrenchStemmer
liste_a= []
stemmer = FrenchStemmer()

ess = pd.Series(tokene.designation)
for i in ess :
    liste_j =[]
    for j in i:
        liste_j.append(stemmer.stem(word = j))
    liste_a.append(liste_j)
tokene = pd.Series(liste_a, index = token.index)

# %%
#Version anglaise
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

porter = PorterStemmer()
lancaster=LancasterStemmer()


liste_a= []

for i in tokene :
    liste_j =[]
    for j in i:
        liste_j.append(porter.stem(word = j))
    liste_a.append(liste_j)
tokene = pd.Series(liste_a, index = token.index)

liste_a= []

for i in tokene :
    liste_j =[]
    for j in i:
        liste_j.append(lancaster.stem(word = j))
    liste_a.append(liste_j)
tokene = pd.Series(liste_a, index = token.index)


tokene
# Out:
# 31                                                   [mov]
# 34                                            [lord, ring]
# 47                 [shin, masoukishin, panz, warf, import]
# 50                                                 [aztec]
# 101                    [innerc, burnout, import, allemand]
#                                ...
# 84817          [black, aly, cri, ensembl, complet, playst]
# 84833                  [gundam, battl, onlin, vert, japon]
# 84841                            [timesplit, fut, perfect]
# 84865    [cabl, audio, jack, stereo, mal, accessoir, sp...
# 84911                                 [sim, import, angla]
# Length: 2478, dtype: object

# %% [markdown]
# # LEMMATIZATION :

# %% [markdown]
# import spacy
#
# for token in doc:
#     print(token, token.lemma_)

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

liste_a= []

for i in tokene :
    liste_j =[]
    for j in i:
        liste_j.append(wnl.lemmatize(word = j, pos = "n"))
    liste_a.append(liste_j)
tokene = pd.Series(liste_a, index = token.index)
tokene
# Out:
# 31                                                   [mov]
# 34                                            [lord, ring]
# 47                 [shin, masoukishin, panz, warf, import]
# 50                                                 [aztec]
# 101                    [innerc, burnout, import, allemand]
#                                ...
# 84817          [black, aly, cri, ensembl, complet, playst]
# 84833                  [gundam, battl, onlin, vert, japon]
# 84841                            [timesplit, fut, perfect]
# 84865    [cabl, audio, jack, stereo, mal, accessoir, sp...
# 84911                                 [sim, import, angla]
# Length: 2478, dtype: object

# %%
tokene = pd.DataFrame(tokene, columns = ["designation"])

# %% [markdown]
# Vectorization :

# %%
tokene.designation=[" ".join(text) for text in tokene.designation.values]
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
vectorizer.fit_transform(tokene.designation)
vectorizer.vocabulary_
# Out:
# {'mov': 2045,
#  'lord': 1823,
#  'ring': 2553,
#  'shin': 2713,
#  'masoukishin': 1903,
#  'panz': 2219,
#  'warf': 3261,
#  'import': 1517,
#  'aztec': 301,
#  'innerc': 1535,
#  'burnout': 480,
#  'allemand': 173,
#  'zumb': 3402,
#  'fit': 1183,
#  'rush': 2596,
#  'kinect': 1689,
#  'xbox': 3322,
#  'pokemon': 2337,
#  'saph': 2624,
#  'alph': 178,
#  'edit': 988,
#  'limit': 1797,
#  'king': 1690,
#  'bount': 438,
#  'arm': 249,
#  'princess': 2378,
#  'cabl': 492,
#  'adapt': 135,
#  'audio': 281,
#  'stereo': 2889,
#  'ordin': 2179,
#  'port': 2345,
#  'mal': 1870,
#  'magid': 1852,
#  'guilt': 1373,
#  'gear': 1288,
#  'vert': 3209,
#  'japon': 1584,
#  'world': 3311,
#  'destruct': 865,
#  'rep': 2510,
#  'mod': 1999,
#  'capt': 517,
#  'analog': 198,
#  'joystick': 1621,
#  'consol': 700,
#  'microsoft': 1969,
#  'assassin': 261,
#  'cree': 750,
#  'broth': 459,
#  'revel': 2539,
#  'angla': 205,
#  'planet': 2303,
#  'coqu': 715,
#  'jeux': 1597,
#  'video': 3218,
#  'alumin': 180,
#  'boit': 414,
#  'son': 2816,
#  'would': 3314,
#  'soul': 2826,
#  'miss': 1991,
#  'veterinair': 3212,
#  'soign': 2806,
#  'anim': 207,
#  'famil': 1138,
#  'san': 2615,
#  'bal': 313,
#  'board': 409,
#  'dant': 799,
#  'greatest': 1356,
#  'hit': 1454,
#  'grab': 1346,
#  'gho': 1310,
#  'jagu': 1577,
#  'disney': 905,
#  'infin': 1528,
#  'star': 2875,
#  'war': 3258,
#  'pack': 2204,
#  'demar': 839,
#  'spec': 2838,
#  'virtu': 3233,
#  'fight': 1168,
#  'evolu': 1091,
#  'puc': 2405,
#  'meil': 1935,
#  'qualit': 2419,
#  'pul': 2409,
#  '1pc': 38,
#  'remington': 2500,
#  'bird': 379,
#  'hunt': 1501,
#  'fusil': 1256,
#  'noir': 2124,
#  'izz': 1572,
#  'quest': 2421,
#  'olymp': 2164,
#  'gen': 1299,
#  '2k13': 74,
#  'mond': 2013,
#  'spac': 2831,
#  'rog': 2568,
#  'wilco': 3284,
#  'tim': 3041,
#  'rip': 2555,
#  'steel': 2883,
#  'fur': 1251,
#  'karkhov': 1665,
#  '1942': 32,
#  'secret': 2663,
#  'dragon': 945,
#  'wheel': 3278,
#  'ton': 3068,
#  'hawk': 1416,
#  'skat': 2772,
#  'fin': 1174,
#  'fantas': 1141,
#  'pouvoir': 2358,
#  'forc': 1211,
#  'kirb': 1695,
#  'cryst': 772,
#  'shard': 2700,
#  'etu': 1080,
#  'telecommand': 2986,
#  'silicon': 2756,
#  'compat': 677,
#  'telev': 2989,
#  'samsung': 2614,
#  'aa59': 118,
#  '00816a': 3,
#  '00813a': 2,
#  'houss': 1491,
#  'bn59': 407,
#  '01265a': 4,
#  'trig': 3124,
#  'declench': 821,
#  'bouton': 440,
#  'schtroumpf': 2645,
#  'fet': 1159,
#  'forain': 1210,
#  'definit': 833,
#  'gam': 1270,
#  'dingo': 890,
#  'dino': 891,
#  'dessin': 862,
#  'interact': 1546,
#  'pas': 2230,
#  'flight': 1195,
#  'sim': 2760,
#  'airbu': 156,
#  'a318': 116,
#  'a321': 117,
#  'fallout': 1135,
#  'year': 3336,
#  'cod': 653,
#  'hon': 1473,
#  'leg': 1773,
#  'etrang': 1079,
#  'pet': 2261,
#  'pal': 2212,
#  'hoffm': 1461,
#  'senh': 2677,
#  'ane': 201,
#  'batalh': 334,
#  'pel': 2248,
#  'ter': 3006,
#  'med': 1927,
#  'fort': 1217,
#  'boyard': 443,
#  'enigm': 1035,
#  'objet': 2145,
#  'cach': 493,
#  'interpol': 1551,
#  'walk': 3253,
#  'dead': 810,
#  'season': 2659,
#  'gart': 1280,
#  'panik': 2217,
#  'hour': 1489,
#  'victor': 3216,
#  'ensembl': 1041,
#  'complet': 680,
#  'cap': 513,
#  'tournev': 3090,
#  'nintendo': 2117,
#  'switch': 2945,
#  'control': 708,
#  'remplac': 2505,
#  'accessoir': 130,
#  'manet': 1880,
#  'plast': 2306,
#  'facil': 1123,
#  'inst': 1541,
#  'club': 646,
#  'nind': 2114,
#  'gaid': 1266,
#  'figurin': 1169,
#  'kureh': 1738,
#  'bug': 468,
#  'bunn': 476,
#  'spir': 2856,
#  'temp': 2991,
#  'tortug': 3079,
#  'pir': 2295,
#  'flibust': 1194,
#  'goat': 1328,
#  'chevr': 590,
#  'end': 1029,
#  'remix': 2501,
#  'witch': 3298,
#  'collect': 662,
#  'rambo': 2444,
#  'coffret': 657,
#  'vin': 3228,
#  '2000': 40,
#  'recet': 2472,
#  'disqu': 908,
#  'additionnel': 136,
#  'lego': 1777,
#  'ind': 1525,
#  'jon': 1612,
#  'trilog': 3125,
#  'origin': 2181,
#  'print': 2380,
#  'pers': 2258,
#  'guerr': 1371,
#  'styl': 2910,
#  'detect': 867,
#  'stor': 2898,
#  'kudo': 1732,
#  'shunsaku': 2746,
#  'whit': 3280,
#  'suit': 2922,
#  'yusaku': 3345,
#  'matsud': 1915,
#  'jap': 1582,
#  'metroid': 1955,
#  'prim': 2376,
#  'left': 1772,
#  'right': 2549,
#  'bluetoo': 406,
#  'gamepad': 1274,
#  'autocol': 287,
#  'guit': 1375,
#  'not': 2131,
#  'cart': 529,
#  'etiquet': 1077,
#  'stick': 2890,
#  'debut': 814,
#  'hero': 1436,
#  'might': 1973,
#  'mag': 1850,
#  'bioshock': 376,
#  'roya': 2585,
#  'rang': 2445,
#  'protect': 2398,
#  'ant': 214,
#  'ray': 2456,
#  'choc': 603,
#  'pokeb': 2336,
#  'plu': 2323,
#  'tig': 3037,
#  'wood': 3308,
#  'tour': 3088,
#  'ghostbust': 1312,
#  'versu': 3208,
#  'kakut': 1649,
#  'mich': 1960,
#  'dark': 800,
#  'par': 2223,
#  'jack': 1573,
#  'ciel': 615,
#  'bowl': 441,
#  'fev': 1160,
#  'cocin': 651,
#  'jam': 1580,
#  'ol': 2162,
#  'spid': 2846,
#  'all': 170,
#  'ennem': 1038,
#  'thund': 3028,
#  'storm': 2899,
#  'meg': 1930,
#  'petit': 2263,
#  'sir': 2769,
#  'cit': 621,
#  'class': 628,
#  'asterix': 263,
#  'obelix': 2144,
#  'fou': 1223,
#  'gaulo': 1285,
#  '1080p': 10,
#  'hdmi': 1418,
#  'femel': 1154,
#  'hdtv': 1419,
#  'piec': 2283,
#  'grand': 1350,
#  'av': 292,
#  'fat': 1147,
#  'battl': 338,
#  'destin': 863,
#  'lin': 1798,
#  'chaot': 569,
#  'chronicl': 612,
#  'ri': 2544,
#  'moorhuhn': 2026,
#  'jump': 1628,
#  'atl': 273,
#  'unchart': 3165,
#  'nath': 2084,
#  'drak': 946,
#  'lar': 1759,
#  'croft': 759,
#  'tomb': 3066,
#  'raid': 2437,
#  'anniversar': 212,
#  'at': 270,
#  'gateway': 1283,
#  'apsha': 231,
#  'knight': 1707,
#  'merch': 1945,
#  'shat': 2703,
#  'kingdom': 1691,
#  'tripack': 3126,
#  'rebel': 2468,
#  'xwing': 3332,
#  'reto': 2526,
#  'myster': 2069,
#  'tal': 2965,
#  'schwarz': 2646,
#  'kat': 1667,
#  'edg': 987,
#  'al': 160,
#  'cossack': 726,
#  'europ': 1084,
#  'command': 670,
#  'conquest': 697,
#  'am': 183,
#  'firestorm': 1178,
#  'adv': 141,
#  'commut': 674,
#  'hot': 1484,
#  'caoutchouc': 511,
#  'hard': 1407,
#  'shel': 2705,
#  'film': 1172,
#  'tremp': 3115,
#  'yxjjpj392': 3367,
#  'ranm': 2447,
#  'bakuretsu': 312,
#  'rantou': 2448,
#  'op': 2172,
#  'mind': 1983,
#  'moy': 2047,
#  'choup': 610,
#  'platin': 2308,
#  'rid': 2546,
#  'obsc': 2148,
#  'fortnit': 1218,
#  'telecharg': 2985,
#  'conty': 709,
#  'million': 1980,
#  'ruckkehr': 2589,
#  'geheimnisvol': 1294,
#  'insel': 1538,
#  'frontlin': 1243,
#  'expand': 1102,
#  'slid': 2780,
#  'sherlock': 2706,
#  'holm': 1467,
#  'devil': 874,
#  'daught': 805,
#  'smackdown': 2786,
#  '2010': 51,
#  'plexton': 2320,
#  'wir': 3296,
#  'pubg': 2404,
#  'earbud': 968,
#  'telephon': 2987,
#  'overwatch': 2199,
#  'legac': 1774,
#  'kain': 1642,
#  'reav': 2467,
#  'malin': 1873,
#  'resid': 2520,
#  'evil': 1089,
#  'remast': 2499,
#  'biohazard': 374,
#  'ratchet': 2453,
#  'clank': 626,
#  'attack': 276,
#  'pearl': 2241,
#  'harb': 1406,
#  'gold': 1332,
#  '2pc': 78,
#  'bord': 426,
#  'mouss': 2043,
#  'soupl': 2827,
#  'haut': 1415,
#  'parl': 2228,
#  'pouc': 2351,
#  'nadesico': 2072,
#  'deceiv': 818,
#  'clash': 627,
#  'evangel': 1086,
#  'koh': 1713,
#  'enf': 1031,
#  'micro': 1965,
#  'bleu': 395,
#  'marvel': 1901,
#  'capcom': 515,
#  'everquest': 1088,
#  'theft': 3017,
#  'auto': 286,
#  'bulletstorm': 471,
#  'ful': 1247,
#  'clip': 638,
#  'clon': 641,
#  'hikon': 1445,
#  'castl': 544,
#  'model': 2001,
#  'doyush': 941,
#  'divin': 915,
#  'sag': 2605,
#  'silv': 2757,
#  'mugtail': 2052,
#  'moo': 2023,
#  'nasc': 2082,
#  'americain': 188,
#  'doubl': 938,
#  'splitt': 2859,
#  'ecout': 983,
#  'casqu': 540,
#  'spring': 2862,
#  'playst': 2315,
#  'odyss': 2153,
#  'trac': 3096,
#  'ulyss': 3161,
#  'engl': 1032,
#  'niveau': 2120,
#  'confirm': 690,
#  'expert': 1106,
#  'bus': 483,
#  'unit': 3173,
#  'princip': 2379,
#  'ba': 302,
#  'rady': 2435,
#  'ventil': 3203,
#  'refroid': 2485,
#  'heat': 1423,
#  'sink': 2768,
#  'yxjjpj204': 3358,
#  'interrupt': 1552,
#  'aly': 182,
#  'garcon': 1275,
#  'coul': 729,
#  'quiz': 2424,
#  'charaokedon': 573,
#  'patton': 2235,
#  'tank': 2971,
#  'joycon': 1619,
#  'gauch': 1284,
#  'droit': 956,
#  'joypad': 1620,
#  'poign': 2332,
#  'quickio': 2423,
#  'spin': 2852,
#  'clanc': 625,
#  'rainbow': 2440,
#  'lockdown': 1811,
#  'conduit': 689,
#  'republ': 2515,
#  'tchequ': 2978,
#  'beyblad': 365,
#  'met': 1950,
#  'fus': 1253,
#  'cyb': 782,
#  'pegasu': 2246,
#  'intern': 1549,
#  'nosferatu': 2128,
#  'helicopt': 1430,
#  'search': 2658,
#  'rescu': 2517,
#  'batail': 333,
#  'ard': 244,
#  'ser': 2682,
#  'honeycomb': 1475,
#  'beat': 344,
#  'hid': 1439,
#  'strok': 2906,
#  'pow': 2359,
#  'real': 2463,
#  'filt': 1173,
#  'epong': 1050,
#  'poussy': 2357,
#  'indestruct': 1526,
#  'terr': 3008,
#  'attaqu': 277,
#  'demoliss': 842,
#  'connect': 695,
#  'charg': 574,
#  'pri': 2375,
#  'puiss': 2408,
#  'prokofiev': 2390,
#  'symphon': 2947,
#  'marc': 1887,
#  'ecko': 978,
#  'get': 1308,
#  'cont': 703,
#  'press': 2372,
#  'histor': 1452,
#  'channel': 566,
#  'rom': 2574,
#  'sceiv': 2634,
#  'rev': 2536,
#  'robin': 2563,
#  'boi': 413,
#  'hor': 1477,
#  'dim': 888,
#  'tel': 2984,
#  'ita': 1571,
#  'cal': 501,
#  'dut': 964,
#  'march': 1888,
#  'ver': 3204,
#  'mobl': 1997,
#  '4in1': 101,
#  'tir': 3047,
#  'yxjjpj311': 3362,
#  'jungl': 1629,
#  'bambin': 317,
#  'un': 3164,
#  'bard': 325,
#  'best': 362,
#  'con': 686,
#  'aok': 219,
#  'housek': 1490,
#  'rinbukyoku': 2552,
#  'seign': 2668,
#  'anneau': 210,
#  'milieu': 1976,
#  'slim': 2781,
#  'fairl': 1130,
#  'oddp': 2152,
#  'shadow': 2696,
#  'showdown': 2741,
#  'jewel': 1598,
#  'match': 1910,
#  'ghost': 1311,
#  'recon': 2478,
#  'desert': 859,
#  'sieg': 2752,
#  'demolit': 843,
#  'compan': 676,
#  'ev': 1085,
#  'oas': 2142,
#  'couvert': 738,
#  'dur': 963,
#  'etanch': 1070,
#  'transport': 3106,
#  'bagf': 307,
#  'logitech': 1813,
#  'g903': 1262,
#  'g900': 1261,
#  'spear': 2837,
#  'black': 384,
#  'thorn': 3024,
#  'shogun': 2730,
#  'tot': 3082,
#  'nee': 2090,
#  'spee': 2841,
#  'prosreet': 2395,
#  'ultim': 3158,
#  'tenkaich': 3001,
#  'momot': 2010,
#  'densestsu': 848,
#  'turbo': 3145,
#  'hudson': 1496,
#  'soft': 2802,
#  'ent': 1043,
#  'matrix': 1914,
#  'nouvel': 2134,
#  'toy': 3093,
#  'gri': 1358,
#  'jaun': 1588,
#  'gamecub': 1273,
#  'outil': 2193,
#  'wing': 3292,
#  'hyp': 1506,
#  'light': 1792,
#  'drift': 952,
#  'saint': 2608,
#  'bijou': 373,
#  'seg': 2666,
#  'rac': 2427,
#  'cam': 504,
#  'infraroug': 1531,
#  'abx': 123,
#  'baton': 337,
#  'ecr': 984,
#  'yxjjpj219': 3360,
#  'blond': 401,
#  'oubl': 2188,
#  'cyc': 783,
#  'man': 1878,
#  'frant': 1229,
#  '2012': 53,
#  'cabel': 491,
#  'dang': 797,
#  '2013': 54,
#  'cardiaqu': 524,
#  'insid': 1540,
#  'monst': 2020,
#  'barb': 324,
#  'coe': 655,
#  'comb': 668,
#  'assault': 262,
#  'horizon': 1478,
#  'colin': 661,
#  'mcra': 1921,
#  'dirt': 895,
#  'seth': 2689,
#  'tribu': 3121,
#  'neandert': 2089,
#  'drac': 942,
#  '150cm': 24,
#  'microphon': 1967,
#  'enreg': 1040,
#  'sign': 2754,
#  'realsport': 2466,
#  'socc': 2798,
#  '2600': 68,
#  'act': 134,
#  'haunt': 1414,
#  'hel': 1429,
#  'reach': 2461,
#  'reset': 2519,
#  'marin': 1892,
#  'fish': 1181,
#  'sne': 2793,
#  'sup': 2927,
#  'circu': 618,
#  'vol': 3245,
#  'tricentenn': 3122,
#  'motorbik': 2037,
#  'tripl': 3127,
#  'part': 2229,
#  'bratz': 447,
#  'forev': 1214,
#  'diamondz': 877,
#  'tokyo': 3064,
#  'twilight': 3150,
#  'peau': 2242,
#  'pair': 2210,
#  'bouchon': 432,
#  'thumbstick': 3027,
#  'camo': 506,
#  'burn': 479,
#  'battlefield': 339,
#  'evolv': 1092,
#  'tornado': 3077,
#  '2004': 44,
#  '2011': 52,
#  'cri': 755,
#  'guncon': 1377,
#  'decod': 822,
#  'lect': 1770,
#  'direct': 894,
#  'aladdin': 162,
#  'plus2': 2325,
#  '10pc': 11,
#  'convert': 711,
#  'donk': 930,
#  'kong': 1720,
#  'countr': 730,
#  'got': 1338,
#  'revolu': 2543,
#  'bonu': 422,
#  'trib': 3120,
#  'xplosiv': 3331,
#  'twin': 3151,
#  'ot': 2186,
#  'extend': 1111,
#  'surv': 2940,
#  'zomb': 3397,
#  'read': 2462,
#  'rumbl': 2594,
#  'box': 442,
#  'fif': 1166,
#  'champ': 563,
#  'rockm': 2567,
#  'chip': 601,
#  'garnit': 1278,
#  'conduc': 688,
#  'chin': 597,
#  'mongol': 2014,
#  'kango': 1658,
#  'livr': 1808,
#  'sight': 2753,
#  'vietnam': 3222,
#  'util': 3188,
#  'want': 3257,
#  'happ': 1405,
#  'mu': 2049,
#  'despereau': 861,
#  'simpson': 2763,
#  'bart': 327,
#  'juggernaut': 1623,
#  'touchpad': 3086,
#  'fem': 1153,
#  'hom': 1468,
#  'echel': 976,
#  'vet': 3211,
#  'noel': 2123,
#  'feminin': 1155,
#  'last': 1761,
#  'prem': 2367,
#  'rub': 2588,
#  'circuit': 619,
#  'coup': 731,
#  '2002': 42,
#  'hybrid': 1503,
#  'rug': 2591,
#  'caoutchout': 512,
#  'snap': 2791,
#  'cov': 739,
#  'yxjjpj217': 3359,
#  'budok': 466,
#  'bugdom': 469,
#  'cuivr': 775,
#  'repartit': 2512,
#  'golf': 1333,
#  'smash': 2788,
#  'bro': 457,
#  'naboo': 2071,
#  'ca': 490,
#  'nca': 2087,
#  'footb': 1209,
#  'espanol': 1062,
#  'conseil': 698,
#  'meteo': 1951,
#  'stat': 2881,
#  'wif': 3281,
#  'meteorolog': 1952,
#  'sh1106': 2694,
#  '3inch': 91,
#  'flash': 1187,
#  'tellt': 2990,
#  'prototyp': 2399,
#  'radnet': 2434,
#  'regl': 2488,
#  'android': 200,
#  'prix': 2384,
#  'saison': 2609,
#  'ext': 1110,
#  'diablo': 876,
#  'chest': 587,
#  'kois': 1714,
#  'lov': 1829,
#  'peac': 2239,
#  'regul': 2490,
#  'her': 1434,
#  'abenteu': 121,
#  'aragorn': 235,
#  'ac': 126,
#  'multifonctionnel': 2056,
#  'pint': 2292,
#  'denud': 853,
#  'cordon': 718,
#  '28awg': 70,
#  'anstoss': 213,
#  '2005': 45,
#  'machin': 1846,
#  'electron': 1005,
#  'virtuel': 3234,
#  'elf': 1008,
#  'van': 3197,
#  'eth': 1074,
#  'premy': 2369,
#  'lign': 1794,
#  'mad': 1847,
#  'commando': 671,
#  'beyond': 366,
#  'uef': 3157,
#  'euro': 1082,
#  '2008': 48,
#  'mast': 1906,
#  'craddl': 742,
#  'ten': 2996,
#  'tabl': 2952,
#  'racket': 2431,
#  'support': 2934,
#  'naruto': 2081,
#  'shippud': 2722,
#  '3pc': 92,
#  'soud': 2825,
#  'trr': 3135,
#  'pol': 2338,
#  'jeun': 1596,
#  'cout': 736,
#  'dor': 934,
#  'enh': 1034,
#  'cirqu': 620,
#  'seur': 2692,
#  'train': 3099,
#  'delux': 837,
#  'front': 1242,
#  'onlin': 2171,
#  'forward': 1221,
#  'set': 2688,
#  'point': 2333,
#  'ampl': 192,
#  'phonograph': 2275,
#  'instru': 1542,
#  'geheimakt': 1292,
#  'purit': 2413,
#  'cord': 717,
#  'inselparad': 1539,
#  'rugb': 2592,
#  'kokun': 1716,
#  'gekit': 1298,
#  'warfight': 3262,
#  'stop': 2897,
#  'yxjjpj596': 3373,
#  'earthworm': 971,
#  'menac': 1942,
#  'galax': 1269,
#  'marco': 1890,
#  'polo': 2339,
#  'hou': 1488,
#  'tast': 2975,
#  'food': 1207,
#  'fact': 1124,
#  'fabl': 1121,
#  'peopl': 2252,
#  'custom': 781,
#  'premedit': 2368,
#  'dinosa': 892,
#  'math': 1913,
#  '2k11': 72,
#  'gundam': 1378,
#  'aeug': 143,
#  'tit': 3049,
#  'yxjjpj300': 3361,
#  'kung': 1735,
#  'harn': 1408,
#  'radio': 2433,
#  'voit': 3244,
#  'toyot': 3094,
#  'lexu': 1784,
#  'scion': 2649,
#  'darksid': 801,
#  'protrain': 2400,
#  'berlin': 359,
#  'hamburg': 1392,
#  'scal': 2631,
#  'kofukud': 1712,
#  'fiv': 1184,
#  'pagod': 2207,
#  'construct': 701,
#  'leagu': 1767,
#  '2001': 41,
#  'childr': 596,
#  'corn': 719,
#  'merlin': 1946,
#  'appr': 228,
#  'jak': 1579,
#  'handym': 1400,
#  'halo': 1390,
#  'mot': 2034,
#  'maledict': 1871,
#  'eglantin': 992,
#  'tru': 3136,
#  'fear': 1151,
#  'abandon': 119,
#  'glac': 1322,
#  'mozart': 2048,
#  'dern': 855,
#  'high': 1441,
#  'impact': 1516,
#  'painkil': 2208,
#  'resurrect': 2524,
#  'wario': 3264,
#  'disgu': 902,
#  'disg': 901,
#  'day': 808,
#  'yum': 3344,
#  'tsubom': 3140,
#  'acac': 127,
#  'shit': 2727,
#  'sil': 2755,
#  'hil': 1446,
#  'homecom': 1469,
#  'remot': 2504,
#  'mahjong': 1857,
#  'comprend': 684,
#  'recev': 2473,
#  'sour': 2828,
#  'tsub': 3139,
#  'reservoir': 2518,
#  'tom': 3065,
#  'parad': 2224,
#  '2pack': 76,
#  'slot': 2783,
#  'cartouch': 532,
#  'detach': 866,
#  'hold': 1463,
#  'factor': 1125,
#  'elkron': 1012,
#  'dear': 812,
#  'otom': 2187,
#  'michael': 1961,
#  'jackson': 1574,
#  'exper': 1104,
#  'softw': 2804,
#  'pyramid': 2418,
#  'crash': 745,
#  'megadr': 1931,
#  'warry': 3265,
#  'jean': 1589,
#  'island': 1569,
#  'castaway': 543,
#  'tivol': 3053,
#  'lernerfolg': 1779,
#  'grundsch': 1367,
#  'deutsch': 872,
#  'rechtschreibtrain': 2475,
#  'truck': 3137,
#  'scoob': 2651,
#  'nuit': 2136,
#  'frisson': 1238,
#  '3pin': 93,
#  'rj45': 2560,
#  'georg': 1306,
#  'protct': 2397,
#  'consl': 699,
#  'rechang': 2474,
#  'sci': 2648,
#  'born': 428,
#  'fich': 1163,
#  'ban': 318,
#  'plaqu': 2305,
#  'mario': 1893,
#  'rabbid': 2426,
#  'blad': 387,
#  'tear': 2980,
#  'ed': 985,
#  'dreamcast': 950,
#  'appart': 226,
#  'cot': 728,
#  'chez': 591,
#  'micropo': 1968,
#  'mei': 1933,
#  'zombrex': 3398,
#  'sect': 2664,
#  'fronty': 1244,
#  'fut': 1258,
#  'sold': 2810,
#  'caraib': 521,
#  'legend': 1775,
#  'sparrow': 2834,
#  'pharaon': 2270,
#  'robinson': 2564,
#  'cruso': 770,
#  'cur': 778,
#  'mcray': 1922,
#  'rall': 2442,
#  'fir': 1176,
#  'chief': 593,
#  'compil': 679,
#  'brav': 449,
#  'travel': 3109,
#  'bouc': 431,
#  'verrouil': 3206,
#  'nouveau': 2133,
#  'kizun': 1702,
#  'driv': 954,
#  'ni': 2105,
#  'repl': 2514,
#  'eiyu': 999,
#  'densetsu': 849,
#  'ry': 2598,
#  'inv': 1555,
#  'vien': 3221,
#  'espac': 1060,
#  'min': 1982,
#  'hannah': 1403,
#  'mont': 2022,
#  'veng': 3201,
#  'wolverin': 3305,
#  'mysim': 2066,
#  'settl': 2691,
#  'hind': 1449,
#  'staf': 2869,
#  'titulair': 3052,
#  'pistolet': 2296,
#  'zap': 3389,
#  'wiimot': 3282,
#  'dist': 911,
#  ...}

# %%
from collections import Counter
print(Counter(vectorizer.vocabulary_))
# Out:
# Counter({'zuruck': 3403, 'zumb': 3402, 'zorro': 3401, 'zool': 3400, 'zon': 3399, 'zombrex': 3398, 'zomb': 3397, 'zodiac': 3396, 'zip': 3395, 'zhongru': 3394, 'zero': 3393, 'zenin': 3392, 'zenig': 3391, 'zeld': 3390, 'zap': 3389, 'zank': 3388, 'zam': 3387, 'zak': 3386, 'zaidanhoujin': 3385, 'yxjjpj809': 3384, 'yxjjpj773': 3383, 'yxjjpj769': 3382, 'yxjjpj761': 3381, 'yxjjpj748': 3380, 'yxjjpj684': 3379, 'yxjjpj681': 3378, 'yxjjpj673': 3377, 'yxjjpj653': 3376, 'yxjjpj629': 3375, 'yxjjpj613': 3374, 'yxjjpj596': 3373, 'yxjjpj595': 3372, 'yxjjpj592': 3371, 'yxjjpj576': 3370, 'yxjjpj547': 3369, 'yxjjpj423': 3368, 'yxjjpj392': 3367, 'yxjjpj389': 3366, 'yxjjpj376': 3365, 'yxjjpj347': 3364, 'yxjjpj329': 3363, 'yxjjpj311': 3362, 'yxjjpj300': 3361, 'yxjjpj219': 3360, 'yxjjpj217': 3359, 'yxjjpj204': 3358, 'yxjjpj170': 3357, 'yxjjpj163': 3356, 'yxjjpj154': 3355, 'yxjjpj149': 3354, 'yxjjpj146': 3353, 'yxjjpj141': 3352, 'yxjjpj121': 3351, 'yxjjpj079': 3350, 'yxjjpj073': 3349, 'yxjjpj031': 3348, 'yuushun': 3347, 'yush': 3346, 'yusaku': 3345, 'yum': 3344, 'yukyu': 3343, 'young': 3342, 'youkoso': 3341, 'youd': 3340, 'yoru': 3339, 'yomeimon': 3338, 'yet': 3337, 'year': 3336, 'yasoukyoku': 3335, 'yam': 3334, 'yabou': 3333, 'xwing': 3332, 'xplosiv': 3331, 'xper': 3330, 'xon': 3329, 'xill': 3328, 'xii': 3327, 'xeviou': 3326, 'xenov': 3325, 'xcom': 3324, 'xbox360': 3323, 'xbox': 3322, 'xblaz': 3321, 'wwi': 3320, 'wright': 3319, 'wrestleman': 3318, 'wrestl': 3317, 'wrap': 3316, 'wra': 3315, 'would': 3314, 'worm': 3313, 'worldest': 3312, 'world': 3311, 'work': 3310, 'word': 3309, 'wood': 3308, 'wondersw': 3307, 'wond': 3306, 'wolverin': 3305, 'wolrd': 3304, 'wolfenstein': 3303, 'wolf': 3302, 'wizard': 3301, 'within': 3300, 'witchav': 3299, 'witch': 3298, 'wireless': 3297, 'wir': 3296, 'wipeout': 3295, 'winx': 3294, 'wint': 3293, 'wing': 3292, 'windwak': 3291, 'window': 3290, 'windjam': 3289, 'win': 3288, 'wimmelbild': 3287, 'wildland': 3286, 'wild': 3285, 'wilco': 3284, 'wiiu': 3283, 'wiimot': 3282, 'wif': 3281, 'whit': 3280, 'whisp': 3279, 'wheel': 3278, 'western': 3277, 'west': 3276, 'weltdiam': 3275, 'weapon': 3274, 'wayward': 3273, 'wayn': 3272, 'waterloo': 3271, 'watch': 3270, 'wat': 3269, 'wasteland': 3268, 'wasp': 3267, 'waru': 3266, 'warry': 3265, 'wario': 3264, 'warham': 3263, 'warfight': 3262, 'warf': 3261, 'warcraft': 3260, 'warband': 3259, 'war': 3258, 'want': 3257, 'wanpaku': 3256, 'wand': 3255, 'waltz': 3254, 'walk': 3253, 'wak': 3252, 'waiw': 3251, 'wack': 3250, 'vulc': 3249, 'voynich': 3248, 'voy': 3247, 'vorurteil': 3246, 'vol': 3245, 'voit': 3244, 'voisin': 3243, 'void': 3242, 'voic': 3241, 'voi': 3240, 'viv': 3239, 'vitess': 3238, 'vita2000': 3237, 'vit': 3236, 'visy': 3235, 'virtuel': 3234, 'virtu': 3233, 'virt': 3232, 'violet': 3231, 'vinyl': 3230, 'vint': 3229, 'vin': 3228, 'vilain': 3227, 'vil': 3226, 'vik': 3225, 'vii': 3224, 'vigil': 3223, 'vietnam': 3222, 'vien': 3221, 'videopac': 3220, 'videogam': 3219, 'video': 3218, 'vid': 3217, 'victor': 3216, 'vic': 3215, 'vi': 3214, 'veut': 3213, 'veterinair': 3212, 'vet': 3211, 'vest': 3210, 'vert': 3209, 'versu': 3208, 'versail': 3207, 'verrouil': 3206, 'vermachtn': 3205, 'ver': 3204, 'ventil': 3203, 'vent': 3202, 'veng': 3201, 'vehic': 3200, 'veg': 3199, 'vanguard': 3198, 'van': 3197, 'vampir': 3196, 'valv': 3195, 'valu': 3194, 'valley': 3193, 'valiset': 3192, 'vagabond': 3191, 'vacu': 3190, 'vac': 3189, 'util': 3188, 'ushua': 3187, 'ushinawaret': 3186, 'uruou': 3185, 'urb': 3184, 'upr': 3183, 'untold': 3182, 'unsolv': 3181, 'unr': 3180, 'unou': 3179, 'unlimit': 3178, 'unlik': 3177, 'unleash': 3176, 'unknown': 3175, 'universel': 3174, 'unit': 3173, 'unforgot': 3172, 'undisput': 3171, 'underworld': 3170, 'undermin': 3169, 'underground': 3168, 'underdom': 3167, 'undead': 3166, 'unchart': 3165, 'un': 3164, 'umineko': 3163, 'umbrel': 3162, 'ulyss': 3161, 'ultraleagu': 3160, 'ultr': 3159, 'ultim': 3158, 'uef': 3157, 'udraw': 3156, 'u0026': 3155, 'typ': 3154, 'tycoon': 3153, 'twist': 3152,  ...

# %% [markdown]
# Histogramme :

# %%
# Insérer votre code ici 
from collections import Counter
freq = Counter(vectorizer.vocabulary_)
plt.figure(figsize = (20,10))
plt.bar(x = pd.DataFrame(freq.most_common(15), columns = ['word', "Count"]).word.tolist(), height = pd.DataFrame(freq.most_common(15), columns = ['word', "Count"]).Count.tolist())
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# WordCloud :

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color = "black", max_words = 400,  height = 100, stopwords = stop_words)

# %%
import matplotlib.pyplot as plt 

# Générer et afficher le nuage de mots

plt.figure(figsize= (50,50)) # Initialisation d'une figure
wc.generate_from_frequencies(vectorizer.vocabulary_)           # "Calcul" du wordcloud
plt.imshow(wc) # Affichage
plt.show()
