# %% [markdown]
# # Transfert Learning: Comparatif de modèles
#
# Différents essais pour comparer différents modèles pré-entainés de Keras, en commençant sur un jeu de'échantillons réduit à 4000 et en testant avec 20000 échantillons les plus prometteurs.
#   Le modèle **EfficientNetB1** sort du lot des modèles testés, aussi bien pour son score *weighted F1 loss* que pour ses performances en temps d'exécution. Il y a cependant d'autres modèles qui n'ont pas été essayés ([keras.io/api/applications](https://keras.io/api/applications/), [awesome-image-classification](https://github.com/weiaicunzai/awesome-image-classification)).
#
#
#
# | Echantillons | Modèle de Base | Modèle Top | Epochs |    Optimizers          | Weighted-F1 | Secondes |
# |--------------|:---------------|------------|--------|------------------------|-------------|----------|
# |     4000     |    InceptionV3 |      A     |  2, 5  | Adam(1e-3), Adam(1e-4) |       0.34  |     926  |
# |      -       |           -    |      B     |  6, 3  |   -                    |       0.34  |     629  |
# |      -       |           -    |      C     |  6, 3  |   -                    |       0.36  |     658  |
# |      -       |          VGG16 |      B     |  4, 5  |   -                    |       0.43  |    5838  |
# |      -       |           -    |      C     |  4, 6  |   -                    |       0.46  |    5390  |
# |      -       |       Xception |      C     |  3, 3  |   -                    |       0.44  |    1882  |
# |      -       |           -    |      C     |  2, 4  |   -                    |       0.47  |    2011  |
# |      -       | EfficientNetB1 |      C     |  3, 3  |   -                    |       0.47  |    1419  |
# |    10000     |       Xception |      C     |  3, 4  |   -                    |       0.52  |    5278  |
# |      -       |          VGG16 |      B     |  4, 3  |   -                    |       0.47  |    8272  |
# |    20000     | EfficientNetB1 |      C     |  4, 5  |   -                    |       0.58  |    9746  |
# |      -       | EfficientNetB3 |      C     |  6, 3  |   -                    |       0.57  |   18426  |
# |      -       |       Xception |      C     |  5, 3  |   -                    |       0.53  |   11437  |
# |    40000     | EfficientNetB1 |      C     |  5, 5  |   -                    |       0.61  |   21062  |

# %%
import pandas as pd
import numpy as np
import time
import os
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

import keras
import keras.applications as kapps
import tensorflow as tf

#
# Paramétres par défaut
#
NB_ECHANTILLONS=40000
NB_CLASSES = 27 
TEST_SPLIT = 0.2
VALIDATION_SPLIT = 0.15
BATCH_SIZE = 32
EPOCHSS = [6, 10] # [epochs en mode freezed, epochs en mode unfreezed]
OPTIMIZERS = [keras.optimizers.Adam(lr=1e-3),
             keras.optimizers.Adam(lr=1e-4)]

def read_X(nb=NB_ECHANTILLONS):
    """
    Lecture de nb entrées et ajout des colonnes 'imgpath' et 'class'
    """
    def image_path(row, subdir="image_train"):
        f = "image_%d_product_%d.jpg" % (row.imageid, row.productid) 
        ff = os.path.join(os.getcwd(), "images", subdir, f)
        return ff if os.path.isfile(ff) else None
    X = pd.read_csv("X_train_update.csv")[:nb]
    y = pd.read_csv("Y_train_CVw08PX.csv").drop("Unnamed: 0", axis=1)["prdtypecode"][:nb]
    X['imgpath'] = X.apply(lambda x: image_path(x), axis=1)
    X['class'] = y.astype(str) # Needed by generator
    return X

def image_data_generator(X_train,
                         X_test,
                         img_height,
                         img_width,
                         preprocessing_function,
                         batch_size,
                         validation_split):
    """
    Générateurs d'images, elle sont augmentées pour train et validation
    Quand ils existent on utilise les preprocesseurs fournis par les modèles et
    non le paramètre rescale=1./255. Certains modèles comme EfficientNet incluent
    le preprocessing dans le modèle lui-même.
    Le générateur de test n'est pas augmenté, ni mélangé (pour garder les indices
    de classes dans l'ordre initial)
    """
    datagenerator = keras.preprocessing.image.ImageDataGenerator(
        validation_split = validation_split,
        preprocessing_function = preprocessing_function,
        rotation_range = 10,
        width_shift_range = 0.1,
        height_shift_range = 0.1,
        zoom_range = 0.1,
        brightness_range=[0.9, 1.1],
        horizontal_flip = True
    )
    traingen = datagenerator.flow_from_dataframe(
        subset = 'training', dataframe=X_train, x_col="imgpath", y_col="class",
        class_mode="sparse", target_size=(img_height, img_width), batch_size=batch_size
    )
    valgen = datagenerator.flow_from_dataframe(
        subset='validation', dataframe=X_train, x_col="imgpath", y_col="class",
        class_mode="sparse", target_size=(img_height, img_width), batch_size=batch_size
    )
    testgen = keras.preprocessing.image.ImageDataGenerator( 
        preprocessing_function = preprocessing_function).flow_from_dataframe(
        dataframe=X_test, x_col="imgpath", y_col="class",
        class_mode=None, target_size=(img_height, img_width), batch_size=batch_size,
        shuffle = False
    )

    return traingen, valgen, testgen

def plot_history(title, history):
    """
    Affiche les évolution par epoch de la perte et de l'accuracy
    """
    plt.figure(figsize=(15,3))
    plt.subplot(121)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{title}: Loss by epoch')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='right')
    plt.subplot(122)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'{title}: Accuracy by epoch')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='right')
    plt.show()

def test_model(name,
               inputshape,
               pprocfunc,
               basemodel,
               topmodel,
               basetrainable,
               epochss=EPOCHSS,
               optimizers=OPTIMIZERS):
    """
    Evalue un modèle en fonction des paramètres, le score F1-w est affiché
    """
    time0 = time.time()
    print(f"+++ {name}: Lit les échantillons")
    X = read_X()
    X = shuffle(X)
    X_train, X_test, y_train, y_test = train_test_split(X, X['class'],
                                            test_size = TEST_SPLIT,
                                            random_state = 123)
    print(f"+++ {name}: Crée les générateurs d'images")
    traingen, valgen, testgen = image_data_generator(X_train, X_test,
                                                     inputshape[0], inputshape[1],
                                                     pprocfunc,
                                                     BATCH_SIZE,
                                                     VALIDATION_SPLIT) 
    print(f"+++ {name}: Freeze des layers de base et entrainement...")
    for layer in basemodel.layers:
        layer.trainable = False
    model = keras.models.Sequential([basemodel, topmodel])
    model.compile(optimizer=optimizers[0],
              loss='sparse_categorical_crossentropy', metrics = ['accuracy'])
    callbacks = [
        keras.callbacks.EarlyStopping(monitor='val_loss', patience=1,
                                      restore_best_weights=True, verbose=1)
    ]
    history = model.fit(traingen, epochs=epochss[0],
                    steps_per_epoch = traingen.n//traingen.batch_size,
                    validation_data = valgen,
                    validation_steps = valgen.n//valgen.batch_size,
                    callbacks=callbacks)
    plot_history(f"{name} freezed", history)
    #
    print(f"+++ {name}: Defreeze les {basetrainable} derniers layers et entrainement...")
    if 0 < epochss[-1]:
        bestweights = f"{name}.bestweights.hdf5"
        if os.path.isfile(bestweights):
            os.remove(bestweights)
        for layer in basemodel.layers[-basetrainable:]:
            if not isinstance(layer, keras.layers.BatchNormalization):
                layer.trainable = True
        model.compile(optimizer=optimizers[-1],
                    loss='sparse_categorical_crossentropy', metrics = ['accuracy'])
        callbacks = [
            keras.callbacks.EarlyStopping(monitor='val_loss', patience=2,
                                          restore_best_weights=True,
                                          verbose=1),
            keras.callbacks.ModelCheckpoint(filepath=bestweights,
                                        save_weights_only=True, save_best_only=True,
                                        monitor='val_loss', mode='min')
        ]
        history = model.fit(traingen, epochs=epochss[-1],
                    steps_per_epoch = traingen.n//traingen.batch_size,
                    validation_data = valgen,
                    validation_steps = valgen.n//valgen.batch_size,
                    callbacks=callbacks)
        model.load_weights(bestweights)
        plot_history(f"{name} unfreezed", history)
    #
    print(f"+++ {name}: Prédit les classes du jeu de test...")
    softmaxout = model.predict(testgen, verbose = 1)
    labels = dict((v,k) for k,v in (traingen.class_indices).items())
    assert len(labels) == NB_CLASSES
    y_pred = [labels[i] for i in np.argmax(softmaxout, axis=1)]
    score = round(f1_score(y_test, y_pred, average = "weighted"), 4)
    duration = int(time.time()-time0)
    print(f"\n+++ {name}: Weighted F1 score = {score}  ({duration} sec)\n")

    return score

# %%
#
# Différents modèles de base pré-entrainés combinés avec des
# modèles (top) en sortie
#

topmodel_A = [
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(1024, activation='relu'),
        keras.layers.Dense(NB_CLASSES, activation='softmax')
    ]

topmodel_B = [
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(1024, activation='relu'),
        keras.layers.Dropout(rate=0.2),
        keras.layers.Dense(512, activation='relu'),
        keras.layers.Dropout(rate=0.2),
        keras.layers.Dense(NB_CLASSES, activation='softmax')
    ]

topmodel_C = [
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(1024, activation="relu"),
        keras.layers.BatchNormalization(trainable = True,axis=1),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(512, activation="relu"),
        keras.layers.BatchNormalization(trainable = True,axis=1),
        keras.layers.Dense(NB_CLASSES,activation='softmax')
    ]
 
def model_inceptionv3():
    inputshape = (150, 150, 3)
    pprocfunc = tf.keras.applications.inception_v3.preprocess_input
    basemodel = kapps.inception_v3.InceptionV3(input_shape = inputshape,
                                               include_top = False,
                                               weights = 'imagenet')
    topmodel = keras.models.Sequential(topmodel_B)
    return test_model("InceptionV3", inputshape, pprocfunc,
                      basemodel, topmodel, basetrainable=3,
                      optimizers=[keras.optimizers.RMSprop(lr=0.0001)])

def model_restnet50():
    inputshape = (224, 224, 3)
    pprocfunc = kapps.resnet50.preprocess_input
    basemodel = kapps.resnet50.ResNet50(include_top=False,
                                        weights='imagenet')
    topmodel = keras.models.Sequential(topmodel_B)
    return test_model("RestNet50", inputshape, pprocfunc,
                      basemodel, topmodel,
                      basetrainable=3)

def model_vgg16():
    inputshape = (224, 224, 3)
    pprocfunc = kapps.vgg16.preprocess_input
    basemodel = kapps. vgg16.VGG16(input_shape = inputshape,
                                   include_top = False,
                                   weights = 'imagenet')
    topmodel = keras.models.Sequential(topmodel_C)
    return test_model("VGG16", inputshape, pprocfunc,
                      basemodel, topmodel, basetrainable=4)

def model_xception():
    inputshape = (240, 240, 3)
    pprocfunc = kapps.xception.preprocess_input
    basemodel = kapps.xception.Xception(input_shape = inputshape,
                                        include_top = False,
                                        weights = 'imagenet')
    topmodel = keras.models.Sequential(topmodel_C)
    return test_model("Xception", inputshape, pprocfunc,
                      basemodel, topmodel, basetrainable=6)

def model_efficientnetb1():
    inputshape = (240, 240, 3) # Dépend du Bx
    pprocfunc = None # Inclus dans le modèle qui attend des données [..255]
    basemodel = tf.keras.applications.EfficientNetB1(input_shape = inputshape,
                                              include_top = False,
                                              # drop_connect_rate=0.4,
                                              weights = 'imagenet')
    topmodel = keras.models.Sequential(topmodel_C)
    return test_model("EfficientNetB1", inputshape, pprocfunc,
                      basemodel, topmodel, basetrainable=20)


def model_efficientnetb3():
    inputshape = (300, 300, 3) # Dépend du Bx
    pprocfunc = None # Inclus dans le modèle qui attend des données [..255]
    basemodel = tf.keras.applications.EfficientNetB3(input_shape = inputshape,
                                              include_top = False,
                                              # drop_connect_rate=0.4,
                                              weights = 'imagenet')
    topmodel = keras.models.Sequential(topmodel_C)
    return test_model("EfficientNetB3", inputshape, pprocfunc,
                      basemodel, topmodel, basetrainable=20)

# %%
model_efficientnetb1()
# Out:
# +++ EfficientNetB1: Lit les échantillons
# +++ EfficientNetB1: Crée les générateurs d'images
# Found 13600 validated image filenames belonging to 27 classes.
# Found 2400 validated image filenames belonging to 27 classes.
# Found 4000 validated image filenames.
# +++ EfficientNetB1: Freeze des layers de base et entrainement...
# Epoch 1/6
# 425/425 [==============================] - 1009s 2s/step - loss: 2.1488 - accuracy: 0.4146 - val_loss: 1.7273 - val_accuracy: 0.4925
# Epoch 2/6
# 425/425 [==============================] - 968s 2s/step - loss: 1.6698 - accuracy: 0.5118 - val_loss: 1.6177 - val_accuracy: 0.5167
# Epoch 3/6
# 425/425 [==============================] - 976s 2s/step - loss: 1.5114 - accuracy: 0.5393 - val_loss: 1.5430 - val_accuracy: 0.5467
# Epoch 4/6
# 425/425 [==============================] - ETA: 0s - loss: 1.3997 - accuracy: 0.5719Restoring model weights from the end of the best epoch.
# 425/425 [==============================] - 967s 2s/step - loss: 1.3997 - accuracy: 0.5719 - val_loss: 1.5658 - val_accuracy: 0.5400
# Epoch 00004: early stopping
# +++ EfficientNetB1: Defreeze les 20 derniers layers et entrainement...
# Epoch 1/10
# 425/425 [==============================] - 1097s 3s/step - loss: 1.2369 - accuracy: 0.6174 - val_loss: 1.4279 - val_accuracy: 0.5733
# Epoch 2/10
# 425/425 [==============================] - 1108s 3s/step - loss: 1.0809 - accuracy: 0.6630 - val_loss: 1.4110 - val_accuracy: 0.5829
# Epoch 3/10
# 425/425 [==============================] - 1115s 3s/step - loss: 0.9570 - accuracy: 0.7014 - val_loss: 1.4030 - val_accuracy: 0.5883
# Epoch 4/10
# 425/425 [==============================] - 1112s 3s/step - loss: 0.8370 - accuracy: 0.7367 - val_loss: 1.4398 - val_accuracy: 0.5871
# Epoch 5/10
# 425/425 [==============================] - ETA: 0s - loss: 0.7444 - accuracy: 0.7713Restoring model weights from the end of the best epoch.
# 425/425 [==============================] - 1102s 3s/step - loss: 0.7444 - accuracy: 0.7713 - val_loss: 1.4817 - val_accuracy: 0.5879
# Epoch 00005: early stopping
# +++ EfficientNetB1: Prédit les classes du jeu de test...
# 125/125 [==============================] - 234s 2s/step
#
# +++ EfficientNetB1: Weighted F1 score = 0.5779  (9746 sec)
# 0.5779

# %%
model_xception()
# Out:
# +++ Xception: Lit les échantillons
# +++ Xception: Crée les générateurs d'images
# Found 13600 validated image filenames belonging to 27 classes.
# Found 2400 validated image filenames belonging to 27 classes.
# Found 4000 validated image filenames.
# +++ Xception: Freeze des layers de base et entrainement...
# Epoch 1/6
# 425/425 [==============================] - 1303s 3s/step - loss: 2.2120 - accuracy: 0.3935 - val_loss: 1.7707 - val_accuracy: 0.4842
# Epoch 2/6
# 425/425 [==============================] - 1296s 3s/step - loss: 1.7606 - accuracy: 0.4724 - val_loss: 1.7179 - val_accuracy: 0.5042
# Epoch 3/6
# 425/425 [==============================] - 1289s 3s/step - loss: 1.6114 - accuracy: 0.5142 - val_loss: 1.6638 - val_accuracy: 0.5208
# Epoch 4/6
# 425/425 [==============================] - 1289s 3s/step - loss: 1.5184 - accuracy: 0.5409 - val_loss: 1.6476 - val_accuracy: 0.5154
# Epoch 5/6
# 425/425 [==============================] - ETA: 0s - loss: 1.4513 - accuracy: 0.5515Restoring model weights from the end of the best epoch.
# 425/425 [==============================] - 1291s 3s/step - loss: 1.4513 - accuracy: 0.5515 - val_loss: 1.6605 - val_accuracy: 0.5175
# Epoch 00005: early stopping
# +++ Xception: Defreeze les 6 derniers layers et entrainement...
# Epoch 1/10
# 425/425 [==============================] - 1499s 4s/step - loss: 1.5050 - accuracy: 0.5404 - val_loss: 1.5200 - val_accuracy: 0.5458
# Epoch 2/10
# 425/425 [==============================] - 1599s 4s/step - loss: 1.0990 - accuracy: 0.6589 - val_loss: 1.5338 - val_accuracy: 0.5604
# Epoch 3/10
# 425/425 [==============================] - ETA: 0s - loss: 0.8791 - accuracy: 0.7257Restoring model weights from the end of the best epoch.
# 425/425 [==============================] - 1512s 4s/step - loss: 0.8791 - accuracy: 0.7257 - val_loss: 1.5687 - val_accuracy: 0.5658
# Epoch 00003: early stopping
# +++ Xception: Prédit les classes du jeu de test...
# 125/125 [==============================] - 315s 3s/step
#
# +++ Xception: Weighted F1 score = 0.5271  (11437 sec)
# 0.5271

# %%
model_efficientnetb3()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941888/43941136 [==============================] - 95s 2us/step
# +++ EfficientNetB3: Lit les échantillons
# +++ EfficientNetB3: Crée les générateurs d'images
# Found 13600 validated image filenames belonging to 27 classes.
# Found 2400 validated image filenames belonging to 27 classes.
# Found 4000 validated image filenames.
# +++ EfficientNetB3: Freeze des layers de base et entrainement...
# Epoch 1/6
# 425/425 [==============================] - 2168s 5s/step - loss: 2.0869 - accuracy: 0.4298 - val_loss: 1.6569 - val_accuracy: 0.5138
# Epoch 2/6
# 425/425 [==============================] - 2156s 5s/step - loss: 1.5959 - accuracy: 0.5271 - val_loss: 1.5473 - val_accuracy: 0.5458
# Epoch 3/6
# 425/425 [==============================] - 2134s 5s/step - loss: 1.4506 - accuracy: 0.5610 - val_loss: 1.5183 - val_accuracy: 0.5521
# Epoch 4/6
# 425/425 [==============================] - 2135s 5s/step - loss: 1.3257 - accuracy: 0.5932 - val_loss: 1.5151 - val_accuracy: 0.5592
# Epoch 5/6
# 425/425 [==============================] - ETA: 0s - loss: 1.2555 - accuracy: 0.6137Restoring model weights from the end of the best epoch.
# 425/425 [==============================] - 2133s 5s/step - loss: 1.2555 - accuracy: 0.6137 - val_loss: 1.5350 - val_accuracy: 0.5525
# Epoch 00005: early stopping
# +++ EfficientNetB3: Defreeze les 20 derniers layers et entrainement...
# Epoch 1/10
# 425/425 [==============================] - 2396s 6s/step - loss: 1.0869 - accuracy: 0.6615 - val_loss: 1.3907 - val_accuracy: 0.5958
# Epoch 2/10
# 425/425 [==============================] - 2354s 6s/step - loss: 0.9043 - accuracy: 0.7160 - val_loss: 1.4069 - val_accuracy: 0.5904
# Epoch 3/10
# 425/425 [==============================] - ETA: 0s - loss: 0.7889 - accuracy: 0.7526Restoring model weights from the end of the best epoch.
# 425/425 [==============================] - 2352s 6s/step - loss: 0.7889 - accuracy: 0.7526 - val_loss: 1.4193 - val_accuracy: 0.5929
# Epoch 00003: early stopping
# +++ EfficientNetB3: Prédit les classes du jeu de test...
# 125/125 [==============================] - 522s 4s/step
#
# +++ EfficientNetB3: Weighted F1 score = 0.5714  (18426 sec)
# 0.5714

# %%
# 40000
model_efficientnetb1()
# Out:
# +++ EfficientNetB1: Lit les échantillons
# +++ EfficientNetB1: Crée les générateurs d'images
# Found 27200 validated image filenames belonging to 27 classes.
# Found 4800 validated image filenames belonging to 27 classes.
# Found 8000 validated image filenames.
# +++ EfficientNetB1: Freeze des layers de base et entrainement...
# Epoch 1/6
# 850/850 [==============================] - 1943s 2s/step - loss: 1.9652 - accuracy: 0.4506 - val_loss: 1.6082 - val_accuracy: 0.5217
# Epoch 2/6
# 850/850 [==============================] - 1921s 2s/step - loss: 1.5834 - accuracy: 0.5281 - val_loss: 1.5398 - val_accuracy: 0.5473
# Epoch 3/6
# 850/850 [==============================] - 1943s 2s/step - loss: 1.4790 - accuracy: 0.5505 - val_loss: 1.4852 - val_accuracy: 0.5648
# Epoch 4/6
# 850/850 [==============================] - 2023s 2s/step - loss: 1.4023 - accuracy: 0.5710 - val_loss: 1.4459 - val_accuracy: 0.5777
# Epoch 5/6
# 850/850 [==============================] - ETA: 0s - loss: 1.3390 - accuracy: 0.5903Restoring model weights from the end of the best epoch.
# 850/850 [==============================] - 1920s 2s/step - loss: 1.3390 - accuracy: 0.5903 - val_loss: 1.4649 - val_accuracy: 0.5706
# Epoch 00005: early stopping
# +++ EfficientNetB1: Defreeze les 20 derniers layers et entrainement...
# Epoch 1/10
# 850/850 [==============================] - 2160s 3s/step - loss: 1.2027 - accuracy: 0.6286 - val_loss: 1.3633 - val_accuracy: 0.5960
# Epoch 2/10
# 850/850 [==============================] - 2158s 3s/step - loss: 1.0705 - accuracy: 0.6675 - val_loss: 1.3285 - val_accuracy: 0.6135
# Epoch 3/10
# 850/850 [==============================] - 2158s 3s/step - loss: 0.9653 - accuracy: 0.6965 - val_loss: 1.3228 - val_accuracy: 0.6200
# Epoch 4/10
# 850/850 [==============================] - 2158s 3s/step - loss: 0.8600 - accuracy: 0.7288 - val_loss: 1.3419 - val_accuracy: 0.6190
# Epoch 5/10
# 850/850 [==============================] - ETA: 0s - loss: 0.7811 - accuracy: 0.7537Restoring model weights from the end of the best epoch.
# 850/850 [==============================] - 2155s 3s/step - loss: 0.7811 - accuracy: 0.7537 - val_loss: 1.3468 - val_accuracy: 0.6173
# Epoch 00005: early stopping
# +++ EfficientNetB1: Prédit les classes du jeu de test...
# 250/250 [==============================] - 462s 2s/step
#
# +++ EfficientNetB1: Weighted F1 score = 0.6107  (21062 sec)
# 0.6107
