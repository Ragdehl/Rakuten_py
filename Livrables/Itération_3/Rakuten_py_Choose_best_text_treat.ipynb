# %% [markdown]
# # Choisir le meilleur text traité

# %% [markdown]
# Ce code a comme objectif trouver le meilleur des textes traités avec NLP.

# %% [markdown]
# D'après les recherches d'Eric, le modèle LightSVC est une modèle très rapide et avec très bons résultats!

# %% [markdown]
# Nous allons tester touts les textes avec les differents traitements et choisir celui avec la meilleure performance.

# %%
import pandas as pd
# Importer la classe train_test 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize

from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

from sklearn.metrics import f1_score

# %% [markdown]
# Transformer les categories target en numeros de 0 à 26:

# %%
target = pd.read_csv(r'C:\Users\Edgar\Documents\Rakuten\Y_train_CVw08PX.csv')

y = target.prdtypecode
categories = list(set(y.to_list()))
y_trans = y
i = 0
for category in categories:
    y_trans = y_trans.replace(category,i)
    i+=1

y_trans
# Out:
# 0         4
# 1        25
# 2        20
# 3         0
# 4         6
#          ..
# 84911    17
# 84912    10
# 84913    25
# 84914    11
# 84915    23
# Name: prdtypecode, Length: 84916, dtype: int64

# %% [markdown]
# Création de la liste avec tous les X_train possibles:

# %%
import os #Miscellaneous operating system interfaces
#https://docs.python.org/3/library/os.html

#get current working directory
current_path = os.getcwd() 

#X_train path
path = current_path + r'/X_train/'

#List with the name of all training images
data_list = os.listdir(path)

# %% [markdown]
# Fonction pour calculer le numero de mots uniques:

# %%
def number_unique_words(text_series): #count unique words in Series
    words = []
    for sentence in text_series.str.split():
        for word in sentence:
            words.append(word)
            
    return len(list(set(words)))

# %% [markdown]
# Essayer chaque possibilité de X_train traité pour voir avec quel type de traitement on arrive a predire mieux:

# %%
#data_list = ['X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN_steem-DE.csv']

for data in data_list:
    
    #Importer fichier
    X = pd.read_csv(path + r'\\' + data,index_col =0).squeeze()
    unique_words = number_unique_words(X)
    
    #if unique_words > 200000:
        #print(unique_words)
        #continue
        
    train_size = 0.2
    
    print('************************')
    print('Try with', data)
    
    # Séparer le jeu de données en données d'entraînement et données test 
    X_train, X_test, y_train, y_test = train_test_split(X, y_trans, train_size=0.1 ,test_size=0.02)
    print('Unique words:', unique_words)
    
    try:
        #Transformer donnés en tensors
        tfid = TfidfVectorizer(analyzer='word',
                               tokenizer=word_tokenize,
                               max_df=0.8,
                               min_df=4,
                               #ngram_range=(1,1),
                               use_idf=True,
                               smooth_idf=True,
                               sublinear_tf=False,
                               binary=True,
                              )
        X_train_tf = tfid.fit_transform(X_train).todense()
        X_test_tf = tfid.transform(X_test).todense()
        print('Size vector X_train', X_train_tf.shape)
    
        #Train model and predict
        model = LinearSVC(penalty="l2", dual=True,C=0.5,max_iter = 1000) #values from best hyperpara from *NLP_SC
        model = model.fit(X_train_tf, y_train)
        pred = model.predict(X_test_tf)
        print('Score for ', data, ':', accuracy_score(y_test, pred))
    
    except:
        print(data, 'has too many unique words')
    print('')
# Out:
# ************************
# Try with X_train_lemma-FR.csv
# Unique words: 250363
# Size vector X_train (8491, 10352)
# Score for  X_train_lemma-FR.csv : 0.7551500882872277
#
# ************************
# Try with X_train_lemma-FR_lemma-EN.csv
# Unique words: 242904
# Size vector X_train (8491, 10276)
# Score for  X_train_lemma-FR_lemma-EN.csv : 0.7657445556209534
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE.csv
# Unique words: 236462
# Size vector X_train (8491, 10179)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE.csv : 0.7781047675103002
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR.csv
# Unique words: 210066
# Size vector X_train (8491, 8838)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR.csv : 0.7663331371394938
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN.csv
# Unique words: 205116
# Size vector X_train (8491, 8828)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN.csv : 0.7716303708063567
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE.csv
# Unique words: 202759
# Size vector X_train (8491, 8642)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE.csv : 0.7669217186580342
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR.csv
# Unique words: 202641
# Size vector X_train (8491, 8569)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR.csv : 0.7628016480282519
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN.csv
# Unique words: 202550
# Size vector X_train (8491, 8500)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN.csv : 0.7686874632136551
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv
# Unique words: 202464
# Size vector X_train (8491, 8544)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv : 0.7569158328428487
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv
# Unique words: 152707
# Size vector X_train (8491, 7645)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv : 0.7569158328428487
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv
# Unique words: 149968
# Size vector X_train (8491, 7543)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv : 0.7616244849911713
#
# ************************
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv
# Unique words: 98634
# Size vector X_train (8491, 7560)
# Score for  X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv : 0.7410241318422601
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR.csv
# Unique words: 248672
# Size vector X_train (8491, 10163)
# Score for  X_train_lemma-FR_stop_words-FR.csv : 0.7622130665097115
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR.csv
# Unique words: 194887
# Size vector X_train (8491, 9681)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR.csv : 0.7545615067686875
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR.csv
# Unique words: 189566
# Size vector X_train (8491, 9399)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR.csv : 0.7639788110653325
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR.csv
# Unique words: 122522
# Size vector X_train (8491, 9078)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR.csv : 0.7657445556209534
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN.csv
# Unique words: 118990
# Size vector X_train (8491, 9008)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN.csv : 0.7792819305473808
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN.csv
# Unique words: 118875
# Size vector X_train (8491, 8910)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN.csv : 0.7469099470276633
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE.csv
# Unique words: 118766
# Size vector X_train (8491, 8894)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE.csv : 0.7680988816951148
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE.csv
# Unique words: 118520
# Size vector X_train (8491, 8817)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE.csv : 0.757504414361389
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR.csv
# Unique words: 95105
# Size vector X_train (8491, 7398)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR.csv : 0.7498528546203649
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN.csv
# Unique words: 90445
# Size vector X_train (8491, 7232)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN.csv : 0.7563272513243084
#
# ************************
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN_steem-DE.csv
# Unique words: 88258
# Size vector X_train (8491, 7054)
# Score for  X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN_steem-DE.csv : 0.7628016480282519
#
# ************************
# Try with X_train_steem-FR.csv
# Unique words: 222055
# Size vector X_train (8491, 9113)
# Score for  X_train_steem-FR.csv : 0.7616244849911713
#
# ************************
# Try with X_train_steem-FR_steem-EN.csv
# Unique words: 211088
# Size vector X_train (8491, 8795)
# Score for  X_train_steem-FR_steem-EN.csv : 0.7492642731018246
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE.csv
# Unique words: 202743
# Size vector X_train (8491, 8873)
# Score for  X_train_steem-FR_steem-EN_steem-DE.csv : 0.7651559741024132
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR.csv
# Unique words: 203332
# Size vector X_train (8491, 8812)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR.csv : 0.7628016480282519
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN.csv
# Unique words: 203329
# Size vector X_train (8491, 8858)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN.csv : 0.772218952324897
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE.csv
# Unique words: 203240
# Size vector X_train (8491, 8770)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE.csv : 0.7680988816951148
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR.csv
# Unique words: 203165
# Size vector X_train (8491, 8849)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR.csv : 0.7504414361389052
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN.csv
# Unique words: 203087
# Size vector X_train (8491, 8719)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN.csv : 0.746321365509123
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv
# Unique words: 203033
# Size vector X_train (8491, 8858)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv : 0.757504414361389
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv
# Unique words: 153168
# Size vector X_train (8491, 7815)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv : 0.7516185991759858
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv
# Unique words: 150407
# Size vector X_train (8491, 7705)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv : 0.7586815773984696
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv
# Unique words: 98911
# Size vector X_train (8491, 7561)
# Score for  X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv : 0.7651559741024132
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR.csv
# Unique words: 202399
# Size vector X_train (8491, 8728)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR.csv : 0.7616244849911713
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN.csv
# Unique words: 202299
# Size vector X_train (8491, 8720)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN.csv : 0.7669217186580342
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv
# Unique words: 202204
# Size vector X_train (8491, 8732)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv : 0.761035903472631
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv
# Unique words: 152205
# Size vector X_train (8491, 7769)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv : 0.7516185991759858
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv
# Unique words: 149474
# Size vector X_train (8491, 7650)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv : 0.7563272513243084
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv
# Unique words: 98176
# Size vector X_train (8491, 7518)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv : 0.7669217186580342
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR.csv
# Unique words: 97213
# Size vector X_train (8491, 7644)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR.csv : 0.7439670394349618
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR_lemma-EN.csv
# Unique words: 96625
# Size vector X_train (8491, 7557)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR_lemma-EN.csv : 0.7510300176574456
#
# ************************
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR_lemma-EN_lemma-DE.csv
# Unique words: 96521
# Size vector X_train (8491, 7631)
# Score for  X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR_lemma-EN_lemma-DE.csv : 0.7680988816951148

# %%
#data_list = ['X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN_steem-DE.csv']

unique_words_list = ['']
score_list = ['']
data_name_list = ['']

for data in data_list:
    
    #Importer fichier
    X = pd.read_csv(path + r'\\' + data,index_col =0).squeeze()
    
    print('**************************************************************************')
    unique_words = number_unique_words(X)
    print('Unique words:', unique_words)
    print('Try with', data)
    
    #if unique_words > 200000:
        #print(unique_words)
        #continue
    
    #My RAM is not enough to calculate with full data size. Let's split the data in half
    X1 = X.loc[:X.size/2]
    X2 = X.loc[X.size/2 + 1:]
    X_list = [X1,X2]
    y1 = y_trans.loc[:X.size/2]
    y2 = y_trans.loc[X.size/2 + 1:]
    y_list = [y1,y2]
    split = 0
    sum_score = 0
    
    #Train model with each data split
    for X,y in zip(X_list,y_list):
        print('')
        print('Split:',split + 1)
        
        # Séparer le jeu de données en données d'entraînement et données test 
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

        try:#if too many unique words it can lead to error due to not enogh RAM!
            #Transform data in tensors
            tfid = TfidfVectorizer(analyzer='word',
                                   tokenizer=word_tokenize,
                                   max_df=0.8,
                                   min_df=4,
                                   #ngram_range=(1,1),
                                   use_idf=True,
                                   smooth_idf=True,
                                   sublinear_tf=False,
                                   binary=True,
                                  )
            X_train_tf = tfid.fit_transform(X_train).todense()
            X_test_tf = tfid.transform(X_test).todense()
            print('Size vector X_train', X_train_tf.shape)

            #Train model and predict
            model = LinearSVC(penalty="l2", dual=True,C=0.5,max_iter = 1000) #values from best hyperpara from *NLP_SC
            model = model.fit(X_train_tf, y_train)
            pred = model.predict(X_test_tf)
            score = f1_score(y_test, pred, average='weighted')
            print('Score for split', split, ':', round(score,2))
            
            sum_score += score
            split += 1

        except:
            print(data, 'has too many unique words')
    
    print('')
    print('************************')
    mean_score = round(sum_score/split,2)
    print('*    Mean score', mean_score,'  *')
    print('************************')
    print('')
    
    unique_words_list.append(unique_words)
    score_list.append(score)
    data_name_list.append(data)
# Out:
# **************************************************************************
# Unique words: 250363
# Try with X_train_lemma-FR.csv
#
# Split: 1
# Size vector X_train (33967, 25050)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 24744)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 242904
# Try with X_train_lemma-FR_lemma-EN.csv
#
# Split: 1
# Size vector X_train (33967, 24326)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 24237)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 236462
# Try with X_train_lemma-FR_lemma-EN_lemma-DE.csv
#
# Split: 1
# Size vector X_train (33967, 24276)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 24140)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 210066
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR.csv
#
# Split: 1
# Size vector X_train (33967, 20454)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 20415)
# Score for split 1 : 0.82
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 205116
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN.csv
#
# Split: 1
# Size vector X_train (33967, 20063)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19923)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202759
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE.csv
#
# Split: 1
# Size vector X_train (33967, 19750)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19527)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202641
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR.csv
#
# Split: 1
# Size vector X_train (33967, 19643)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19577)
# Score for split 1 : 0.82
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202550
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN.csv
#
# Split: 1
# Size vector X_train (33967, 19755)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19401)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202464
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv
#
# Split: 1
# Size vector X_train (33967, 19681)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19394)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 152707
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv
#
# Split: 1
# Size vector X_train (33967, 17043)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 16819)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 149968
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv
#
# Split: 1
# Size vector X_train (33967, 16506)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 16424)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 98634
# Try with X_train_lemma-FR_lemma-EN_lemma-DE_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv
#
# Split: 1
# Size vector X_train (33967, 15990)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 15768)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 248672
# Try with X_train_lemma-FR_stop_words-FR.csv
#
# Split: 1
# Size vector X_train (33967, 24934)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 24691)
# Score for split 1 : 0.82
#
# ************************
# *    Mean score 0.82   *
# ************************
#
# **************************************************************************
# Unique words: 194887
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR.csv
#
# Split: 1
# Size vector X_train (33967, 22368)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 22105)
# Score for split 1 : 0.82
#
# ************************
# *    Mean score 0.82   *
# ************************
#
# **************************************************************************
# Unique words: 189566
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR.csv
#
# Split: 1
# Size vector X_train (33967, 21752)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 21563)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.82   *
# ************************
#
# **************************************************************************
# Unique words: 122522
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR.csv
#
# Split: 1
# Size vector X_train (33967, 20545)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 20278)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 118990
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN.csv
#
# Split: 1
# Size vector X_train (33967, 19801)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19740)
# Score for split 1 : 0.82
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 118875
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN.csv
#
# Split: 1
# Size vector X_train (33967, 19752)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 19628)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 118766
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE.csv
#
# Split: 1
# Size vector X_train (33967, 19628)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19643)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 118520
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE.csv
#
# Split: 1
# Size vector X_train (33967, 19556)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19560)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 95105
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR.csv
#
# Split: 1
# Size vector X_train (33967, 15604)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 15325)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 90445
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN.csv
#
# Split: 1
# Size vector X_train (33967, 14895)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 14846)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 88258
# Try with X_train_lemma-FR_stop_words-FR_no_num-FR_remove_accents-FR_no_special-FR_lemma-EN_stop_words-EN_stop_words-DE_lemma-DE_steem-FR_steem-EN_steem-DE.csv
#
# Split: 1
# Size vector X_train (33967, 14634)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 14472)
# Score for split 1 : 0.8
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 222055
# Try with X_train_steem-FR.csv
#
# Split: 1
# Size vector X_train (33967, 21267)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 20969)
# Score for split 1 : 0.82
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 211088
# Try with X_train_steem-FR_steem-EN.csv
#
# Split: 1
# Size vector X_train (33967, 20006)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 20044)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202743
# Try with X_train_steem-FR_steem-EN_steem-DE.csv
#
# Split: 1
# Size vector X_train (33967, 19900)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19672)
# Score for split 1 : 0.82
#
# ************************
# *    Mean score 0.82   *
# ************************
#
# **************************************************************************
# Unique words: 203332
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR.csv
#
# Split: 1
# Size vector X_train (33967, 20066)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 19869)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 203329
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN.csv
#
# Split: 1
# Size vector X_train (33967, 20058)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19817)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 203240
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE.csv
#
# Split: 1
# Size vector X_train (33967, 20167)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 19864)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 203165
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR.csv
#
# Split: 1
# Size vector X_train (33967, 20054)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 19639)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 203087
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN.csv
#
# Split: 1
# Size vector X_train (33967, 19899)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 19655)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 203033
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv
#
# Split: 1
# Size vector X_train (33967, 19924)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19618)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 153168
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv
#
# Split: 1
# Size vector X_train (33967, 17295)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 17000)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 150407
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv
#
# Split: 1
# Size vector X_train (33967, 16833)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 16624)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 98911
# Try with X_train_steem-FR_steem-EN_steem-DE_lemma-FR_lemma-EN_lemma-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv
#
# Split: 1
# Size vector X_train (33967, 16173)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 16072)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202399
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR.csv
#
# Split: 1
# Size vector X_train (33967, 19893)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 19674)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202299
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN.csv
#
# Split: 1
# Size vector X_train (33967, 19821)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 19548)
# Score for split 1 : 0.8
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 202204
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE.csv
#
# Split: 1
# Size vector X_train (33967, 19760)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 19370)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 152205
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR.csv
#
# Split: 1
# Size vector X_train (33967, 17140)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 16886)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 149474
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR.csv
#
# Split: 1
# Size vector X_train (33967, 16586)
# Score for split 0 : 0.82
#
# Split: 2
# Size vector X_train (33965, 16406)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 98176
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR.csv
#
# Split: 1
# Size vector X_train (33967, 16005)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 15952)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 97213
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR.csv
#
# Split: 1
# Size vector X_train (33967, 16096)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 15914)
# Score for split 1 : 0.8
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 96625
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR_lemma-EN.csv
#
# Split: 1
# Size vector X_train (33967, 16004)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 15891)
# Score for split 1 : 0.81
#
# ************************
# *    Mean score 0.81   *
# ************************
#
# **************************************************************************
# Unique words: 96521
# Try with X_train_steem-FR_steem-EN_steem-DE_stop_words-FR_stop_words-EN_stop_words-DE_no_num-FR_remove_accents-FR_no_special-FR_lemma-FR_lemma-EN_lemma-DE.csv
#
# Split: 1
# Size vector X_train (33967, 16006)
# Score for split 0 : 0.81
#
# Split: 2
# Size vector X_train (33965, 15860)
# Score for split 1 : 0.8
#
# ************************
# *    Mean score 0.81   *
# ************************

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Il parait que peu importe le traitement du text, l'algoritme SVC a à peu près le même score à chaque fois.

# %% [markdown]
# On peut donc se baser sur le critère de la taille des donnes pour notre choix de texte traité.
# On va donc choisir celui avec une taille plus petite afin d'accelerer les calcules!
