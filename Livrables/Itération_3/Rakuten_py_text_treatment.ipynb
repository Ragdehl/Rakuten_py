# %% [markdown]
# # Text Treatment

# %% [markdown]
# L'objectif de ce notebook est de génerer plusieurs X_train avec des traitement de texte differents. Ces textes vont être utilisés afin de savoir quel est le meilleur traitement.

# %%
import pandas as pd
from datetime import datetime
import unidecode
import re   

#Création fonctions de netoyage de texte
import spacy #https://spacy.io/usage  ----> POUR INSTALLER
#https://www.stat4decision.com/fr/traitement-langage-naturel-francais-tal-nlp/

from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize

# %%
#importer les données texte

pd.set_option('display.max_rows', 500)
df_X = pd.read_csv(r'C:\Users\Edgar\Documents\Rakuten\X_train_update.csv',index_col =0)
df_X.head(20)
# Out:
#                                           designation  \
# 0   Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1   Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2   Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3   Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                                La Guerre Des Tuques
# 5   Afrique Contemporaine N° 212 Hiver 2004 - Doss...
# 6          Christof E: Bildungsprozessen Auf Der Spur
# 7   Conquérant Sept Cahier Couverture Polypro 240 ...
# 8           Puzzle Scooby-Doo Avec Poster 2x35 Pieces
# 9   Tente Pliante V3s5-Pro Pvc Blanc - 3 X 4m50 - ...
# 10            Eames Inspired Sxw Chair - Pink - Black
# 11  Fauteuil Chesterfield Brenton 100% Cuir De Buf...
# 12  Peaceable Kingdom Wheres Bear? The Hide And Fi...
# 13               Paire De Voilages Imprimés Fantaisie
# 14  Matelas Mémoire De Forme 180x200 X 20 Cm Très ...
# 15       Zenith Pince Agrafeuse 591 N°10 Coloris Noir
# 16  Walter Scott Oeuvres Complètes Tomes 3456 10 E...
# 17                Mod Podge Dishwasher Safe Gloss 8oz
# 18  Power Rangers Rouge Force Mystic Figurine Tran...
# 19  Monde Illustre (Le) N° 3083 Du 20/01/1917 - L'...
#
#                                           description   productid     imageid
# 0                                                 NaN  3804725264  1263597046
# 1                                                 NaN   436067568  1008141237
# 2   PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                 NaN    50418756   457047496
# 4   Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
# 5                                                 NaN     5862738   393356830
# 6                                                 NaN    91920807   907794536
# 7   CONQUERANT CLASSIQUE Cahier 240 x 320 mm seyès...   344240059   999581347
# 8                                                 NaN  4239126071  1325918866
# 9   Tente pliante V3S5 Pro PVC 500 gr/m² - 3 x 4m5...  3793572222  1245644185
# 10  The timeless DSW seat can now be paired with m...  1915836983  1111840281
# 11  Canapé et fauteuil chesterfield en cuir antiqu...  4127967621  1295816984
# 12  pCan my 2-year-old play a game? Yes Each game ...  3287127001  1204199842
# 13  Paire de voilages droits fantaisie qui mettra ...  1882164320  1109088140
# 14  MATELAS:<br />Â· Accueil : Ferme .<br />Â· Sou...  4108914287  1292441752
# 15  Pince agrafeuse 591 N°10. Capot en ABS. Dispos...  3718150116  1237257586
# 16                                                NaN  3735707499  1239242410
# 17                                                NaN  2666371748  1156191369
# 18                                                NaN    91015572   857195931
# 19                                                NaN   570628142  1027257229

# %% [markdown]
# On va mettre designation et description dans une même string:

# %%
#Merger les colones texte en une seule
X = df_X.designation.astype(str) + ' ' + df_X.description.astype(str)

#Numero de lignes du texte
size_X = X.size
print('Num lignes totale:', size_X)

X.head(20)
# Out:
# Num lignes totale: 84916
# 0     Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1     Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2     Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3     Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4     La Guerre Des Tuques Luc a des id&eacute;es de...
# 5     Afrique Contemporaine N° 212 Hiver 2004 - Doss...
# 6        Christof E: Bildungsprozessen Auf Der Spur nan
# 7     Conquérant Sept Cahier Couverture Polypro 240 ...
# 8         Puzzle Scooby-Doo Avec Poster 2x35 Pieces nan
# 9     Tente Pliante V3s5-Pro Pvc Blanc - 3 X 4m50 - ...
# 10    Eames Inspired Sxw Chair - Pink - Black The ti...
# 11    Fauteuil Chesterfield Brenton 100% Cuir De Buf...
# 12    Peaceable Kingdom Wheres Bear? The Hide And Fi...
# 13    Paire De Voilages Imprimés Fantaisie Paire de ...
# 14    Matelas Mémoire De Forme 180x200 X 20 Cm Très ...
# 15    Zenith Pince Agrafeuse 591 N°10 Coloris Noir P...
# 16    Walter Scott Oeuvres Complètes Tomes 3456 10 E...
# 17              Mod Podge Dishwasher Safe Gloss 8oz nan
# 18    Power Rangers Rouge Force Mystic Figurine Tran...
# 19    Monde Illustre (Le) N° 3083 Du 20/01/1917 - L'...
# dtype: object

# %% [markdown]
# Definition des differentes fonctions à utiliser pour le traitement de texte:

# %%
def tokeniser_spacy(sentence,language): #Tokenisation par phrases
    
    langue = {'french':'fr_core_news_sm',
          'german':'de_core_news_sm',
          'english':'en_core_web_sm'}
    
    #nlp = spacy.load(langue[language])
    # Tokeniser la phrase
    tokens = nlp(sentence)
    # Retourner le texte coupé par mots(token)
    return [token for token in tokens]

def tokeniser_nltk(sentence,language): #Tokenisation par phrases
    
    tokens = word_tokenize(text, language=language)

    # Retourner le texte coupé par mots(token)
    return [token for token in tokens]

def language_(language):
    langue = {'fr':'french',
             'de':'german',
             'en':'english'}
    return langue[language]

def stop_words(sentence,language): #Enleve stop words per phrase
    clean_words = ''
    stop_words =stopwords.words(language)
    tokens = tokeniser_spacy(sentence,language)
    for token in tokens:
        if token.text not in stop_words:
            clean_words += token.text + ' '
    return clean_words

def number_unique_words(text_series): #count unique words in Series
    words = []
    for sentence in text_series.str.split():
        for word in sentence:
            words.append(word)
            
    return len(list(set(words)))

def remove_accents(sentece,language): #removes accents
    #language is not used in this function, but needs to be added on the definition as the rest
    try:
        text = unidecode.unidecode(sentece)
    except:
        pass
    return text

def steem(sentence,language): #Steeming
    steemed = ''
    tokens = tokeniser_spacy(sentence,language)
    stemmer = SnowballStemmer(language=language)
    
    for token in tokens:
        steemed += stemmer.stem(token.text) +' '
    return steemed

def lemma(sentence,language): #Lemmatizer
    lemma = ''
    tokens = tokeniser_spacy(sentence,language)
    
    for token in tokens:
        lemma += token.lemma_ + ' '
    return lemma

def no_num(sentence,language): #delete numbers
    #language is not used in this function, but needs to be added on the definition as the rest
    return ''.join([word for word in sentence if not word.isdigit()])

def no_special(sentence,language): #delete special characters
    #language is not used in this function, but needs to be added on the definition as the rest
    return re.sub(r"[^a-zA-Z0-9]+", ' ', sentence)

# %% [markdown]
# Fonction qui va génerer les differents combinations de traitement de texte:

# %%
# Ce code divise le dataframe en batchs afin de voir l'avancement du traitement à chaque fin de batch

def treat_text(text_series,text_treat_funct,language,batch,old_treatments=''):
    
    treatments = '_' + text_treat_funct.__name__ + '-' + language.upper()
    language = language_(language)
    
    langue = {'french':'fr_core_news_sm',
              'german':'de_core_news_sm',
              'english':'en_core_web_sm'}
    
    global nlp
    nlp = spacy.load(langue[language])
    
    print('************************************************')
    print('')
    print(text_treat_funct.__name__.upper(),language.upper())
    print('')
    print("Treatment Start Time =", datetime.now().strftime("%H:%M:%S"))
    print("Number of unique words at start =", number_unique_words(text_series))
    #print('Type of function:', text_treat_funct.__name__)
    #print('Treatment language choosen:', language)
    print('Number of batch:', batch)
    
    size = text_series.size
    treated_text = pd.Series()
    text = text_series.str.lower()
    
    #treat batches
    for i in range(batch):
        treated_batch = text[int(size/batch) * i:int(size/batch) * (i + 1)].apply(lambda cell: text_treat_funct(cell,language))
        treated_text = pd.concat([treated_text,treated_batch])
        
        treated_text.to_csv(r'C:\Users\Edgar\Documents\Rakuten\batches\X_train' + old_treatments + treatments + '_batch-' + str(i) + '.csv') 
        
        print('Treatment Batch', i, 'from', batch ,'; Time =', datetime.now().strftime("%H:%M:%S"))
    
    #tret last batch
    treated_batch = text[int(size/batch) * (i + 1):size].apply(lambda cell: text_treat_funct(cell,language))
    treated_text = pd.concat([treated_text,treated_batch])
    
    treated_text.to_csv('X_train' + old_treatments + treatments + '.csv') 
    
    print("Number of unique words at end =", number_unique_words(treated_text))
    print('')
    
    return treated_text, old_treatments + treatments

#X_test = X[:23]
#treat_text(X_test,no_special,'french',7)

# %% [markdown]
# Cette suite de lignes génere les differentes combinations de textes traités:

# %%
batch = 5

X_treated, treatments = treat_text(X,lemma,'fr',batch)
X_treated, treatments = treat_text(X_treated,stop_words,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,no_num,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,remove_accents,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,no_special,'fr',batch,treatments)

X_treated, treatments = treat_text(X_treated,lemma,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,stop_words,'en',batch,treatments)

X_treated, treatments = treat_text(X_treated,stop_words,'de',batch,treatments)
X_treated, treatments = treat_text(X_treated,lemma,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,steem,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,steem,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,steem,'de',batch,treatments)
# Out:
# ************************************************
#
# LEMMA FRENCH
#
# Treatment Start Time = 18:03:19
# Number of unique words at start = 407222
# Number of batch: 5
# <ipython-input-257-8d124fc37cf0>:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   treated_text = pd.Series()
# Treatment Batch 0 from 5 ; Time = 18:10:11
# Treatment Batch 1 from 5 ; Time = 18:16:23
# Treatment Batch 2 from 5 ; Time = 18:22:26
# Treatment Batch 3 from 5 ; Time = 18:28:25
# Treatment Batch 4 from 5 ; Time = 18:34:24
# Number of unique words at end = 250363
#
# ************************************************
#
# STOP_WORDS FRENCH
#
# Treatment Start Time = 18:34:29
# Number of unique words at start = 250363
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 18:41:33
# Treatment Batch 1 from 5 ; Time = 18:47:56
# Treatment Batch 2 from 5 ; Time = 18:54:05
# Treatment Batch 3 from 5 ; Time = 19:00:13
# Treatment Batch 4 from 5 ; Time = 19:06:18
# Number of unique words at end = 248672
#
# ************************************************
#
# NO_NUM FRENCH
#
# Treatment Start Time = 19:06:22
# Number of unique words at start = 248672
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 19:06:26
# Treatment Batch 1 from 5 ; Time = 19:06:27
# Treatment Batch 2 from 5 ; Time = 19:06:29
# Treatment Batch 3 from 5 ; Time = 19:06:30
# Treatment Batch 4 from 5 ; Time = 19:06:32
# Number of unique words at end = 194887
#
# ************************************************
#
# REMOVE_ACCENTS FRENCH
#
# Treatment Start Time = 19:06:37
# Number of unique words at start = 194887
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 19:06:42
# Treatment Batch 1 from 5 ; Time = 19:06:46
# Treatment Batch 2 from 5 ; Time = 19:06:50
# Treatment Batch 3 from 5 ; Time = 19:06:54
# Treatment Batch 4 from 5 ; Time = 19:06:58
# Number of unique words at end = 189566
#
# ************************************************
#
# NO_SPECIAL FRENCH
#
# Treatment Start Time = 19:07:02
# Number of unique words at start = 189566
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 19:07:05
# Treatment Batch 1 from 5 ; Time = 19:07:05
# Treatment Batch 2 from 5 ; Time = 19:07:06
# Treatment Batch 3 from 5 ; Time = 19:07:08
# Treatment Batch 4 from 5 ; Time = 19:07:09
# Number of unique words at end = 122522
#
# ************************************************
#
# LEMMA ENGLISH
#
# Treatment Start Time = 19:07:13
# Number of unique words at start = 122522
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 19:11:35
# Treatment Batch 1 from 5 ; Time = 19:15:52
# Treatment Batch 2 from 5 ; Time = 19:20:06
# Treatment Batch 3 from 5 ; Time = 19:24:23
# Treatment Batch 4 from 5 ; Time = 19:28:38
# Number of unique words at end = 118990
#
# ************************************************
#
# STOP_WORDS ENGLISH
#
# Treatment Start Time = 19:28:41
# Number of unique words at start = 118990
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 19:33:10
# Treatment Batch 1 from 5 ; Time = 19:37:34
# Treatment Batch 2 from 5 ; Time = 19:41:54
# Treatment Batch 3 from 5 ; Time = 19:46:17
# Treatment Batch 4 from 5 ; Time = 19:50:41
# Number of unique words at end = 118875
#
# ************************************************
#
# STOP_WORDS GERMAN
#
# Treatment Start Time = 19:50:45
# Number of unique words at start = 118875
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 19:55:02
# Treatment Batch 1 from 5 ; Time = 19:59:18
# Treatment Batch 2 from 5 ; Time = 20:03:29
# Treatment Batch 3 from 5 ; Time = 20:07:39
# Treatment Batch 4 from 5 ; Time = 20:11:50
# Number of unique words at end = 118766
#
# ************************************************
#
# LEMMA GERMAN
#
# Treatment Start Time = 20:11:54
# Number of unique words at start = 118766
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 20:16:01
# Treatment Batch 1 from 5 ; Time = 20:20:07
# Treatment Batch 2 from 5 ; Time = 20:24:05
# Treatment Batch 3 from 5 ; Time = 20:28:02
# Treatment Batch 4 from 5 ; Time = 20:31:59
# Number of unique words at end = 118520
#
# ************************************************
#
# STEEM FRENCH
#
# Treatment Start Time = 20:32:03
# Number of unique words at start = 118520
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 20:37:31
# Treatment Batch 1 from 5 ; Time = 20:42:29
# Treatment Batch 2 from 5 ; Time = 20:47:15
# Treatment Batch 3 from 5 ; Time = 20:51:58
# Treatment Batch 4 from 5 ; Time = 20:56:40
# Number of unique words at end = 95105
#
# ************************************************
#
# STEEM ENGLISH
#
# Treatment Start Time = 20:56:44
# Number of unique words at start = 95105
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 21:01:05
# Treatment Batch 1 from 5 ; Time = 21:05:23
# Treatment Batch 2 from 5 ; Time = 21:09:39
# Treatment Batch 3 from 5 ; Time = 21:13:55
# Treatment Batch 4 from 5 ; Time = 21:18:12
# Number of unique words at end = 90445
#
# ************************************************
#
# STEEM GERMAN
#
# Treatment Start Time = 21:18:16
# Number of unique words at start = 90445
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 21:22:28
# Treatment Batch 1 from 5 ; Time = 21:26:37
# Treatment Batch 2 from 5 ; Time = 21:30:43
# Treatment Batch 3 from 5 ; Time = 21:34:50
# Treatment Batch 4 from 5 ; Time = 21:38:57
# Number of unique words at end = 88258

# %% [markdown]
# Encore d'autres combinations:

# %%
batch = 5

X_treated, treatments = treat_text(X,steem,'fr',batch)
X_treated, treatments = treat_text(X_treated,steem,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,steem,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,stop_words,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,stop_words,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,stop_words,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,no_num,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,remove_accents,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,no_special,'fr',batch,treatments)

X_treated, treatments = treat_text(X_treated,lemma,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,lemma,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,lemma,'de',batch,treatments)
# Out:
# ************************************************
#
# STEEM FRENCH
#
# Treatment Start Time = 21:39:00
# Number of unique words at start = 407222
# Number of batch: 5
# <ipython-input-257-8d124fc37cf0>:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   treated_text = pd.Series()
# Treatment Batch 0 from 5 ; Time = 21:46:49
# Treatment Batch 1 from 5 ; Time = 21:53:57
# Treatment Batch 2 from 5 ; Time = 22:00:42
# Treatment Batch 3 from 5 ; Time = 22:07:22
# Treatment Batch 4 from 5 ; Time = 22:14:04
# Number of unique words at end = 222055
#
# ************************************************
#
# STEEM ENGLISH
#
# Treatment Start Time = 22:14:08
# Number of unique words at start = 222055
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 22:20:04
# Treatment Batch 1 from 5 ; Time = 22:25:57
# Treatment Batch 2 from 5 ; Time = 22:31:43
# Treatment Batch 3 from 5 ; Time = 22:37:32
# Treatment Batch 4 from 5 ; Time = 22:43:20
# Number of unique words at end = 211088
#
# ************************************************
#
# STEEM GERMAN
#
# Treatment Start Time = 22:43:25
# Number of unique words at start = 211088
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 22:49:09
# Treatment Batch 1 from 5 ; Time = 22:54:49
# Treatment Batch 2 from 5 ; Time = 23:00:24
# Treatment Batch 3 from 5 ; Time = 23:06:05
# Treatment Batch 4 from 5 ; Time = 23:11:53
# Number of unique words at end = 202743
#
# ************************************************
#
# STOP_WORDS FRENCH
#
# Treatment Start Time = 23:11:58
# Number of unique words at start = 202743
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 23:19:06
# Treatment Batch 1 from 5 ; Time = 23:25:50
# Treatment Batch 2 from 5 ; Time = 23:32:31
# Treatment Batch 3 from 5 ; Time = 23:38:38
# Treatment Batch 4 from 5 ; Time = 23:44:45
# Number of unique words at end = 202399
#
# ************************************************
#
# STOP_WORDS ENGLISH
#
# Treatment Start Time = 23:44:49
# Number of unique words at start = 202399
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 23:49:55
# Treatment Batch 1 from 5 ; Time = 23:54:59
# Treatment Batch 2 from 5 ; Time = 23:59:58
# Treatment Batch 3 from 5 ; Time = 00:04:57
# Treatment Batch 4 from 5 ; Time = 00:09:58
# Number of unique words at end = 202299
#
# ************************************************
#
# STOP_WORDS GERMAN
#
# Treatment Start Time = 00:10:02
# Number of unique words at start = 202299
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 00:14:59
# Treatment Batch 1 from 5 ; Time = 00:19:54
# Treatment Batch 2 from 5 ; Time = 00:24:43
# Treatment Batch 3 from 5 ; Time = 00:29:36
# Treatment Batch 4 from 5 ; Time = 00:34:29
# Number of unique words at end = 202204
#
# ************************************************
#
# NO_NUM FRENCH
#
# Treatment Start Time = 00:34:33
# Number of unique words at start = 202204
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 00:34:37
# Treatment Batch 1 from 5 ; Time = 00:34:38
# Treatment Batch 2 from 5 ; Time = 00:34:39
# Treatment Batch 3 from 5 ; Time = 00:34:41
# Treatment Batch 4 from 5 ; Time = 00:34:42
# Number of unique words at end = 152205
#
# ************************************************
#
# REMOVE_ACCENTS FRENCH
#
# Treatment Start Time = 00:34:46
# Number of unique words at start = 152205
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 00:34:52
# Treatment Batch 1 from 5 ; Time = 00:34:55
# Treatment Batch 2 from 5 ; Time = 00:34:58
# Treatment Batch 3 from 5 ; Time = 00:35:01
# Treatment Batch 4 from 5 ; Time = 00:35:05
# Number of unique words at end = 149474
#
# ************************************************
#
# NO_SPECIAL FRENCH
#
# Treatment Start Time = 00:35:09
# Number of unique words at start = 149474
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 00:35:11
# Treatment Batch 1 from 5 ; Time = 00:35:12
# Treatment Batch 2 from 5 ; Time = 00:35:13
# Treatment Batch 3 from 5 ; Time = 00:35:14
# Treatment Batch 4 from 5 ; Time = 00:35:15
# Number of unique words at end = 98176
#
# ************************************************
#
# LEMMA FRENCH
#
# Treatment Start Time = 00:35:19
# Number of unique words at start = 98176
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 00:40:25
# Treatment Batch 1 from 5 ; Time = 00:44:55
# Treatment Batch 2 from 5 ; Time = 00:49:23
# Treatment Batch 3 from 5 ; Time = 00:53:46
# Treatment Batch 4 from 5 ; Time = 00:58:15
# Number of unique words at end = 97213
#
# ************************************************
#
# LEMMA ENGLISH
#
# Treatment Start Time = 00:58:19
# Number of unique words at start = 97213
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 01:02:36
# Treatment Batch 1 from 5 ; Time = 01:06:53
# Treatment Batch 2 from 5 ; Time = 01:11:06
# Treatment Batch 3 from 5 ; Time = 01:15:27
# Treatment Batch 4 from 5 ; Time = 01:19:51
# Number of unique words at end = 96625
#
# ************************************************
#
# LEMMA GERMAN
#
# Treatment Start Time = 01:19:55
# Number of unique words at start = 96625
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 01:24:17
# Treatment Batch 1 from 5 ; Time = 01:28:58
# Treatment Batch 2 from 5 ; Time = 01:33:20
# Treatment Batch 3 from 5 ; Time = 01:37:30
# Treatment Batch 4 from 5 ; Time = 01:41:34
# Number of unique words at end = 96521

# %% [markdown]
# Et encore:

# %%
batch = 5

X_treated, treatments = treat_text(X,steem,'fr',batch)
X_treated, treatments = treat_text(X_treated,steem,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,steem,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,lemma,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,lemma,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,lemma,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,stop_words,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,stop_words,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,stop_words,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,no_num,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,remove_accents,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,no_special,'fr',batch,treatments)
# Out:
# ************************************************
#
# STEEM FRENCH
#
# Treatment Start Time = 01:41:38
# Number of unique words at start = 407222
# Number of batch: 5
# <ipython-input-257-8d124fc37cf0>:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   treated_text = pd.Series()
# Treatment Batch 0 from 5 ; Time = 01:50:07
# Treatment Batch 1 from 5 ; Time = 01:57:17
# Treatment Batch 2 from 5 ; Time = 02:04:07
# Treatment Batch 3 from 5 ; Time = 02:10:56
# Treatment Batch 4 from 5 ; Time = 02:17:42
# Number of unique words at end = 222055
#
# ************************************************
#
# STEEM ENGLISH
#
# Treatment Start Time = 02:17:47
# Number of unique words at start = 222055
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 02:23:48
# Treatment Batch 1 from 5 ; Time = 02:29:44
# Treatment Batch 2 from 5 ; Time = 02:35:35
# Treatment Batch 3 from 5 ; Time = 02:41:27
# Treatment Batch 4 from 5 ; Time = 02:47:17
# Number of unique words at end = 211088
#
# ************************************************
#
# STEEM GERMAN
#
# Treatment Start Time = 02:47:22
# Number of unique words at start = 211088
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 02:53:12
# Treatment Batch 1 from 5 ; Time = 02:59:01
# Treatment Batch 2 from 5 ; Time = 03:04:42
# Treatment Batch 3 from 5 ; Time = 03:10:25
# Treatment Batch 4 from 5 ; Time = 03:16:11
# Number of unique words at end = 202743
#
# ************************************************
#
# LEMMA FRENCH
#
# Treatment Start Time = 03:16:16
# Number of unique words at start = 202743
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 03:23:15
# Treatment Batch 1 from 5 ; Time = 03:29:31
# Treatment Batch 2 from 5 ; Time = 03:35:31
# Treatment Batch 3 from 5 ; Time = 03:41:28
# Treatment Batch 4 from 5 ; Time = 03:47:23
# Number of unique words at end = 203332
#
# ************************************************
#
# LEMMA ENGLISH
#
# Treatment Start Time = 03:47:28
# Number of unique words at start = 203332
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 03:53:11
# Treatment Batch 1 from 5 ; Time = 03:58:51
# Treatment Batch 2 from 5 ; Time = 04:04:24
# Treatment Batch 3 from 5 ; Time = 04:10:00
# Treatment Batch 4 from 5 ; Time = 04:15:36
# Number of unique words at end = 203329
#
# ************************************************
#
# LEMMA GERMAN
#
# Treatment Start Time = 04:15:41
# Number of unique words at start = 203329
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 04:21:17
# Treatment Batch 1 from 5 ; Time = 04:26:49
# Treatment Batch 2 from 5 ; Time = 04:32:17
# Treatment Batch 3 from 5 ; Time = 04:37:48
# Treatment Batch 4 from 5 ; Time = 04:43:21
# Number of unique words at end = 203240
#
# ************************************************
#
# STOP_WORDS FRENCH
#
# Treatment Start Time = 04:43:26
# Number of unique words at start = 203240
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 04:50:33
# Treatment Batch 1 from 5 ; Time = 04:56:58
# Treatment Batch 2 from 5 ; Time = 05:03:08
# Treatment Batch 3 from 5 ; Time = 05:09:18
# Treatment Batch 4 from 5 ; Time = 05:15:25
# Number of unique words at end = 203165
#
# ************************************************
#
# STOP_WORDS ENGLISH
#
# Treatment Start Time = 05:15:29
# Number of unique words at start = 203165
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 05:20:36
# Treatment Batch 1 from 5 ; Time = 05:25:40
# Treatment Batch 2 from 5 ; Time = 05:30:39
# Treatment Batch 3 from 5 ; Time = 05:35:39
# Treatment Batch 4 from 5 ; Time = 05:40:41
# Number of unique words at end = 203087
#
# ************************************************
#
# STOP_WORDS GERMAN
#
# Treatment Start Time = 05:40:46
# Number of unique words at start = 203087
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 05:45:44
# Treatment Batch 1 from 5 ; Time = 05:50:39
# Treatment Batch 2 from 5 ; Time = 05:55:31
# Treatment Batch 3 from 5 ; Time = 06:00:25
# Treatment Batch 4 from 5 ; Time = 06:05:20
# Number of unique words at end = 203033
#
# ************************************************
#
# NO_NUM FRENCH
#
# Treatment Start Time = 06:05:25
# Number of unique words at start = 203033
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 06:05:28
# Treatment Batch 1 from 5 ; Time = 06:05:29
# Treatment Batch 2 from 5 ; Time = 06:05:31
# Treatment Batch 3 from 5 ; Time = 06:05:32
# Treatment Batch 4 from 5 ; Time = 06:05:34
# Number of unique words at end = 153168
#
# ************************************************
#
# REMOVE_ACCENTS FRENCH
#
# Treatment Start Time = 06:05:38
# Number of unique words at start = 153168
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 06:05:44
# Treatment Batch 1 from 5 ; Time = 06:05:47
# Treatment Batch 2 from 5 ; Time = 06:05:50
# Treatment Batch 3 from 5 ; Time = 06:05:54
# Treatment Batch 4 from 5 ; Time = 06:05:58
# Number of unique words at end = 150407
#
# ************************************************
#
# NO_SPECIAL FRENCH
#
# Treatment Start Time = 06:06:02
# Number of unique words at start = 150407
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 06:06:04
# Treatment Batch 1 from 5 ; Time = 06:06:05
# Treatment Batch 2 from 5 ; Time = 06:06:06
# Treatment Batch 3 from 5 ; Time = 06:06:07
# Treatment Batch 4 from 5 ; Time = 06:06:08
# Number of unique words at end = 98911

# %% [markdown]
# ...Et encore

# %%
batch = 5

X_treated, treatments = treat_text(X,lemma,'fr',batch)
X_treated, treatments = treat_text(X_treated,lemma,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,lemma,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,steem,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,steem,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,steem,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,stop_words,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,stop_words,'en',batch,treatments)
X_treated, treatments = treat_text(X_treated,stop_words,'de',batch,treatments)

X_treated, treatments = treat_text(X_treated,no_num,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,remove_accents,'fr',batch,treatments)
X_treated, treatments = treat_text(X_treated,no_special,'fr',batch,treatments)
# Out:
# ************************************************
#
# LEMMA FRENCH
#
# Treatment Start Time = 07:30:56
# Number of unique words at start = 407222
# Number of batch: 5
# <ipython-input-257-8d124fc37cf0>:27: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   treated_text = pd.Series()
# Treatment Batch 0 from 5 ; Time = 07:38:09
# Treatment Batch 1 from 5 ; Time = 07:44:33
# Treatment Batch 2 from 5 ; Time = 07:50:41
# Treatment Batch 3 from 5 ; Time = 07:56:41
# Treatment Batch 4 from 5 ; Time = 08:02:41
# Number of unique words at end = 250363
#
# ************************************************
#
# LEMMA ENGLISH
#
# Treatment Start Time = 08:02:46
# Number of unique words at start = 250363
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 08:08:24
# Treatment Batch 1 from 5 ; Time = 08:13:53
# Treatment Batch 2 from 5 ; Time = 08:19:17
# Treatment Batch 3 from 5 ; Time = 08:24:42
# Treatment Batch 4 from 5 ; Time = 08:30:10
# Number of unique words at end = 242904
#
# ************************************************
#
# LEMMA GERMAN
#
# Treatment Start Time = 08:30:15
# Number of unique words at start = 242904
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 08:35:44
# Treatment Batch 1 from 5 ; Time = 08:41:11
# Treatment Batch 2 from 5 ; Time = 08:46:31
# Treatment Batch 3 from 5 ; Time = 08:51:53
# Treatment Batch 4 from 5 ; Time = 08:57:16
# Number of unique words at end = 236462
#
# ************************************************
#
# STEEM FRENCH
#
# Treatment Start Time = 08:57:22
# Number of unique words at start = 236462
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 09:04:59
# Treatment Batch 1 from 5 ; Time = 09:11:52
# Treatment Batch 2 from 5 ; Time = 09:18:27
# Treatment Batch 3 from 5 ; Time = 09:25:02
# Treatment Batch 4 from 5 ; Time = 09:31:37
# Number of unique words at end = 210066
#
# ************************************************
#
# STEEM ENGLISH
#
# Treatment Start Time = 09:31:42
# Number of unique words at start = 210066
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 09:37:31
# Treatment Batch 1 from 5 ; Time = 09:43:16
# Treatment Batch 2 from 5 ; Time = 09:48:57
# Treatment Batch 3 from 5 ; Time = 09:54:39
# Treatment Batch 4 from 5 ; Time = 10:00:21
# Number of unique words at end = 205116
#
# ************************************************
#
# STEEM GERMAN
#
# Treatment Start Time = 10:00:27
# Number of unique words at start = 205116
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 10:06:06
# Treatment Batch 1 from 5 ; Time = 10:11:42
# Treatment Batch 2 from 5 ; Time = 10:17:12
# Treatment Batch 3 from 5 ; Time = 10:22:43
# Treatment Batch 4 from 5 ; Time = 10:28:15
# Number of unique words at end = 202759
#
# ************************************************
#
# STOP_WORDS FRENCH
#
# Treatment Start Time = 10:28:21
# Number of unique words at start = 202759
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 10:35:16
# Treatment Batch 1 from 5 ; Time = 10:41:35
# Treatment Batch 2 from 5 ; Time = 10:47:34
# Treatment Batch 3 from 5 ; Time = 10:53:29
# Treatment Batch 4 from 5 ; Time = 10:59:22
# Number of unique words at end = 202641
#
# ************************************************
#
# STOP_WORDS ENGLISH
#
# Treatment Start Time = 10:59:26
# Number of unique words at start = 202641
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 11:04:23
# Treatment Batch 1 from 5 ; Time = 11:09:16
# Treatment Batch 2 from 5 ; Time = 11:14:05
# Treatment Batch 3 from 5 ; Time = 11:18:54
# Treatment Batch 4 from 5 ; Time = 11:23:44
# Number of unique words at end = 202550
#
# ************************************************
#
# STOP_WORDS GERMAN
#
# Treatment Start Time = 11:23:48
# Number of unique words at start = 202550
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 11:28:34
# Treatment Batch 1 from 5 ; Time = 11:33:22
# Treatment Batch 2 from 5 ; Time = 11:38:02
# Treatment Batch 3 from 5 ; Time = 11:42:45
# Treatment Batch 4 from 5 ; Time = 11:47:29
# Number of unique words at end = 202464
#
# ************************************************
#
# NO_NUM FRENCH
#
# Treatment Start Time = 11:47:33
# Number of unique words at start = 202464
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 11:47:36
# Treatment Batch 1 from 5 ; Time = 11:47:38
# Treatment Batch 2 from 5 ; Time = 11:47:39
# Treatment Batch 3 from 5 ; Time = 11:47:40
# Treatment Batch 4 from 5 ; Time = 11:47:42
# Number of unique words at end = 152707
#
# ************************************************
#
# REMOVE_ACCENTS FRENCH
#
# Treatment Start Time = 11:47:47
# Number of unique words at start = 152707
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 11:47:52
# Treatment Batch 1 from 5 ; Time = 11:47:55
# Treatment Batch 2 from 5 ; Time = 11:47:59
# Treatment Batch 3 from 5 ; Time = 11:48:02
# Treatment Batch 4 from 5 ; Time = 11:48:06
# Number of unique words at end = 149968
#
# ************************************************
#
# NO_SPECIAL FRENCH
#
# Treatment Start Time = 11:48:10
# Number of unique words at start = 149968
# Number of batch: 5
# Treatment Batch 0 from 5 ; Time = 11:48:12
# Treatment Batch 1 from 5 ; Time = 11:48:13
# Treatment Batch 2 from 5 ; Time = 11:48:14
# Treatment Batch 3 from 5 ; Time = 11:48:15
# Treatment Batch 4 from 5 ; Time = 11:48:16
# Number of unique words at end = 98634
