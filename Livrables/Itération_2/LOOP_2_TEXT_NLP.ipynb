# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragdehl/Rakuten_py/blob/main/Livrables/It%C3%A9ration_2/LOOP_2_TEXT_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

import nltk
from nltk import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import re
import string

from collections import Counter
from wordcloud import WordCloud

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

from pylab import rcParams
import warnings
warnings.filterwarnings("ignore")
rcParams['figure.figsize']= 14,6
plt.style.use('ggplot')

# %%
pd.set_option('display.max_colwidth', None)

# %%
# importation du dataframe
df = pd.read_csv('X_train_update.csv',index_col=0)
df.head()
# Out:
#                                                                                                                                                                                                       designation  \
# 0                                                                                                                        Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris - Jacques Barrere - Francois Perrier - La Reforme Des Ventes Aux Encheres Publiques - Le Sna Fete Ses Cent Ans.
# 2                                                                                                                                    Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style
# 3                                                                                                                                                 Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# 4                                                                                                                                                                                            La Guerre Des Tuques
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 2  PILOT STYLE Touch Pen de marque Speedlink est 1 stylet ergonomique pour GamePad Nintendo Wii U.<br> Pour un confort optimal et une précision maximale sur le GamePad de la Wii U: ce grand stylet hautement ergonomique est non seulement parfaitement adapté à votre main mais aussi très élégant.<br> Il est livré avec un support qui se fixe sans adhésif à l'arrière du GamePad<br> <br> Caractéristiques:<br> Modèle: Speedlink PILOT STYLE Touch Pen<br> Couleur: Bleu<br> Ref. Fabricant: SL-3468-BE<br> Compatibilité: GamePad Nintendo Wii U<br> Forme particulièrement ergonomique excellente tenue en main<br> Pointe à revêtement longue durée conçue pour ne pas abîmer l'écran tactile<br> En bonus : Support inclu pour GamePad<br> <span class="vga_style2"><b></b><br>
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de boules de neige et s'arranger pour en &ecirc;tre le vainqueur incontest&eacute;. Mais Sophie s'en m&ecirc;le et chambarde tous ses plans...
#
#     productid     imageid
# 0  3804725264  1263597046
# 1   436067568  1008141237
# 2   201115110   938777978
# 3    50418756   457047496
# 4   278535884  1077757786

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84916 entries, 0 to 84915
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   designation  84916 non-null  object
#  1   description  55116 non-null  object
#  2   productid    84916 non-null  int64
#  3   imageid      84916 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 3.2+ MB

# %%
# ETUDE DE LA COLONNE DESIGNATION
df['designation'] = df['designation'].apply(lambda _: str(_))

# %%
words_per_review = df.designation.apply(lambda x: len(x.split(" ")))
words_per_review.hist(bins = 100, color='darkblue')
plt.title ('variable designation')
plt.xlabel('Review Length (words)')
plt.ylabel('Frequency')
plt.xlim(0,200)
plt.show()

# %%
print('Average words de la variable designation:', words_per_review.mean())
print('Skewness de la variable designation:', words_per_review.skew())
# Out:
# Average words de la variable designation: 11.650925620613313
# Skewness de la variable designation: 2.438238052042657

# %%
# ETUDE DE LA COLONNE DESCRIPTION
df['description'] = df['description'].apply(lambda _: str(_))

# %%
words_per_review2 = df.description.apply(lambda x: len(x.split(" ")))
words_per_review2.hist(bins = 100, color='lime')
plt.title ('variable description')
plt.xlabel('Review Length (words)')
plt.ylabel('Frequency')
plt.xlim(0,200)
plt.show()

# %%
print('Average words de la variable description:', words_per_review2.mean())
print('Skewness de la variable description:', words_per_review2.skew())
# Out:
# Average words de la variable description: 81.11347684770833
# Skewness de la variable description: 3.1630647668569902

# %%
# il y a + de mots de la variable description ve designation, ce qui est logique

# %%
# ETUDE DE LA TARGET
target = pd.read_csv('Y_train_CVw08PX.csv',index_col=0)

# %%
df['target'] =target
df.head(1)
# Out:
#                                                                                 designation  \
# 0  Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
#
#   description   productid     imageid  target
# 0         nan  3804725264  1263597046      10

# %% [markdown]
# df['target'].value_counts()

# %%
percent_target = 100 * df['target'].value_counts()/len(df)
percent_target.plot.bar(color='darkblue')
plt.ylabel('% of all targets')
plt.show()

# %%
df['target'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='target'>

# %%
# Removing all not alphanumeric characters (cleaning express 1)
df.replace("[^a-zA-Z]"," ",regex=True, inplace=True)

# %%
# Converting headlines to lower case (cleaning express 2 )
index = df.columns
index
# Out:
# Index(['designation', 'description', 'productid', 'imageid', 'target'], dtype='object')

# %%
#for j in index:
  #  df[j]=df[j].str.lower()
#df.sample(3)

# %%
# Converting headlines to lower case (cleaning express 2 )
df['designation'] = df['designation'].str.lower() 
df['description'] = df['description'].str.lower()

# %%
df.head(3)
# Out:
#                                                                                                                                                                                                       designation  \
# 0                                                                                                                        olivia  personalisiertes notizbuch       seiten   punktraster   ca din a    rosen design
# 1  journal des arts  le  n      du              l art et son marche salon d art asiatique a paris   jacques barrere   francois perrier   la reforme des ventes aux encheres publiques   le sna fete ses cent ans
# 2                                                                                                                                    grand stylet ergonomique bleu gamepad nintendo wii u   speedlink pilot style
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       nan
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       nan
# 2  pilot style touch pen de marque speedlink est   stylet ergonomique pour gamepad nintendo wii u  br  pour un confort optimal et une pr cision maximale sur le gamepad de la wii u  ce grand stylet hautement ergonomique est non seulement parfaitement adapt    votre main mais aussi tr s  l gant  br  il est livr  avec un support qui se fixe sans adh sif   l arri re du gamepad br   br  caract ristiques  br  mod le  speedlink pilot style touch pen br  couleur  bleu br  ref  fabricant  sl      be br  compatibilit   gamepad nintendo wii u br  forme particuli rement ergonomique excellente tenue en main br  pointe   rev tement longue dur e con ue pour ne pas ab mer l  cran tactile br  en bonus   support inclu pour gamepad br   span class  vga style    b   b  br
#
#     productid     imageid  target
# 0  3804725264  1263597046      10
# 1   436067568  1008141237    2280
# 2   201115110   938777978      50

# %%
# tokenization (cleaning express 3 )
from nltk.tokenize import word_tokenize
def tok (tx):
        token =  word_tokenize(tx)
        return token

# %%
df['designation'] = df['designation'].apply(tok)

# %%
df['description'] = df['description'].astype(str).apply(tok)

# %%
# remove stopwords (cleaning express 4 )
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
eng_stop_words = stopwords.words('english')####### stopwords.words('french')
stopwords =  set (eng_stop_words)  #######
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stopwords = nltk.corpus.stopwords.words('english')
stopwords2 = nltk.corpus.stopwords.words('french')
list_a_nettoyer = ('e','haute',"l'",'x',"'",'p','lumi','re','de','une','li','que','vous','mat','riel','x','X','cm','vous','b','d','pour','les','peut','tre','et','les','carac','h''de ','la ',"l '",'x ', 'cm ', 'ristiques','mat ','riel ','vous ','pla ','br','diff','diff ','rent','rent ', 'rents','rents ','int', 'int ','rieur','rieur ','rieures','rieures ','id','id ','al','al ','ra','ra ','qualit','qualit ','pla','pla ','sine','sine ','r','r ','g','g ','rique','rique ','sistant','sistant','nan','nan ','tout','tout ','sine','sine ','sol','ge','ge ','div','div ','strong','strong ','temp','temp ','si','si ','h','h ','cor','cor ','con','con ','imperm','imperm ','able','able ','sp,', 'cification','cification ','ext', 'ext ','ger','amp','nbsp','ans','span','span ','sp','sp ','cifications','cifications ','rement','rement ','non','non ','comprend','comprend ', 'contenu','contenu ','v','v ','diff','diff ','rent','rent ','rents','rents ','int','int ','rieur', 'rieur ','u','u ','eacute','eacute ','pr','pr ','gr','gr ','tr','tr ','ul','ul ','f','f ')

# %%
# Création d'une liste fusionnée des stopwords french & english puis list à nettoyer
for i in stopwords2:
    stopwords.append(i)
for j in list_a_nettoyer:
    stopwords.append(j)

# %%
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'au', 'aux', 'avec', 'ce', 'ces', 'dans', 'de', 'des', 'du', 'elle', 'en', 'et', 'eux', 'il', 'ils', 'je', 'la', 'le', 'les', 'leur', 'lui', 'ma', 'mais', 'me', 'même', 'mes', 'moi', 'mon', 'ne', 'nos', 'notre', 'nous', 'on', 'ou', 'par', 'pas', 'pour', 'qu', 'que', 'qui', 'sa', 'se', 'ses', 'son', 'sur', 'ta', 'te', 'tes', 'toi', 'ton', 'tu', 'un', 'une', 'vos', 'votre', 'vous', 'c', 'd', 'j', 'l', 'à', 'm', 'n', 's', 't', 'y', 'été', 'étée', 'étées', 'étés', 'étant', 'étante', 'étants', 'étantes', 'suis', 'es', 'est', 'sommes', 'êtes', 'sont', 'serai', 'seras', 'sera', 'serons', 'serez', 'seront', 'serais', 'serait', 'serions', 'seriez', 'seraient', 'étais', 'était', 'étions', 'étiez', 'étaient', 'fus', 'fut', 'fûmes', 'fûtes', 'furent', 'sois', 'soit', 'soyons', 'soyez', 'soient', 'fusse', 'fusses', 'fût', 'fussions', 'fussiez', 'fussent', 'ayant', 'ayante', 'ayantes', 'ayants', 'eu', 'eue', 'eues', 'eus', 'ai', 'as', 'avons', 'avez', 'ont', 'aurai', 'auras', 'aura', 'aurons', 'aurez', 'auront', 'aurais', 'aurait', 'aurions', 'auriez', 'auraient', 'avais', 'avait', 'avions', 'aviez', 'avaient', 'eut', 'eûmes', 'eûtes', 'eurent', 'aie', 'aies', 'ait', 'ayons', 'ayez', 'aient', 'eusse', 'eusses', 'eût', 'eussions', 'eussiez', 'eussent', 'e', 'haute', "l'", 'x', "'", 'p', 'lumi', 're', 'de', 'une', 'li', 'que', 'vous', 'mat', 'riel', 'x', 'X', 'cm', 'vous', 'b', 'd', 'pour', 'les', 'peut', 'tre', 'et', 'les', 'carac', 'hde ', 'la ', "l '", 'x ', 'cm ', 'ristiques', 'mat ', 'riel ', 'vous ', 'pla ', 'br', 'diff', 'diff ', 'rent', 'rent ', 'rents', 'rents ', 'int', 'int ', 'rieur', 'rieur ', 'rieures', 'rieures ', 'id', 'id ', 'al', 'al ', 'ra', 'ra ', 'qualit', 'qualit ', 'pla', 'pla ', 'sine', 'sine ', 'r', 'r ', 'g', 'g ', 'rique', 'rique ', 'sistant', 'sistant', 'nan', 'nan ', 'tout', 'tout ', 'sine', 'sine ', 'sol', 'ge', 'ge ', 'div', 'div ', 'strong', 'strong ', 'temp', 'temp ', 'si', 'si ', 'h', 'h ', 'cor', 'cor ', 'con', 'con ', 'imperm', 'imperm ', 'able', 'able ', 'sp,', 'cification', 'cification ', 'ext', 'ext ', 'ger', 'amp', 'nbsp', 'ans', 'span', 'span ', 'sp', 'sp ', 'cifications', 'cifications ', 'rement', 'rement ', 'non', 'non ', 'comprend', 'comprend ', 'contenu', 'contenu ', 'v', 'v ', 'diff', 'diff ', 'rent', 'rent ', 'rents', 'rents ', 'int', 'int ', 'rieur', 'rieur ', 'u', 'u ', 'eacute', 'eacute ', 'pr', 'pr ', 'gr', 'gr ', 'tr', 'tr ', 'ul', 'ul ', 'f', 'f ']

# %%
def remove_stopwords(text):
    words = [w for w in text if w not in stopwords]
    return words

# %%
df['designation'] = df['designation'].apply(remove_stopwords)

# %%
df['description'] = df['description'].apply(remove_stopwords)

# %%
# STEMMING OU LEMMATIZATION (cleaning optionnel 5 )
from nltk.stem import PorterStemmer, LancasterStemmer # Common stemmers
from nltk.stem import WordNetLemmatizer # Common Lematizer
nltk.download('wordnet')
from nltk.corpus import wordnet

porter = PorterStemmer()
lancaster = LancasterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def stem(text):
    stemi = [ps.stem(word) for word in text]
    return stemi

# %%
df.head(3)
# Out:
#                                                                                                                                               designation  \
# 0                                                                      [olivia, personalisiertes, notizbuch, seiten, punktraster, ca, din, rosen, design]
# 1  [journal, arts, art, marche, salon, art, asiatique, paris, jacques, barrere, francois, perrier, reforme, ventes, encheres, publiques, sna, fete, cent]
# 2                                                                     [grand, stylet, ergonomique, bleu, gamepad, nintendo, wii, speedlink, pilot, style]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       description  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              []
# 2  [pilot, style, touch, pen, marque, speedlink, stylet, ergonomique, gamepad, nintendo, wii, confort, optimal, cision, maximale, gamepad, wii, grand, stylet, hautement, ergonomique, seulement, parfaitement, adapt, main, aussi, gant, livr, support, fixe, sans, adh, sif, arri, gamepad, caract, mod, speedlink, pilot, style, touch, pen, couleur, bleu, ref, fabricant, sl, compatibilit, gamepad, nintendo, wii, forme, particuli, ergonomique, excellente, tenue, main, pointe, rev, tement, longue, dur, ue, ab, mer, cran, tactile, bonus, support, inclu, gamepad, class, vga, style]
#
#     productid     imageid  target
# 0  3804725264  1263597046      10
# 1   436067568  1008141237    2280
# 2   201115110   938777978      50

# %%
# réalisation de la jointure des 2 colonnes texte du dataframe
headlines = []  #####
for row in range(0,len(df.index)):
    headlines.append(' '.join(str(x) for x in df.iloc[row,0:2]))

# %%
headlines
# Out:
# ["['olivia', 'personalisiertes', 'notizbuch', 'seiten', 'punktraster', 'ca', 'din', 'rosen', 'design'] []",
#  "['journal', 'arts', 'art', 'marche', 'salon', 'art', 'asiatique', 'paris', 'jacques', 'barrere', 'francois', 'perrier', 'reforme', 'ventes', 'encheres', 'publiques', 'sna', 'fete', 'cent'] []",
#  "['grand', 'stylet', 'ergonomique', 'bleu', 'gamepad', 'nintendo', 'wii', 'speedlink', 'pilot', 'style'] ['pilot', 'style', 'touch', 'pen', 'marque', 'speedlink', 'stylet', 'ergonomique', 'gamepad', 'nintendo', 'wii', 'confort', 'optimal', 'cision', 'maximale', 'gamepad', 'wii', 'grand', 'stylet', 'hautement', 'ergonomique', 'seulement', 'parfaitement', 'adapt', 'main', 'aussi', 'gant', 'livr', 'support', 'fixe', 'sans', 'adh', 'sif', 'arri', 'gamepad', 'caract', 'mod', 'speedlink', 'pilot', 'style', 'touch', 'pen', 'couleur', 'bleu', 'ref', 'fabricant', 'sl', 'compatibilit', 'gamepad', 'nintendo', 'wii', 'forme', 'particuli', 'ergonomique', 'excellente', 'tenue', 'main', 'pointe', 'rev', 'tement', 'longue', 'dur', 'ue', 'ab', 'mer', 'cran', 'tactile', 'bonus', 'support', 'inclu', 'gamepad', 'class', 'vga', 'style']",
#  "['peluche', 'donald', 'europe', 'disneyland', 'marionnette', 'doigt'] []",
#  "['guerre', 'tuques'] ['luc', 'grandeur', 'veut', 'organiser', 'jeu', 'guerre', 'boules', 'neige', 'arranger', 'ecirc', 'vainqueur', 'incontest', 'sophie', 'ecirc', 'chambarde', 'tous', 'plans']",
#  "['afrique', 'contemporaine', 'hiver', 'dossier', 'japon', 'afrique'] []",
#  "['christof', 'bildungsprozessen', 'auf', 'der', 'spur'] []",
#  "['conqu', 'rant', 'sept', 'cahier', 'couverture', 'polypro', 'mm', 'pages', 'sey', 'incolore'] ['conquerant', 'classique', 'cahier', 'mm', 'sey', 'incolorecouverture', 'polypro', 'pages', 'agraf', 'papier']",
#  "['puzzle', 'scooby', 'doo', 'poster', 'pieces'] []",
#  "['tente', 'pliante', 'pro', 'pvc', 'blanc', 'longueur', 'largeur', 'blanc'] ['tente', 'pliante', 'pro', 'pvc', 'particulier', 'jardin', 'professionnel', 'stand', 'commercial', 'ceptions', 'barnum', 'pro', 'combler', 'imaginez', 'stand', 'robuste', 'adaptable', 'chacun', 'pliable', 'peu', 'encombrant', 'ploiement', 'ultra', 'rapide', 'glage', 'hauteur', 'font', 'maintenant', 'via', 'poign', 'indexage', 'galement', 'enti', 'repens', 'pi', 'jonction', 'coulissants', 'plus', 'rigides', 'res', 'elles', 'aussi', 'maintenant', 'plus', 'sistantes', 'tente', 'pliante', 'pro', 'professionnelle', 'fabrication', 'fran', 'aise', 'compl', 'tement', 'adaptable', 'deviendra', 'outil', 'indispensable', 'activit', 'toujours', 'vue', 'liorer', 'quotidien', 'cette', 'version', 'veut', 'encore', 'plus', 'sistante', 'temps', 'traitement', 'ignifug', 'pond', 'exigences', 'curit', 'vigueur', 'certifi', 'facilit', 'entretien', 'fait', 'alli', 'toutes', 'occasions', 'produit', 'base', 'compos', 'structure', 'toit', 'che', 'pvc', 'housse', 'apr', 'configurer', 'fa', 'ades', 'comme', 'souhaitez', 'avantages', 'facile', 'monter', 'traitement', 'anti', 'feu', 'fa', 'ades', 'choix', 'caract', 'coloris', 'blanc', 'pvc', 'blanc', 'ignifug', 'indexation', 'via', 'poign', 'blocage', 'stand', 'sans', 'effort', 'hauteurs', 'glables', 'via', 'indexeurs', 'croisillons', 'renfort', 'interne', 'renforts', 'externes', 'inox', 'embases', 'fonte', 'aluminium', 'mm', 'anneaux', 'haubanage', 'structure', 'aluminium', 'visserie', 'inox', 'pi', 'jonctions', 'renforc', 'polypropyl', 'fibre', 'verre', 'fils', 'nacit', 'hydrofuges', 'pied', 'coulissant', 'syst', 'guidage', 'pieds', 'hexagonaux', 'aluminium', 'paisseur', 'mm', 'renforts', 'toit', 'pvc', 'finition', 'toit', 'grant', 'biais', 'serg', 'auto', 'agrippant', 'mm', 'maintien', 'toit', 'auto', 'agrippants', 'encombrement', 'referm', 'inf', 'dimensions', 'ts', 'hauteur', 'fa', 'tage', 'hauteur', 'sous', 'bandeau', 'dimensions', 'repli']",
#  "['eames', 'inspired', 'sxw', 'chair', 'pink', 'black'] ['timeless', 'dsw', 'seat', 'paired', 'types', 'legs', 'wood', 'legs', 'look', 'like', 'natural', 'fit', 'seat', 'make', 'safe', 'choice', 'interior', 'chair', 'perfect', 'offices', 'kitchens', 'dining', 'rooms', 'ideal', 'kitchen', 'living', 'room', 'office', 'waiting', 'room', 'reception', 'available', 'colours', 'white', 'red', 'blue', 'baby', 'blue', 'black', 'yellow', 'orange', 'olive', 'dark', 'orange', 'chocolate', 'light', 'green', 'warm', 'grey', 'beige', 'light', 'grey', 'blue', 'ocean', 'pink', 'fushia', 'green', 'tree', 'graphite', 'tarmac', 'royal', 'blue', 'features', 'avalaible', 'without', 'amrests']",
#  "['fauteuil', 'chesterfield', 'brenton', 'cuir', 'buffle', 'vert', 'empire'] ['canap', 'fauteuil', 'chesterfield', 'cuir', 'antique', 'enton', 'coloris', 'chocolat', 'vert', 'empire', 'rouge', 'cherry', 'disponible', 'canap', 'places', 'places', 'places', 'fauteuil', 'design', 'mythique', 'succombez', 'design', 'mythique', 'style', 'chesterfield', 'capitonnage', 'marqu', 'dossier', 'font', 'salon', 'brenton', 'mod', 'tendance', 'intemporel', 'optez', 'couleur', 'chocolat', 'reflets', 'ch', 'tain', 'sortez', 'commun', 'rouge', 'cherry', 'appr', 'cierez', 'lattention', 'port', 'tails', 'tels', 'capitonnage', 'structure', 'lassise', 'coutures', 'daccoudoirs', 'clout', 'riaux', 'premium', 'duits', 'cuir', 'antique', 'patin', 'main', 'apporte', 'salon', 'brenton', 'aspect', 'vieilli', 'tendance', 'fois', 'esth', 'tique', 'agr', 'toucher', 'succombez', 'cuir', 'buffle', 'pleine', 'fleur', 'conf', 'canap', 'toute', 'gance', 'cuir', 'pleine', 'fleur', 'premi', 'couche', 'peau', 'animal', 'corrig', 'conserv', 'surface', 'origine', 'appel', 'fleur', 'laissant', 'apercevoir', 'grain', 'naturel', 'peau', 'mati', 'noble', 'luxueuse', 'cuir', 'pleine', 'fleur', 'particuli', 'doux', 'agr', 'toucher', 'confort', 'optimal', 'douceur', 'cuir', 'plein', 'fleur', 'ajoute', 'confort', 'garnissage', 'mousse', 'silience', 'garantit', 'confort', 'absolu', 'durable', 'choisir', 'brenton', 'opter', 'canap', 'haut', 'gamme', 'apportera', 'satisfaction', 'totale', 'durable', 'caract', 'techniques', 'linea', 'sofa', 'collection', 'salons', 'linea', 'sofa', 'pond', 'sirs', 'confort', 'sth', 'tisme', 'ceux', 'recherchent', 'produits', 'exception', 'cialis', 'salons', 'designers', 'haut', 'gamme', 'marque', 'linea', 'sofa', 'donne', 'personnalit', 'soin', 'extr', 'apport', 'fabrication', 'produits', 'luxe', 'finitions', 'irr', 'prochables', 'us', 'riaux', 'nobles', 'exclusivement', 'toujours', 'pointe', 'tendances', 'linea', 'sofa', 'tient', 'proposer', 'sans', 'cesse', 'collections', 'fois', 'fonctionnelles', 'uniques', 'nuancier', 'couleurs', 'innovantes', 'cuir', 'buffle', 'pleine', 'fleur', 'mati', 'noble', 'luxueuse', 'cuir', 'pleine', 'fleur', 'particuli', 'doux', 'agr', 'toucher', 'fleur', 'corrig', 'pigment', 'paisseur', 'mm', 'cuir', 'antique', 'cuir', 'pleine', 'fleur', 'patin', 'main', 'aspect', 'vieilli', 'brillant', 'durable', 'salon', 'recouvert', 'exclusivement', 'cuir', 'buffle', 'pleine', 'fleur', 'garantissant', 'ainsi', 'confort', 'long', 'vit', 'assise', 'dossier', 'garnis', 'mousse', 'polyur', 'thane', 'silience', 'utilis', 'literie', 'mousse', 'silience', 'plus', 'confortable', 'plus', 'robuste', 'mousses', 'classiques', 'assure', 'donc', 'plus', 'grand', 'confort', 'meilleure', 'sistance', 'cours', 'temps', 'densit', 'assise', 'kg', 'premi', 'couche', 'kg', 'deuxi', 'couche', 'kg', 'troisi', 'couche', 'densit', 'dossier', 'accoudoirs', 'kg', 'premi', 'couche', 'kg', 'seconde', 'couche', 'suspension', 'dossier', 'sangles', 'lastiques', 'ressorts', 'suspension', 'assise', 'ressorts', 'lico', 'daux', 'structure', 'pieds', 'bois', 'bon', 'savoir', 'cuir', 'buffle', 'cuir', 'dont', 'relief', 'plus', 'important', 'grain', 'fois', 'naturel', 'irr', 'gulier', 'caract', 'font', 'riau', 'particuli', 'qualitatif', 'vaut', 'surnom', 'diamant', 'cuir', 'dimensions', 'canap', 'places', 'canap', 'places', 'canap', 'places', 'fauteuil', 'hauteur', 'assise', 'profondeur', 'assise', 'veillez', 'bien', 'rifier', 'dimensions', 'porte', 'escalier', 'livraison', 'lai', 'livraison', 'produit', 'confirm', 'panier', 'dimensions', 'colis', 'fauteuil', 'brenton', 'produit', 'longueur', 'largeur', 'hauteur', 'poids', 'kg', 'colis', 'longueur', 'largeur', 'hauteur', 'poids', 'kg']",
#  "['peaceable', 'kingdom', 'wheres', 'bear', 'hide', 'find', 'stacking', 'block', 'game', 'year', 'olds'] ['pcan', 'year', 'old', 'play', 'game', 'yes', 'game', 'year', 'old', 'collection', 'designed', 'child', 'experience', 'like', 'take', 'turns', 'play', 'within', 'rules', 'even', 'loosely', 'possibly', 'learn', 'new', 'skill', 'like', 'rolling', 'die', 'unlike', 'games', 'older', 'children', 'however', 'dont', 'win', 'lose', 'game', 'play', 'explore', 'play', 'learn', 'play', 'connect', 'quality', 'time', 'little', 'one', 'since', 'play', 'heart', 'soul', 'peaceable', 'kingdom', 'silly', 'play', 'special', 'play', 'wholehearted', 'play', 'create', 'experiences', 'help', 'kids', 'play', 'well', 'together', 'play', 'well', 'world', 'games', 'gifts', 'connect', 'kids', 'families', 'encourage', 'learning', 'self', 'expression', 'let', 'imaginations', 'soar', 'piece', 'peaceable', 'kingdom', 'game', 'gift', 'gets', 'lost', 'fun', 'gladly', 'send', 'replacement', 'piece', 'contact', 'us', 'directly', 'need', 'play', 'comes', 'heart', 'feeds', 'soul', 'thats', 'peaceable', 'kingdom']",
#  "['paire', 'voilages', 'imprim', 'fantaisie'] ['paire', 'voilages', 'droits', 'fantaisie', 'mettra', 'valeurun', 'parement', 'uni', 'petits', 'coeurs', 'suivi', 'petit', 'galon', 'color', 'forme', 'galement', 'coeur', 'viendra', 'faire', 'jonction', 'partie', 'inf', 'rieure', 'ray', 'coloris', 'cru', 'coloris', 'gris', 'rouge', 'dimensions', 'cmfinition', 'ourlet', 'passe', 'tringlepr', 'poserla', 'base', 'ourl', 'caract', 'coloris', 'gris', 'rougefinition', 'ourlet', 'passe', 'tringlecomposition', 'polyester', 'cotondimensions', 'vendu', 'pairepr', 'poser']",
#  "['matelas', 'moire', 'forme', 'ferme', 'houssable', 'housse', 'lavable', 'zones', 'confort', 'noyau', 'poli', 'lattex', 'hr', 'derni', 'ration', 'respirant'] ['matelas', 'accueil', 'ferme', 'soutien', 'ferme', 'technologie', 'matelas', 'face', 'mousse', 'poli', 'lattex', 'derni', 'ration', 'ind', 'formable', 'silience', 'face', 'hiver', 'mousse', 'moire', 'forme', 'densit', 'kg', 'massante', 'paisseur', 'matelas', 'repos', 'plus', 'sain', 'traitement', 'anti', 'acariens', 'anti', 'bact', 'rien', 'anti', 'moisissures', 'bonne', 'ind', 'pendance', 'couchage', 'dormez', 'tranquille', 'garantie', 'compatible', 'sommiers', 'caniques', 'lectriques', 'coutil', 'coutil', 'stretch', 'matelass', 'polyester', 'traitement', 'sanitized', 'faces', 'couchage', 'versibles', 'houssable', 'housse', 'lavable', 'position', 'lavage', 'main', 'licat', 'sanitized', 'traitement', 'antibact', 'rien', 'anti', 'moisissures', 'diminuant', 'galement', 'veloppement', 'odeurs', 'structure', 'garnissage', 'matelas', 'faces', 'dormeur', 'mousse', 'profil', 'ventilation', 'maximiser', 'confort', 'coutil', 'tissu', 'bonne', 'respiration', 'noyau', 'matelass', 'air', 'system', 'tissu', 'hyper', 'respirant', 'alis', 'dimensions', 'permet', 'circulation', 'libre', 'air', 'offrant', 'ainsi', 'plus', 'grande', 'ventilation', 'hygi', 'plate', 'bande', 'tissu', 'hyper', 'respirant', 'matelass', 'ouate', 'polyester', 'noyau', 'bloc', 'mousse', 'resilience', 'poli', 'lattex', 'derni', 'ration', 'ind', 'formable', 'structure', 'matelas', 'divis', 'incroyables', 'zones', 'confort', 'adaptent', 'tous', 'types', 'morphologies', 'aident', 'lib', 'rer', 'tensions', 'musculaires', 'soulager', 'maux', 'dos', 'provoqu', 'mauvaises', 'postures', 'cours', 'journ', 'tissus', 'certifies', 'syst', 'certifi', 'oeko', 'tex', 'certipur', 'test', 'contre', 'substances', 'nocives', 'certification', 'iso']",
#  "['zenith', 'pince', 'agrafeuse', 'coloris', 'noir'] ['pince', 'agrafeuse', 'capot', 'abs', 'dispositif', 'anti', 'blocage', 'canisme', 'corps', 'tal', 'agrafage', 'feuilles', 'capacit', 'agrafes', 'profondeur', 'gorge', 'mm', 'livr', 'bo', 'agrafes', 'boite', 'individuelle']",
#  "['walter', 'scott', 'oeuvres', 'compl', 'tomes'] []",
#  "['mod', 'podge', 'dishwasher', 'safe', 'gloss', 'oz'] []",
#  "['power', 'rangers', 'rouge', 'force', 'mystic', 'figurine', 'transformable'] []",
#  "['monde', 'illustre', 'emprunt', 'victoire', 'angleterre', 'meeting', 'guildhall', 'lloyd', 'george', 'bonar', 'law', 'mac', 'kenna', 'conference', 'allies', 'briand', 'barrere', 'general', 'palitzine'] []",
#  "['kit', 'sinfection', 'piscines', 'enfants'] []",
#  "['glitter', 'beach', 'barbie', 'barbie'] ['original', 'barbie', 'doll', 'contains', 'glitter', 'lotion']",
#  "['seigneur', 'anneaux', 'figurine', 'plomb', 'peindre', 'socle', 'sam'] []",
#  "['hicule', 'star', 'wars', 'ast'] ['hicule', 'vintage', 'saga', 'star', 'wars', 'ast']",
#  "['mini', 'wifi', 'cam', 'drone', 'rc', 'quadcopter', 'ghz', 'ch', 'axis', 'gyro', 'ufo', 'fpv', 'rc', 'cocoworld'] ['mini', 'wifi', 'cam', 'drone', 'rc', 'quadcopter', 'ghz', 'ch', 'axis', 'gyro', 'ufo', 'fpv', 'rc', 'description', 'marque', 'dhd', 'point', 'fr', 'quence', 'ghz', 'canal', 'canaux', 'axe', 'axes', 'couleur', 'vert', 'bleu', 'copter', 'batterie', 'mah', 'temps', 'vol', 'propos', 'mins', 'temps', 'charge', 'propos', 'mins', 'contr', 'distance', 'environ', 'taille', 'produit', 'caract', 'canaux', 'mini', 'quadcopter', 'mode', 'tection', 'gravit', 'rend', 'plus', 'ressant', 'contr', 'ler', 'drone', 'cam', 'permet', 'prendre', 'photos', 'enregistrer', 'vid', 'os', 'wifi', 'fpv', 'temps', 'el', 'apporte', 'monde', 'devant', 'led', 'nuit', 'flight', 'flips', 'roll', 'rendre', 'vol', 'plus', 'dr', 'permettent', 'voir', 'vue', 'hd', 'direct', 'cam', 'fpv', 'tenir', 'courant', 'passe', 'air', 'technologie', 'adopt', 'anti', 'ing', 'rence', 'encore', 'plus', 'quadcopter', 'vole', 'temps', 'vont', 'interf', 'rer', 'uns', 'autres', 'axis', 'vol', 'quad', 'giravion', 'gyroscope', 'forte', 'stabilit', 'facilement', 'mettre', 'uvre', 'divers', 'mouvements', 'vol', 'plus', 'forte', 'sistance', 'vent', 'plus', 'facile', 'contr', 'ler', 'led', 'deviennent', 'plus', 'curit', 'ciel', 'nocturne', 'mini', 'portable', 'cellule', 'pliage', 'peuvent', 'mont', 'contr', 'distance', 'hicules', 'riens', 'quip', 'plein', 'air', 'sac', 'vol', 'voyage', 'facile', 'sans', 'pression', 'fonctions', 'haut', 'bas', 'tourner', 'gauche', 'droite', 'avant', 'arri', 'gauche', 'droite', 'sidewayfly', 'flips', 'roll', 'led', 'paquet', 'contient', 'quadcopter', 'camera', 'sans', 'fil', 'batterie', 'commande', 'tui', 'protection', 'rieure', 'support', 'phone', 'quadcoper', 'chargeur', 'usb', 'garde', 'lame', 'manuel', 'facilement', 'mettre', 'uvre', 'divers', 'mouvements', 'vol', 'plus', 'forte', 'sistance', 'vent', 'plus', 'facile', 'contr', 'ler', 'led', 'deviennent', 'plus', 'curit', 'ciel', 'nocturne', 'mini', 'portable', 'cellule', 'pliage', 'peuvent', 'mont', 'contr', 'distance', 'hicules', 'riens', 'quip', 'plein', 'air', 'sac', 'vol', 'voyage', 'facile', 'sans', 'pression', 'fonctions', 'haut', 'bas', 'tourner', 'gauche', 'droite', 'avant', 'arri', 'gauche', 'droite', 'sidewayfly', 'flips', 'roll', 'led', 'paquet', 'contient', 'quadcopter', 'camera', 'sans', 'fil', 'batterie', 'commande', 'tui', 'protection', 'rieure', 'support', 'phone', 'quadcoper', 'chargeur', 'usb', 'garde', 'lame', 'manuel', 'facilement', 'mettre', 'uvre', 'divers', 'mouvements', 'vol', 'plus', 'forte', 'sistance', 'vent', 'plus', 'facile', 'contr', 'ler', 'led', 'deviennent', 'plus', 'curit', 'ciel', 'nocturne', 'mini', 'portable', 'cellule', 'pliage', 'peuvent', 'mont', 'contr', 'distance', 'hicules', 'riens', 'quip', 'plein', 'air', 'sac', 'vol', 'voyage', 'facile', 'sans', 'pression', 'fonctions', 'haut', 'bas', 'tourner', 'gauche', 'droite', 'avant', 'arri', 'gauche', 'droite', 'sidewayfly', 'flips', 'roll', 'led', 'paquet', 'contient', 'quadcopter', 'camera', 'sans', 'fil', 'batterie', 'commande', 'tui', 'protection', 'rieure', 'support', 'phone', 'quadcoper', 'chargeur', 'usb', 'garde', 'lame', 'manuel']",
#  "['dsi', 'chargeur', 'sacoche', 'jeux'] []",
#  "['mod', 'voiture', 'pcs', 'alliage', 'tallique', 'jante', 'roue', 'traxxas', 'trx', 'hsp', 'scx', 'rc', 'voiture'] ['pcs', 'alliage', 'tallique', 'jante', 'roue', 'traxxas', 'trx', 'hsp', 'scx', 'rc', 'car', 'description', 'moyeux', 'roue', 'pouces', 'alliage', 'tallique', 'durable', 'solide', 'conviennent', 'pneus', 'traxxas', 'hsp', 'redcat', 'tamiya', 'axiale', 'scx', 'hpi', 'rc', 'roues', 'motrices', 'voiture', 'formidable', 'performance', 'pondre', 'besoins', 'utilisateurs', 'alors', 'venez', 'prendre', 'maison', 'excellent', 'choix', 'permettra', 'profiter', 'plus', 'plaisir', 'pouces', 'jante', 'roue', 'blocage', 'tal', 'neuf', 'durable', 'diam', 'mm', 'epaisseur', 'mm', 'jante', 'roue', 'hex', 'mm', 'taille', 'paquet', 'couleur', 'noir', 'poids', 'tal', 'package', 'moyeu', 'roue']",
#  "['faber', 'castell', 'lot', 'crayons', 'couleur', 'polychromos', 'mine', 'mm', 'huile', 'vert', 'emeraude'] ['faber', 'castell', 'crayon', 'couleur', 'polychromos', 'vert', 'meraudepour', 'artistes', 'hexagonal', 'essuyage', 'auxintemp', 'ries', 'mine', 'craie', 'huile', 'solide', 'paisseur', 'mine', 'mm', 'longueur', 'mm', 'couleur']",
#  "['univers', 'france', 'paris', 'septembre', 'lac', 'protestation', 'joseph'] []",
#  "['dragon', 'ball', 'super', 'bt', 'misses', 'peur', 'peu', 'commune'] []",
#  "['lampe', 'lecture', 'rechargeable', 'led', 'lampe', 'beaut', 'lampe', 'protection', 'yeux', 'lampe', 'froide', 'col', 'cygne', 'lampe', 'moderne', 'lampe', 'bureau', 'rechargeable'] ['nom', 'marque', 'syth', 'ampoules', 'incluses', 'oui', 'certification', 'ccc', 'corps', 'aluminium', 'type', 'ombre', 'abs', 'voltage', 'aluminium', 'num', 'ro', 'mod', 'syth', 'dmsh', 'style', 'moderne', 'type', 'coupage', 'bouton', 'poussoir', 'source', 'ampoules', 'led', 'type', 'article', 'lampes', 'bureau', 'source', 'nergie', 'dc', 'terminer', 'fer', 'glable', 'oui', 'feature', 'table', 'lamp', 'feature', 'desk', 'lamp', 'feature', 'led', 'table', 'lamp', 'feature', 'led', 'desk', 'lamp', 'feature', 'study', 'lamp', 'feature', 'table', 'light', 'feature', 'usb', 'led', 'feature', 'book', 'light', 'feature', 'reading', 'light', 'feature', 'reading', 'lamp']",
#  "['men', 'movie'] []",
#  "['cagettes', 'rangement', 'happy', 'life', 'beige'] ['organisez', 'rangez', 'mani', 'scandinave', 'lot', 'deux', 'cagettes', 'citations', 'bordantes', 'bonne', 'humeur', 'empilables', 'pourrez', 'facilement', 'ranger', 'obtenir', 'gain', 'place', 'optimal', 'co', 'disposez', 'sous', 'table', 'basse', 'meuble', 'rangement', 'simplement', 'coin', 'salon', 'tant', 'objets', 'rangement', 'coratifs', 'fiche', 'technique', 'cagettes', 'bois', 'rentes', 'tailles', 'caracteristiques', 'techniques', 'dimensions', 'grande', 'cagette', 'dimensions', 'petite', 'cagette', 'poids', 'kg']",
#  "['lindner', 'coin', 'case', 'nera', 'xl', 'trays', 'black', 'coin', 'inserts', 'rectangular', 'compartments', 'coins', 'coin', 'capsules', 'mm'] ['timeless', 'elegance', 'clear', 'design', 'versatility', 'functionality', 'special', 'haptics', 'touch', 'distinguished', 'features', 'nera', 'series', 'grained', 'structure', 'material', 'conjunction', 'cr', 'colored', 'stitching', 'grants', 'series', 'individual', 'character', 'graphite', 'colored', 'padded', 'lining', 'lid', 'nera', 'case', 'provides', 'attractive', 'contrast', 'inserts', 'coins', 'coin', 'trays', 'covered', 'high', 'quality', 'velour', 'like', 'surface', 'coin', 'case', 'black', 'grained', 'surface', 'leather', 'optic', 'cr', 'colored', 'stitching', 'graphite', 'colored', 'padded', 'lining', 'lid', 'trays', 'black', 'coin', 'inserts', 'rectangular', 'compartments', 'coin', 'inserts', 'covered', 'high', 'quality', 'velour', 'like', 'surface', 'format', 'mm', 'mm', 'mm', 'suitable', 'coins', 'coin', 'capsules', 'mm']",
#  "['lord', 'th', 'rings'] []",
#  "['decoration', 'noel', 'christmas', 'snowman', 'kitchen', 'table', 'chair', 'covers', 'holiday', 'home', 'decoration'] ['christmas', 'snowman', 'kitchen', 'table', 'chair', 'covers', 'holiday', 'home', 'decoration', 'description', 'product', 'name', 'christmas', 'ornamentsbrand', 'new', 'high', 'quality', 'occasion', 'party', 'banquetrestaurantvery', 'easy', 'use', 'simply', 'stretch', 'chairmaterial', 'clothcolor', 'redblueblackgreensize', 'cmtips', 'due', 'difference', 'different', 'monitors', 'picture', 'may', 'reflect', 'actual', 'color', 'item', 'thanks', 'package', 'included', 'chair', 'cover']",
#  "['spots', 'encastrable', 'orientable', 'blanc', 'gu', 'led', 'w', 'eqv', 'w', 'blanc', 'froid', 'k'] ['lot', 'spots', 'encastrable', 'orientable', 'blanc', 'gu', 'led', 'w', 'w', 'kit', 'contenant', 'douilles', 'gu', 'ampoules', 'gu', 'w', 'colerettes', 'blanche', 'ampoules', 'led', 'w', 'gu', 'fait', 'partie', 'vaste', 'gamme', 'lampes', 'ambiance', 'led', 'longue', 'dur', 'faible', 'consommation', 'brillamment', 'ues', 'culot', 'gu', 'sans', 'avoir', 'changer', 'installation', 'remarquable', 'combinaison', 'technologie', 'efficacit', 'forme', 'innovante', 'ampoules', 'led', 'gu', 'w', 'fournit', 'attendez', 'dure', 'jusqu', 'fois', 'plus', 'longtemps', 'fournit', 'jusqu', 'conomies', 'nergie', 'plus', 'tres', 'design', 'ampoules', 'led', 'gu', 'w', 'efficacit', 'rayonnement', 'pouvant', 'tendre', 'jusqu', 'ampoules', 'led', 'gu', 'w', 'meilleures', 'ampoules', 'standards', 'elles', 'consomment', 'moins', 'nergie', 'solution', 'conomique', 'cologique', 'nouvelle', 'ration', 'utilisation', 'maisons', 'bureaux', 'restaurants', 'tels', 'timents', 'publics', 'remplace', 'enti', 'lampe', 'incandescence', 'halog', 'standard', 'installation', 'facile', 'longue', 'dur', 'vie', 'avantage', 'dur', 'vie', 'heures', 'consomme', 'jusqu', 'moins', 'nergie', 'ampoule', 'led', 'omnidirectionnelle', 'homog', 'quilibr', 'allumage', 'instantan', 'efficacit', 'nerg', 'tique', 'longue', 'dur', 'vie', 'ampoules', 'led', 'gu', 'engendrent', 'moins', 'remplacements', 'lampe', 'comparaison', 'sources', 'incandescentes', 'halog', 'nes', 'standards', 'douille', 'ramique', 'gu', 'ble', 'gain', 'volts', 'classe', 'connecteur', 'lectrique', 'automatique', 'vis', 'double', 'connexion', 'montage', 'parall', 'arriv', 'spot', 'part', 'spot', 'suivant', 'sucre', 'protection', 'clipsable', 'dimensions', 'longueur', 'diam', 'mm', 'conforme', 'normes', 'rohs', 'emc', 'douille', 'ampoule', 'culot', 'gu', 'gz', 'automatique', 'corps', 'isolant', 'steatite', 'fil', 'silicone', 'mm', 'ble', 'gain', 'sucre', 'protection', 'fermeture', 'clipser', 'besoin', 'vis', 'amovible', 'double', 'connexion', 'montage', 'rie', 'clipsable', 'sans', 'besoin', 'aider', 'outil', 'longueur', 'collerette', 'orientable', 'ronde', 'blanche', 'dimensions', 'diam', 'mm', 'per', 'age', 'encastrement', 'mm', 'diam', 'total', 'support', 'encastrable', 'blanc', 'ale', 'centre', 'orientable', 'cela', 'permet', 'diffuser', 'direction', 'choisie', 'diam', 'mm', 'trou', 'coupe', 'mm', 'ampoule', 'place', 'avant', 'pratique', 'lorsque', 'veut', 'changer', 'couleur', 'blanche', 'permet', 'grer', 'sans', 'probl', 'plafond', 'blanc', 'color', 'puissance', 'w', 'douille', 'gu', 'alimentation', 'ac', 'flux', 'lumineux', 'lm', 'puissance', 'leds', 'w', 'fr', 'quence', 'fonctionnement', 'hz', 'couleur', 'k', 'angle', 'gt', 'consommation', 'kwh', 'rature', 'fonctionnement', 'thermoplastic', 'aluminium', 'degr', 'protection', 'ip', 'taille', 'mm', 'poids', 'kg', 'exploitation', 'gt', 'heures']",
#  "['nouveau', 'chelle', 'alloy', 'mini', 'pull', 'back', 'voiturette', 'w', 'clubs', 'diecast', 'jouets', 'mod', 'hicule'] ['nouveau', 'chelle', 'alloy', 'mini', 'pull', 'back', 'voiturette', 'w', 'clubs', 'mod', 'caract', 'toy', 'diecast', 'hicule', 'marque', 'nouvelle', 'mini', 'chelle', 'retirent', 'golf', 'clubs', 'mod', 'diecast', 'tirez', 'voiture', 'rel', 'chez', 'voiture', 'va', 'aller', 'vite', 'douceur', 'alliage', 'plastique', 'couleur', 'jaune', 'rouge', 'bleu', 'vert', 'taille', 'environ', 'inch', 'note', 'tir', 'affichages', 'provoquer', 'couleur', 'ment', 'image', 'peu', 'rente', 'vraie', 'chose', 'erreur', 'mesure', 'autoris', 'coffret', 'golf', 'cart', 'mod', 'toy']",
#  "['pcs', 'coussin', 'ind', 'pendance', 'style', 'jeter', 'covers', 'taie', 'oreiller'] ['pcs', 'coussin', 'independence', 'day', 'style', 'throw', 'taie', 'oreiller', 'couvre', 'vente', 'produits', 'point', 'utilis', 'corer', 'salon', 'faire', 'para', 'maison', 'chaleur', 'plus', 'confortable', 'coussin', 'coratif', 'couverture', 'utilis', 'pouces', 'oreiller', 'inserts', 'pls', 'noter', 'insertions', 'inclus', 'motif', 'peinture', 'seul', 'taies', 'oreiller', 'facile', 'faire', 'correspondre', 'canap', 'canap', 'autre', 'pillows', 'soft', 'durable', 'deux', 'salon', 'bureau', 'chambre', 'etc', 'terrasse', 'voiture', 'etc', 'fermeture', 'glissi', 'cach', 'draps', 'coton', 'coussin', 'coffre', 'fort', 'machine', 'wash', 'lavage', 'sec', 'hand', 'dot', 'bleach', 'tumble', 'low', 'fer', 'fait', 'draps', 'coton', 'durable', 'cologique', 'materials', 'keep', 'place', 'propre', 'throw', 'pillow', 'contre', 'z', 'ro', 'traces', 'doigts', 'description', 'coton', 'lin', 'approx', 'taille', 'avoir', 'cart', 'raison', 'produit', 'date', 'remarque', 'permettre', 'erreur', 'mineure', 'raison', 'mesure', 'manuelle', 'raison', 'rence', 'entre', 'moniteurs', 'image', 'refl', 'ter', 'couleur', 'article', 'forfait', 'pcs', 'taie', 'oreiller', 'coussin', 'inclus']",
#  "['bou', 'gonflable', 'river', 'tube', 'oogarden'] ['bou', 'gonflable', 'river', 'tube', 'pvc', 'ale', 'parties', 'glissade', 'eau', 'dimensions', 'article', 'gonfl', 'cmdimensions', 'article', 'plat', 'cmmati', 'pvcinclus', 'corde', 'maintienconfortablement', 'install', 'accrochez', 'cette', 'bou', 'gonflable', 'river', 'tube', 'jeux', 'glisse', 'piscine', 'mer']",
#  "['mini', 'console', 'jeux', 'double', 'joueurs', 'bits', 'console', 'jeux', 'vid', 'enfance', 'jeux', 'classiques', 'av', 'family', 'tv', 'contr', 'jeux', 'tro'] ['nom', 'marque', 'noenname', 'null', 'affichage', 'couleur', 'oui', 'ecran', 'tactile', 'num', 'ro', 'mod', 'coolbaby', 'paquet', 'oui', 'communication', 'usb']",
#  "['sentoir', 'biscuits', 'chocolats'] []",
#  "['pilot', 'mr', 'stylo', 'plume', 'moyenne', 'design', 'crocodile', 'noir', 'bleu'] ['couleur', 'crocodile', 'noir', 'bleu', 'description', 'produit', 'touche', 'esprit', 'sauvage', 'criture', 'stylo', 'plume', 'premium', 'plume', 'acier', 'corps', 'tal', 'rechargeable', 'cartouches', 'din', 'standards', 'points', 'forts', 'rechargeable']",
#  "['toxique', 'effacer', 'slime', 'coul', 'beau', 'lange', 'nuage', 'slime', 'relief', 'enfants', 'jouets', 'stress'] ['toxique', 'effacer', 'slime', 'couleur', 'beau', 'lange', 'nuage', 'slime', 'relief', 'enfants', 'stress', 'jouets', 'caract', 'fabriqu', 'mati', 'res', 'premi', 'res', 'respectueuses', 'environnement', 'toxiques', 'assur', 'jouer', 'eat', 'safe', 'enfants', 'utiliser', 'toxiques', 'enfants', 'jouer', 'mang', 'trop', 'petits', 'enfants', 'parfait', 'soulager', 'stress', 'comme', 'presser', 'plier', 'rouler', 'tirez', 'boue', 'heures', 'plaisir', 'satisfaction', 'bruits', 'grand', 'cadeau', 'choix', 'cadeau', 'enfants', 'jouet', 'boue', 'merveilleux', 'gar', 'ons', 'filles', 'grand', 'soulagement', 'stress', 'adultes', 'enfants', 'aucun', 'post', 'moins', 'collante', 'autres', 'fluffy', 'slime', 'alors', 'essayez', 'barrasser', 'adh', 'sivit', 'grande', 'coh', 'rence', 'texture', 'tonnante', 'super', 'facile', 'jouer', 'slime', 'juste', 'sortir', 'pot', 'trouver', 'fa', 'jouer', 'cette', 'boue', 'pelucheux', 'aussi', 'arts', 'artisanat', 'projets', 'scolaires', 'jouant', 'visuel', 'enfants', 'peuvent', 'exercer', 'leurs', 'mains', 'liorer', 'motricit', 'velopper', 'yeux', 'main', 'caract', 'mati', 'boue', 'boue', 'poids', 'marchandise', 'poids', 'unique', 'capacit', 'produit', 'ml', 'paquet', 'ml', 'boue', 'argile']",
#  "['diagrammes', 'siecle', 'petrole', 'guillerme', 'claude', 'henri', 'rocquet'] []",
#  "['rideau', 'oeillets', 'plastique', 'polyester', 'uni', 'essentiel', 'lin'] ['poser', 'rideau', 'installe', 'facilement', 'fera', 'gagner', 'temps', 'composition', 'polyester', 'rideau', 'prot', 'gera', 'regards', 'rieurs', 'laissera', 'passer', 'dimension', 'finition', 'oeillets', 'ronds', 'plastique', 'plusieurs', 'coloris', 'cette', 'collection', 'ainsi', 'galettes', 'chaise', 'housses', 'coussin', 'nappes', 'donner', 'cot', 'original', 'interieur']",
#  "['vassivi', 'limousin', 'jardin', 'art', 'lieu', 'moire'] []",
#  "['shin', 'masoukishin', 'panzer', 'warfare', 'import', 'jap'] []",
#  "['dragon', 'ball', 'z', 'serie', 'francaise'] []",
#  "['pcs', 'premium', 'tons', 'bracelets', 'neon', 'light', 'glowing', 'party', 'favors', 'rallye', 'raves', 'cocoworld'] ['pcs', 'premium', 'tons', 'bracelets', 'neon', 'light', 'party', 'favors', 'glowing', 'rallye', 'raves', 'proposons', 'choix', 'couleur', 'style', 'ferons', 'parvenir', 'produit', 'hasard', 'esp', 'rons', 'pouvez', 'comprendre', 'feature', 'neuf', 'quantit', 'pcs', 'couleur', 'vari', 'lange', 'couleur', 'atoire', 'mode', 'emploi', 'doucement', 'seulement', 'pause', 'liquide', 'tons', 'glo', 'alors', 'langer', 'imm', 'diatement', 'tube', 'fluoresce', 'instantan', 'articulation', 'adapt', 'faciliter', 'plusieurs', 'extension', 'illimit', 'aussi', 'transform', 'color', 'grande', 'vari', 'utilis', 'concerts', 'salles', 'danse', 'anniversaire', 'mariage', 'vacances', 'bration', 'randonn', 'destre', 'camping', 'lieux', 'tels', 'clairage', 'coration', 'tons', 'glo', 'appartient', 'taille', 'pcs', 'tons', 'lumineux', 'haut', 'gamme', 'bracelets', 'neon', 'light', 'party', 'favors', 'glowing', 'rallye', 'raves']",
#  "['jeu', 'pc', 'cd', 'rom', 'azteca'] []",
#  "['one', 'piece', 'log', 'impel', 'partie'] []",
#  "['mot', 'plus', 'long'] []",
#  "['testeur', 'lectronique', 'ph'] ['utilisation', 'testeur', 'lectronique', 'phgr', 'testeur', 'lectronique', 'ph', 'lecture', 'instantan', 'valeur', 'affiche', 'sans', 'besoin', 'interpr', 'ter', 'plus', 'testeur', 'sensibilise', 'importance', 'ph', 'bon', 'quilibre', 'eau', 'caract', 'techniques', 'testeur', 'lectronique', 'ph', 'affichage', 'num', 'alimentation', 'piles', 'garantie', 'solution', 'tampon', 'fournie', 'afin', 'pouvoir', 'recalibrer', 'appareil', 'apr', 'dizaine', 'utilisation', 'garantissant', 'sultat', 'fiable']",
#  "['fate', 'zero', 'lot', 'mangas', 'tome'] []",
#  "['moakoada', 'abs', 'cong', 'lateur', 'teether', 'sensorielle', 'jouet', 'mois'] ['abs', 'cong', 'lateur', 'teether', 'sensorielle', 'jouet', 'mois', 'sentation', 'produit', 'soulagez', 'teething', 'malaise', 'douleur', 'rehausseurs', 'maman', 'papa', 'lifesavers', 'pendant', 'tape', 'dentition', 'fonctionnent', 'comme', 'sucettes', 'encore', 'mieux', 'courbes', 'textures', 'massent', 'gencives', 'enfants', 'stimuler', 'croissance', 'leurs', 'dents', 'aider', 'encourager', 'veloppement', 'cerveau', 'apprentissage', 'tactile', 'chaque', 'teether', 'conception', 'color', 'amusement', 'texture', 'fait', 'vraiment', 'bon', 'jouets', 'sensorielles', 'mis', 'part', 'amusants', 'jouer', 'offrent', 'galement', 'apprentissage', 'visuel', 'tactile', 'sans', 'danger', 'jouet', 'sucette', 'conception', 'solide', 'petites', 'pi', 'mordre', 'certainement', 'fonction', 'esprit', 'jouet', 'dentition', 'adapte', 'parfaitement', 'bouche', 'juste', 'bonne', 'taille', 'poser', 'risque', 'touffement', 'poign', 'us', 'sorte', 'peuvent', 'facilement', 'saisis', 'petites', 'mains', 'conception', 'fonctionnelle', 'rend', 'galement', 'chaque', 'teether', 'facile', 'nettoyer', 'ranger', 'abs', 'riau', 'toxique', 'adopt', 'bouillie', 'emballage', 'rature', 'ensemble', 'pi', 'conseils', 'teether', 'cuites', 'rature', 'pendant', 'moins', 'demi', 'minute', 'utiliser', 'eau', 'froide', 'refroidir', 'imm', 'diatement', 'apr', 'sinfection', 'sinon', 'provoque', 'formation', 'produit', 'sinon', 'causera', 'formation', 'produit', 'sinon', 'causera', 'formation', 'produit']",
#  "['regardez', 'voleur', 'passe'] ['depuis', 'quatre', 'mensuel', 'marie', 'claire', 'organise', 'concours', 'aupr', 'lectrices', 'lecteurs', 'permettant', 'attribuer', 'prix', 'marie', 'claire', 'futur', 'crivain', 'cette', 'ann', 'premi', 'fois', 'auteurs', 'premiers', 'romans', 'taient', 'seuls', 'participer', 'th', 'impos', 'changer', 'manuscrits', 'disput', 'faveurs', 'jury', 'compos', 'journalistes', 'diteurs', 'enseignants', 'criture', 'unanimit', 'prix', 'cern', 'isabelle', 'kauffmann', 'roman', 'aussi', 'insolite', 'captivant', 'regardez', 'voleur', 'passe', 'entra', 'lecteur', 'traces', 'nigmatique', 'lose', 'personnage', 'inqui', 'tant', 'capable', 'voler', 'fragments', 'vie', 'ceux', 'dont', 'croise', 'regard', 'haletante', 'jusqu', 'bout', 'trange']",
#  "['lot', 'livres', 'grans', 'peintres'] []",
#  "['pompe', 'filtration', 'speck', 'badu'] []",
#  "['moakoada', 'body', 'wrap', 'peau', 'autocollant', 'decal', 'dji', 'phantom', 'pro', 'pro', 'drone', 'controller'] ['body', 'wrap', 'peau', 'autocollant', 'decal', 'dji', 'phantom', 'pro', 'drone', 'contr', 'dji', 'phantom', 'pro', 'drone', 'contr', 'compatible', 'contr', 'auto', 'moniteur', 'tanche', 'ajustement', 'parfait', 'calcomanies', 'prot', 'gez', 'drone', 'gratignures', 'sale', 'flexibilit', 'surface', 'courbe', 'tirable', 'eau', 'sistance', 'rayures', 'anti', 'uv', 'aucune', 'trace', 'peler', 'laissant', 'sans', 'calage', 'nettoyage', 'entretien', 'facile', 'fournit', 'meilleure', 'protection', 'drone', 'contr', 'caract', 'mati', 'pvc', 'chlorure', 'vinyle', 'couleur', 'bleu', 'jaune', 'orange', 'rouge', 'vert', 'noir', 'compatible', 'phantom', 'dji', 'pro', 'quantit', 'set', 'remarque', 'nettoyer', 'endroit', 'cessit', 'coller', 'rature', 'inf', 'rieure', 'colle', 'plus', 'forte', 'enought', 'calorifiques', 'ventilateur', 'devenir', 'plus', 'fort', 'emball', 'inclus']",
#  "['pcs', 'mobilier', 'poup', 'pot', 'fleur', 'plastique', 'jardin', 'accessoires', 'maison', 'poup', 'jouet', 'cadeau', 'enfant', 'fille', 'magideal'] ['description', 'belle', 'conception', 'excellente', 'finition', 'pi', 'pot', 'pot', 'pot', 'fit', 'accessoires', 'coration', 'jardin', 'dollhouse', 'chelle', 'collection', 'exquise', 'poup', 'superbe', 'ajout', 'toute', 'maison', 'traditionnelle', 'poup', 'plastique', 'couleur', 'comme', 'illustr', 'note', 'risque', 'touffement', 'petites', 'pi', 'enfants', 'moins', 'tableau', 'tailles', 'round', 'pot', 'hauteur', 'environ', 'pouces', 'diam', 'environ', 'pouce', 'pot', 'carr', 'w', 'environ', 'pouces', 'w', 'environ', 'pouces', 'plus', 'lev', 'forfait', 'pot', 'fleur', 'miniature', 'pi', 'dollhouse', 'remarque', 'raison', 'mesure', 'manuelle', 'veuillez', 'voir', 'rences', 'taille', 'mm']",
#  "['lot', 'pf', 'marque', 'pages', 'illustrations', 'vintage', 'enfants', 'amoureux'] []",
#  "['largo', 'poussette', 'combin', 'parasol', 'auto', 'poussette', 'canne', 'accessoires', 'cosmique', 'noir', 'cr'] ['largo', 'poussette', 'combin', 'combin', 'set', 'complet', 'parasol', 'auto', 'inclus', 'adaptateurs', 'habillage', 'pluie', 'moustiquaire', 'roues', 'pivotantes', 'air', 'ect', 'equipement', 'poussette', 'kg', 'conforme', 'normes', 'europ', 'ennes', 'curit', 'ch', 'ssis', 'solide', 'guidon', 'glable', 'hauteur', 'frein', 'curit', 'facile', 'replier', 'encombrant', 'grand', 'panier', 'capacit', 'charge', 'lev', 'kg', 'roues', 'roues', 'air', 'pneumatique', 'roues', 'pivotantes', 'bloque', 'aussi', 'roues', 'pivotantes', 'roulements', 'billes', 'roues', 'avant', 'pouces', 'environ', 'roues', 'arri', 'pouces', 'environ', 'nacelle', 'couvre', 'jambes', 'dossier', 'glable', 'nacelle', 'fait', 'rocking', 'chair', 'utilisable', 'naissance', 'position', 'allong', 'nacelle', 'clipser', 'face', 'parents', 'face', 'route', 'ch', 'ssis', 'nacelle', 'amovible', 'fond', 'rigide', 'rieure', 'lavable', 'capote', 'amovible', 'utiliser', 'comme', 'couffin', 'auto', 'groupe', 'kg', 'conforme', 'norme', 'europ', 'enne', 'curit', 'couvre', 'jambes', 'position', 'assise', 'poign', 'glable', 'positions', 'harnais', 'curit', 'points', 'glable', 'auto', 'cosy', 'fait', 'rocking', 'chair', 'tissus', 'amovible', 'lavable', 'main', 'utilisable', 'naissance', 'livr', 'ducteur', 'jusqu', 'kg', 'isofix', 'suppl', 'ment', 'possible', 'regardez', 'boutique', 'priceminister', 'auto', 'cosy', 'clipser', 'face', 'parents', 'face', 'route', 'ch', 'ssis', 'fixation', 'ceinture', 'hicule', 'offre', 'meilleure', 'stabilit', 'vite', 'placement', 'cas', 'choc', 'sport', 'poussette', 'canne', 'kg', 'conforme', 'normes', 'europ', 'ennes', 'curit', 'couvre', 'jambes', 'poign', 'curit', 'ceinture', 'curit', 'points', 'facile', 'replier', 'encombrant', 'poign', 'glage', 'rentes', 'positions', 'repose', 'jambes', 'glable', 'plusieurs', 'positions', 'dossier', 'glable', 'positions', 'position', 'couch', 'capote', 'large', 'prot', 'uv', 'intemp', 'ries', 'sport', 'clipser', 'face', 'parents', 'face', 'route', 'ch', 'ssis', 'accessoires', 'parasol', 'moustiquaire', 'sac', 'langer', 'habillage', 'pluie', 'adaptateurs', 'dimensions', 'poids', 'coton', 'polyester', 'groupe', 'cible', 'unisex', 'canisme', 'pliage', 'pliant', 'nacelle', 'dimensions', 'environ', 'hauteur', 'poussette', 'incl', 'hotte', 'capote', 'fractionn', 'environ', 'inclinables', 'positions', 'horizontal', 'taille', 'poussette', 'canne', 'environ', 'repose', 'pied', 'poussette', 'canne', 'environ', 'dossier', 'poussette', 'canne', 'environ', 'surface', 'couchage', 'position', 'horizontale', 'environ', 'position', 'horizontale', 'repose', 'pieds', 'sport', 'mis', 'position', 'horizontale', 'poussette', 'roues', 'environ', 'ch', 'ssis', 'roues', 'environ', 'repli', 'ch', 'ssis', 'sans', 'roues', 'environ', 'repli', 'poids', 'poussette', 'canne', 'environ', 'kg', 'poids', 'poussette', 'nacelle', 'environ', 'kg', 'roues', 'diam', 'avant', 'pouces', 'arri', 'pouces', 'roues', 'pneumatique', 'guidon', 'glable', 'hauteur', 'nombre', 'roues', 'roues', 'nombre', 'places', 'unit']",
#  "['axis', 'wifi', 'fpv', 'drone', 'mp', 'cam', 'terre', 'air', 'saut', 'mode', 'assemblez', 'deformation', 'uapa'] []",
#  "['astralcom', 'cv', 'mono', 'dab', 'surpresseur', 'piscine'] ['tension', 'monophas', 'puissance', 'cv', 'turbine', 'nombre', 'compatible', 'traitement', 'sel', 'oui']",
#  "['lot', 'filtres', 'jetables', 'panier', 'skimmer', 'marina'] ['lots', 'filtres', 'jetables', 'marque', 'marina', 'universels', 'compatibles', 'touts', 'paniers', 'skimmer', 'mesurant', 'jusqu', 'diam']",
#  "['magnet', 'europe', 'paris'] []",
#  "['happy', 'halloween', 'sorci', 'accueil', 'stickers', 'muraux', 'amovibles', 'art', 'sticker', 'mural', 'shen'] ['happy', 'halloween', 'sorci', 'accueil', 'amovible', 'wallstickers', 'art', 'feature', 'neuf', 'quantit', 'pc', 'protection', 'toxique', 'environnement', 'eau', 'grand', 'coration', 'halloween', 'taille', 'comme', 'image', 'mati', 'pvc', 'appliqu', 'toute', 'surface', 'lisse', 'telle', 'mur', 'porte', 'verre', 'vitre', 'carreaux', 'ramique', 'cuisine', 'salle', 'bains', 'lectrom', 'nager', 'air', 'conditionn', 'corps', 'voiture', 'comment', 'utiliser', 'choisissez', 'surface', 'lisse', 'propre', 'sec', 'peler', 'autocollants', 'feuille', 'position', 'adh', 'sif', 'surface', 'plane', 'sans', 'presser', 'sorte', 'laisse', 'possibilit', 'retirer', 'nouveau', 'repositionner', 'sultat', 'satisfaisant', 'tenez', 'fermement', 'surface', 'appuyant', 'bulles', 'air', 'vers', 'bulles', 'prenez', 'aiguille', 'ennuyer', 'nettoyer', 'surface', 'lisse', 'avant', 'coller', 'emballage', 'xhalloween', 'wall', 'sticker']",
#  "['france', 'illustree', 'doux', 'far', 'niente'] ['journal', 'litt', 'raire', 'scientifique', 'religieux', 'journal', 'hebdomadaire', 'sommaire', 'texte', 'chronique', 'venet', 'revue', 'semaine', 'argenteuil', 'union', 'gu', 'soci', 'savantes', 'sorbonne', 'visite', 'artistique', 'soci', 'fran', 'aise', 'arch', 'ologie', 'alexandre', 'salies', 'assise', 'souvenir', 'lerinage', 'italie', 'kall', 'ye', 'beaux', 'arts', 'bas', 'reliefs', 'monument', 'lev', 'mars', 'tour', 'moire', 'soldats', 'fran', 'ais', 'morts', 'champ', 'bataille', 'argus', 'lassements', 'hebdomadaires', 'edme', 'simonot', 'bibliographie', 'fran', 'ois', 'bouveau', 'gravures', 'echecs', 'emile', 'pradignat', 'suppl', 'ment', 'avis', 'importants', 'courrier', 'roussel', 'gravures', 'doux', 'far', 'nitnte', 'argenteuil', 'dessin', 'coulanges', 'charge', 'infanterie', 'charge', 'cavalerie', 'bas', 'reliefs', 'monument', 'mars', 'tour', 'dessin', 'mathieu', 'eglise', 'assise', 'croquis', 'cham', 'bus']",
#  "['encyclop', 'die', 'universalis', 'vol'] []",
#  "['piscine', 'gonflable', 'pulv', 'risation', 'forme', 'tortue'] ['cette', 'merveilleuse', 'piscine', 'pulv', 'risation', 'offrira', 'ann', 'divertissement', 'amis', 'familles', 'arri', 'cour', 'faite', 'paroi', 'pvc', 'lamin', 'couches', 'cette', 'piscine', 'gonflable', 'capacit', 'jusqu', 'piscine', 'install', 'mani', 'rapide', 'facile', 'suffit', 'poser', 'pataugeoire', 'surface', 'plane', 'gonfler', 'remplir', 'piscine', 'eau', 'cette', 'piscine', 'raccordement', 'pompe', 'filtre', 'incluse', 'outre', 'facile', 'replier', 'stockage', 'transport', 'lorsqu', 'utilis', 'convient', 'enfants', 'partir', 'couleur', 'vert', 'jaune', 'riau', 'pvc', 'dimensions', 'totales', 'diam', 'diam', 'raccordement', 'mm', 'capacit', 'paroi', 'lamin', 'couches', 'partition', 'paisse', 'fonction', 'pulv', 'risation', 'connect', 'tuyau', 'arrosage', 'installation', 'facile', 'rapide', 'convient', 'enfants', 'partir']",
#  "['xbox', 'one', 'giga', 'avc', 'jeux', 'manette'] []",
#  "['lampe', 'star', 'wars', 'lampe', 'neon', 'sabre', 'laser'] ['lampe', 'taille', 'env', 'base', 'alimentation']",
#  "['pot', 'marina', 'eda', 'diam', 'rubis'] ['pot', 'marina', 'eda', 'diam', 'rubis', 'marque', 'eda', 'rence', 'fournisseur', 'ru', 'np', 'sx', 'gamme', 'marina', 'type', 'produit', 'pot', 'fleur', 'mati', 'plastique', 'couleur', 'rubis', 'hauteur', 'diam', 'contenance', 'pays', 'origine', 'france']",
#  "['lot', 'livres', 'partitions', 'hector', 'apprenti', 'musicien', 'vol', 'debeda', 'martin', 'van', 'velde'] []",
#  "['ponse'] []",
#  "['ml', 'halloween', 'head', 'ghost', 'lange', 'nuage', 'slime', 'putty', 'parfum', 'stress', 'enfants', 'clay', 'toy'] ['ml', 'halloween', 'head', 'ghost', 'lange', 'nuage', 'slime', 'putty', 'parfum', 'stress', 'enfants', 'clay', 'toy', 'caract', 'fabriqu', 'mati', 'res', 'premi', 'res', 'respectueuses', 'environnement', 'toxiques', 'assur', 'jouer', 'eat', 'safe', 'enfants', 'utiliser', 'toxiques', 'enfants', 'jouer', 'mang', 'trop', 'petits', 'enfants', 'parfait', 'soulager', 'stress', 'comme', 'presser', 'plier', 'rouler', 'tirez', 'boue', 'hes', 'plaisir', 'satisfaction', 'bruits', 'grand', 'cadeau', 'choix', 'cadeau', 'enfants', 'jouet', 'boue', 'merveilleux', 'gar', 'ons', 'filles', 'grand', 'soulagement', 'stress', 'adultes', 'enfants', 'aucun', 'post', 'moins', 'collant', 'autres', 'fluffy', 'slime', 'essayez', 'donc', 'barrasser', 'adh', 'sivit', 'grande', 'coh', 'rence', 'texture', 'tonnante', 'friables', 'sec', 'comme', 'autres', 'argiles', 'dohs', 'slime', 'termin', 'suffit', 'prendre', 'pot', 'trouver', 'fa', 'jouer', 'cette', 'boue', 'pelucheux', 'aussi', 'arts', 'artisanat', 'projets', 'scolaires', 'jouant', 'visuel', 'enfants', 'peuvent', 'exercer', 'ls', 'mains', 'liorer', 'motricit', 'velopper', 'oeil', 'main', 'nouveaux', 'ments', 'ajout', 'halloween', 'faire', 'jouer', 'bonh', 'enfants', 'capacit', 'produit', 'ml', 'paquet', 'jouet', 'pc', 'slime']",
#  "['boite', 'savons', 'metal', 'collection', 'moulin', 'rouge', 'cabaret', 'goulue', 'paris'] []",
#  "['crochets', 'plafond', 'crochets', 'coupe', 'vis', 'crochets', 'suspendus', 'plantes', 'tasses', 'ustensiles', 'cuisine', 'pc', 'fournitures', 'cuisine'] ['plafond', 'crochets', 'coupe', 'vis', 'crochets', 'plantes', 'suspendues', 'tasses', 'ustensiles', 'cuisine', 'wind', 'chimes', 'caract', 'installation', 'facile', 'faire', 'pouces', 'trou', 'profond', 'utilisant', 'pouces', 'foret', 'bois', 'tendres', 'peu', 'pouces', 'bois', 'durs', 'longueur', 'vis', 'pouce', 'taraudeuse', 'facilement', 'obtenir', 'bois', 'assez', 'durable', 'accrochez', 'carillons', 'lanternes', 'mangeoires', 'oiseaux', 'res', 'patio', 'res', 'autres', 'accoutrements', 'ornements', 'vacances', 'utilisez', 'point', 'ancrage', 'cas', 'forage', 'plaques', 'pl', 'plafond', 'sans', 'goujon', 'longueur', 'crochet', 'pouces', 'longueur', 'vis', 'pouce', 'poids', 'palier', 'maximum', 'kg', 'crochets', 'plafond', 'mur', 'durable', 'suspendez', 'plantes', 'pot', 'jardini', 'res', 'lampes', 'lanternes', 'rideaux', 'talliques', 'carillons', 'oliens', 'baldaquins', 'mobiles', 'essuie', 'mains', 'boules', 'fleurs', 'divers', 'objets', 'coratifs', 'grand', 'cuisine', 'accrocher', 'tasses', 'planches', 'boutures', 'ustensiles', 'tidy', 'garde', 'robe', 'sacs', 'main', 'ceintures', 'suspendus', 'foulards', 'forfait', 'crochet', 'plafond', 'xwhite']",
#  "['squishies', 'adorable', 'pingouin', 'squeeze', 'rising', 'slow', 'cr', 'parfum', 'stress', 'relief', 'jouets'] ['squishies', 'adorable', 'pingouin', 'lente', 'hausse', 'squeeze', 'cr', 'parfum', 'stress', 'relief', 'jouets', 'description', 'elastic', 'environnement', 'pu', 'taille', 'environ', 'inches', 'style', 'sangles', 'toycollectionscellphone', 'patron', 'adorable', 'quantit', 'penguin', 'pc', 'applicable', 'plus', 'squishy', 'super', 'lente', 'mont', 'quand', 'regardez', 'mignons', 'pouvez', 'sentir', 'mieux', 'tous', 'mauvais', 'sentiments', 'gone', 'rem', 'contre', 'stress', 'charme', 'ponge', 'vraiment', 'tactile', 'confortable', 'regard', 'aliste', 'odorante', 'super', 'mignons', 'kawaii', 'charme', 'doux', 'phones', 'mobiles', 'sacs', 'cl', 'cadeaux', 'collecte', 'plus', 'encore', 'aussi', 'comme', 'jouets', 'soulagement', 'stress', 'donner', 'libre', 'cours', 'motions', 'mesure', 'garder', 'mains', 'squishies', 'montantes', 'stupides', 'super', 'doux', 'lent']",
# ...
#  "['paires', 'montage', 'rapide', 'lices', 'tractables', 'vis', 'lames', 'rechange', 'partie', 'cg', 'drone', 'doauhao'] ['pairs', 'montage', 'rapide', 'lices', 'tractables', 'vis', 'lames', 'pi', 'rechange', 'cg', 'cg', 'drone', 'description', 'rapide', 'lib', 'ration', 'lices', 'poids', 'pliable', 'robuste', 'bonne', 'endurance', 'rigidit', 'parfait', 'cg', 'cg', 'drone', 'caract', 'lices', 'cg', 'cg', 'drone', 'pliable', 'forte', 'tension', 'plus', 'lev', 'facile', 'installer', 'lisseur', 'actif', 'plus', 'silencieux', 'forfait', 'vol', 'montage', 'rapide', 'accessoires', 'pliage']",
#  "['belle', 'poup', 'animaux', 'doux', 'risson', 'peluche', 'toy', 'home', 'wedding', 'party', 'kid', 'cadeau', 'sweetheart'] ['beau', 'doux', 'risson', 'poup', 'animaux', 'peluche', 'toy', 'home', 'wedding', 'party', 'kid', 'gift', 'grayproduct', 'description', 'court', 'peluche', 'pp', 'cottonsize', 'cmcolor', 'graybrand', 'hautes', 'nouvelles', 'quality', 'suitable', 'occasion', 'accueil', 'parti', 'weddinggiftmade', 'tissu', 'peluche', 'douce', 'curit', 'respectueuse', 'environnement', 'coton', 'pp', 'fillercan', 'servi', 'oreiller', 'liner', 'jouet', 'jouer', 'choices', 'regards', 'visage', 'couleurs', 'jouet', 'cadeau', 'fur', 'great', 'coration', 'home', 'perfectly', 'adapt', 'enfants', 'choisir', 'apporter', 'avion', 'voiture', 'sac', 'simple', 'jouer', 'poup', 'home', 'meilleur', 'partenaire', 'enfants', 'seulement', 'jouet', 'enfants', 'aussi', 'grande', 'coration', 'capacit', 'anti', 'statique', 'lovelystrong', 'facile', 'nettoyer', 'odorenvironmental', 'amical', 'besoin', 'inqui', 'ter', 'plus', 'convivial', 'skin', 'note']",
#  "['bernadette', 'illustre', 'catholique', 'fillettes', 'cheval', 'petite', 'fille', 'blonde', 'deux', 'champions'] []",
#  "['pack', 'electrolyseur', 'hayward', 'salt', 'swim', 'ld', 'gulation', 'ph', 'ez'] ['principaux', 'atouts', 'pack', 'electrolyseur', 'hayward', 'salt', 'swim', 'ld', 'piscine', 'jusqu', 'gulation', 'ph', 'ez', 'version', 'nouvelle', 'cellule', 'longue', 'dur', 'environ', 'heures', 'syst', 'complet', 'electrolyseur', 'hayward', 'salt', 'swim', 'gulation', 'ph', 'ez', 'contr', 'dosage', 'automatique', 'ph', 'cellule', 'installation', 'simplifi', 'sonde', 'rature', 'tecteur', 'bit', 'livr', 'gabarit', 'coupe', 'cl', 'sangle', 'serrage', 'tanch', 'unions', 'appareil', 'calibre', 'filtration', 'arr', 'panneau', 'contr', 'intuitif', 'diagnostic', 'voyant', 'led', 'gration', 'local', 'technique', 'existant', 'encombrement', 'duit', 'pack', 'hayward', 'salt', 'swim', 'ld', 'ph', 'ez', 'permettra', 'automatiser', 'totalement', 'gestion', 'traitement', 'eau', 'bassin', 'profiterez', 'encore', 'plus', 'bassin', 'solution', 'ale', 'piscine', 'retrouvez', 'ments', 'taill', 'annonces', 'hayward', 'salt', 'swim', 'ld', 'piscine', 'jusqu', 'ph', 'ez']",
#  "['batman', 'dc', 'comics', 'septembre', 'zero', 'hour'] []",
#  "['germi', 'uv', 'germi', 'sinfection', 'uv'] ['germi', 'uv', 'germi', 'sinfection', 'uv']",
#  "['independence', 'day', 'juillet', 'vinyle', 'diy', 'autocollant', 'mural', 'stickers', 'home', 'chambre'] ['juillet', 'independence', 'day', 'vinyle', 'diy', 'wall', 'sticker', 'stickers', 'coration', 'rieure', 'chambre', 'caract', 'fait', 'riaux', 'pvc', 'protection', 'toxiques', 'environnement', 'tanche', 'amovibles', 'utilisables', 'facile', 'appliquer', 'enlever', 'coration', 'gante', 'maison', 'pouvez', 'utiliser', 'corer', 'salon', 'chambre', 'ainsi', 'onsuitable', 'toute', 'surface', 'plane', 'lisse', 'comme', 'fen', 'mur', 'ramique', 'etc', 'mati', 'pvc', 'couleur', 'multicolore', 'taille', 'coffret', 'mur', 'remarques', 'autocollant', 'raison', 'rence', 'glage', 'cran', 'couleur', 'ment', 'images', 'permettre', 'rence', 'dimension', 'raison', 'rentes', 'mesures', 'manuelles']",
#  "['lampe', 'solaire', 'planter', 'metal', 'noir'] ['lampe', 'solaireen', 'tal', 'peint', 'noirhauteur', 'cmabat', 'jour', 'forme', 'fleurint', 'dor', 'ampoule', 'led', 'fournie', 'clairage', 'rouge', 'pi', 'tement', 'fourche', 'planter', 'montable', 'trois', 'parties', 'neufjamais', 'servieemballage', 'carton']",
#  "['haie', 'tale', 'artificielle', 'lux', 'brins', 'vert', 'thuya', 'multicolore'] ['haie', 'tale', 'artificielle', 'lux', 'brins', 'occultation', 'produit', 'haut', 'gamme', 'grande', 'haie', 'artificielle', 'lux', 'brins', 'sistante', 'esth', 'tique', 'solution', 'nager', 'facilement', 'jardin', 'confectionn', 'maillage', 'serr', 'offre', 'occultation', 'ale', 'camoufler', 'regards', 'indiscrets', 'cessite', 'entretien', 'particulier', 'compos', 'feuillage', 'pvc', 'deux', 'tons', 'vert', 'cette', 'haie', 'artificielle', 'souple', 'agr', 'toucher', 'lange', 'vert', 'fonc', 'vert', 'moyen', 'offre', 'fini', 'naturel', 'reproduire', 'couleur', 'thuya', 'trait', 'anti', 'feu', 'anti', 'uv', 'changera', 'couleur', 'fil', 'ann', 'simple', 'poser', 'recoup', 'sans', 'structurer', 'adapter', 'parfaitement', 'support', 'haie', 'artificielle', 'lux', 'tres', 'hauteur', 'fabriqu', 'partir', 'haies', 'tres', 'maillage', 'carr', 'aussi', 'dense', 'haie', 'artificielle', 'lux', 'brins', 'caract', 'mati', 'pvc', 'grade', 'vierge', 'recycl', 'format', 'rouleau', 'tres', 'couleurs', 'tons', 'vert', 'moyen', 'fonc', 'usage', 'occultation', 'feuillage', 'vert', 'thuya', 'trait', 'anti', 'feu', 'anti', 'uv', 'nombre', 'brins', 'brins', 'densit', 'brins', 'carr', 'maillage', 'serr', 'crois', 'quadrillage', 'environ', 'attache', 'fil', 'fer', 'galvanis', 'diam', 'attache', 'mm', 'conditionnement', 'bo', 'carton', 'recyclable', 'chaque', 'rouleau', 'tres', 'fourni', 'notice', 'installation', 'attaches', 'exp', 'dition', 'france', 'uniquement', 'exp', 'ditions', 'europe', 'hors', 'france', 'tropolitaine', 'consulter', 'frais', 'port']",
#  "['xcsource', 'large', 'dog', 'playing', 'bed', 'soft', 'warm', 'pet', 'cat', 'rug', 'cozy', 'washable', 'pad', 'puppy', 'blanket', 'cushion', 'car', 'seat', 'furniture', 'ps'] ['features', 'lovely', 'pets', 'worry', 'car', 'seats', 'bed', 'furniture', 'get', 'damage', 'pet', 'bed', 'comes', 'exquisite', 'pattern', 'good', 'decor', 'home', 'boring', 'colors', 'soft', 'flat', 'pet', 'bed', 'dogs', 'cats', 'made', 'high', 'quality', 'fabric', 'padded', 'cotton', 'pet', 'bed', 'designed', 'vehicles', 'bed', 'furniture', 'take', 'lightweight', 'foldable', 'pet', 'bed', 'everywhere', 'pet', 'goes', 'bottom', 'fabric', 'waterproof', 'provides', 'furniture', 'extra', 'protection', 'washable', 'durable', 'long', 'term', 'use', 'specifications', 'material', 'cotton', 'color', 'black', 'white', 'size', 'w', 'package', 'includes', 'pet', 'bed']",
#  "['jeu', 'caf', 'international', 'allemand'] []",
#  "['autocollants', 'vinyle', 'ps'] ['propos', 'produit', 'autocollant', 'unique', 'illustration', 'imprim', 'num', 'riquement', 'vinyle', 'stratifi', 'finition', 'brillante', 'facilement', 'amovible', 'sans', 'laisser', 'sidu', 'collant', 'installation', 'facile', 'bonne', 'protection', 'ps', 'prot', 'gez', 'ps', 'salet', 'rayures', 'poussi', 'usage', 'quotidien', 'coupe', 'cision', 'acc', 'commutateurs', 'boutons', 'faders', 'boutons', 'propos', 'produit', 'autocollant', 'unique', 'illustration', 'imprim', 'num', 'riquement', 'vinyle', 'stratifi', 'finition', 'brillante', 'facilement', 'amovible', 'sans', 'laisser', 'sidu', 'collant', 'installation', 'facile', 'bonne', 'protection', 'ps', 'prot', 'gez', 'ps', 'salet', 'rayures', 'poussi', 'usage', 'quotidien', 'coupe', 'cision', 'acc', 'commutateurs', 'boutons', 'faders', 'boutons']",
#  "['cavalier', 'pcs', 'set', 'aluminium', 'arbres', 'laiton', 'tonneaux', 'acier', 'astuce', 'fl', 'chettes', 'professionnel', 'dur', 'aiguille', 'vols'] ['cavalier', 'pcs', 'set', 'aluminium', 'arbres', 'laiton', 'tonneaux', 'acier', 'astuce', 'fl', 'chettes', 'professionnel', 'dur', 'aiguille', 'vols', 'type', 'fl', 'chette', 'dard', 'droit', 'longueur', 'totale', 'fl', 'che', 'longueur', 'pointe', 'comprise', 'mm', 'dart', 'diam', 'mm', 'laiton', 'acier', 'alliage', 'aluminium', 'pet', 'dart', 'baril', 'poids', 'dart', 'entier', 'poids', 'rielaluminium', 'aciertaille', 'mm', 'longueur', 'totale', 'poids']",
#  "['renolux', 'travel', 'systeme', 'equation', 'poussette', 'frabina'] []",
#  "['puisette', 'surface', 'cat', 'gorie', 'nettoyage', 'manuel'] ['type', 'puisette', 'fixation', 'clipser', 'riau', 'plastique']",
#  "['ques', 'canap', 'lit', 'accueil', 'coration', 'coussin', 'festival', 'taie', 'oreiller', 'couverture', 'taie', 'oreiller'] ['ques', 'canap', 'lit', 'coration', 'pillow', 'festival', 'coussin', 'case', 'cover', 'point', 'vente', 'produit', 'utilis', 'corer', 'salon', 'faire', 'para', 'maison', 'chaleur', 'plus', 'confortable', 'coussin', 'coratif', 'couverture', 'utilis', 'pouces', 'oreiller', 'inserts', 'pls', 'noter', 'insertions', 'inclus', 'motif', 'peinture', 'seul', 'taies', 'oreiller', 'facile', 'faire', 'correspondre', 'canap', 'canap', 'autre', 'pillows', 'soft', 'durable', 'deux', 'salon', 'bureau', 'chambre', 'etc', 'terrasse', 'voiture', 'etc', 'fermeture', 'glissi', 'cach', 'draps', 'coton', 'coussin', 'coffre', 'fort', 'machine', 'wash', 'lavage', 'sec', 'hand', 'dot', 'bleach', 'tumble', 'low', 'fer', 'fait', 'draps', 'coton', 'durable', 'cologique', 'materials', 'keep', 'place', 'propre', 'throw', 'pillow', 'contre', 'z', 'ro', 'traces', 'doigts', 'description', 'coton', 'lin', 'approx', 'taille', 'avoir', 'cart', 'raison', 'produit', 'date', 'remarque', 'permettre', 'erreur', 'mineure', 'raison', 'mesure', 'manuelle', 'raison', 'rence', 'entre', 'moniteurs', 'image', 'refl', 'ter', 'couleur', 'article', 'paquet', 'contient', 'taie', 'oreiller', 'coussin', 'inclus']",
#  "['coffret', 'gestion', 'lame', 'eau', 'telecommande'] ['bo', 'tier', 'contr', 'chute', 'eau', 'leds', 'bande', 'leds', 'unit', 'lieu', 'utiliser', 'fibre', 'optique', 'ant', 'plus', 'possible', 'cascade', 'design', 'cr', 'merveilleuse', 'illumination', 'eau', 'tombant', 'piscine', 'lections', 'possibles', 'effets', 'clairage', 'led', 'programm', 'permettent', 'obtenir', 'meilleurs', 'accessoires', 'eau', 'lumineuses']",
#  "['aquachek', 'bleu', 'bandelettes'] ['bandelettes', 'aquachek', 'bleu', 'permettent', 'analyser', 'simplement', 'efficacement', 'eau', 'piscine', 'plus', 'cis', 'ment', 'chlore', 'taux', 'alcalinit', 'aquachek', 'bleu', 'analyse', 'phmb', 'revacil', 'baquacil', 'newcil', 'aquaklar', 'etc', 'ph', 'tac']",
#  "['kit', 'piscine', 'acier', 'aspect', 'pierre', 'rcega', 'ovale', 'che', 'bulles', 'kit', 'entretien'] ['piscine', 'ovale', 'acier', 'aspect', 'pierre', 'rcega', 'marque', 'cette', 'gamme', 'piscines', 'ovales', 'aspect', 'pierre', 'avoir', 'grand', 'espace', 'nage', 'domicile', 'amuser', 'toute', 'famille', 'cet', 'acier', 'galvanis', 'gamme', 'piscines', 'acier', 'rcega', 'apportera', 'cachet', 'structure', 'aspect', 'pierre', 'dispose', 'quipement', 'complet', 'filtration', 'sable', 'kg', 'sable', 'inclus', 'chelle', 'curit', 'marche', 'amovible', 'skimmer', 'liner', 'pvc', 'bleu', 'paisseur', 'piscine', 'acier', 'rcega', 'disponible', 'tailles', 'rentes', 'kitprov', 'po', 'piscine', 'acier', 'rcega', 'dimensions', 'dimensions', 'espace', 'cessaire', 'volume', 'eau', 'kitprov', 'po', 'piscine', 'acier', 'rcega', 'dimensions', 'dimensions', 'espace', 'cessaire', 'volume', 'eau', 'kitprov', 'po', 'piscine', 'acier', 'rcega', 'dimensions', 'dimensions', 'espace', 'cessaire', 'volume', 'eau', 'gamme', 'piscine', 'hors', 'acier', 'rcega', 'ficie', 'grantie', 'fabricant', 'structure', 'filtration', 'sable', 'liner', 'ainsi', 'accessoires']",
#  "['mod', 'voiturealuminium', 'alloy', 'motor', 'mount', 'base', 'holder', 'traxxas', 'trx', 'rc', 'car', 'buggy', 'yzz'] ['moteur', 'base', 'alliage', 'aluminium', 'traxxas', 'titulaire', 'mont', 'trx', 'rc', 'auto', 'buggy', 'caract', 'ristique', 'moteur', 'base', 'pratique', 'intelligent', 'design', 'permet', 'jouir', 'plus', 'amusant', 'plaisir', 'offrant', 'structure', 'plus', 'solide', 'prolonger', 'moteur', 'esp', 'rance', 'vie', 'trx', 'traxxas', 'chenilles', 'appliquent', 'voiture', 'faite', 'alliage', 'aluminium', 'grande', 'facile', 'installer', 'voiture', 'fonctionnelle', 'exquise', 'facture', 'performant', 'liorer', 'transfert', 'puissance', 'moteur', 'duire', 'risque', 'surchauffe', 'adoption', 'moteur', 'signifie', 'structure', 'plus', 'solide', 'constitue', 'pratique', 'plus', 'parfaite', 'riau', 'alliage', 'aluminium', 'comme', 'montre', 'couleur', 'viation', 'raison', 'mesure', 'manuelle', 'rie', 'information', 'taille', 'emballage', 'poids', 'emballage', 'octies', 'colis', 'moteur', 'base', 'vis', 'devant', 'aluminium', 'alloy', 'motor', 'mount', 'base', 'holder', 'traxxas', 'trx', 'rc', 'car', 'buggy', 'feature', 'motor', 'base', 'high', 'quality', 'practical', 'seat', 'smart', 'design', 'enables', 'enjoy', 'fun', 'delight', 'providing', 'firmer', 'structure', 'lengthen', 'motor', 'life', 'expectancy', 'apply', 'traxxas', 'trx', 'crawler', 'car', 'made', 'aluminum', 'alloy', 'high', 'quality', 'easy', 'install', 'car', 'significantly', 'functional', 'lightweight', 'exquisite', 'workmanship', 'high', 'performance', 'improve', 'power', 'transfer', 'reduce', 'possibility', 'motor', 'overheating', 'adoption', 'motor', 'seat', 'means', 'firmer', 'structure', 'provides', 'perfect', 'practice', 'material', 'aluminum', 'alloy', 'color', 'shown', 'may', 'deviation', 'manual', 'measurement', 'package', 'information', 'package', 'size', 'package', 'weight', 'gpackage', 'list', 'motor', 'base', 'set', 'screws', 'set']",
#  "['porte', 'challenger', 'remote', 'control', 'rc', 'boat', 'warship', 'battleship', 'bk', 'fua'] ['commande', 'challenger', 'porte', 'rc', 'bateau', 'warship', 'battleship', 'feature', 'neuf', 'quantit', 'pcs', 'description', 'produit', 'fonction', 'conduction', 'eau', 'taille', 'produit', 'riau', 'produit', 'composants', 'lectroniques', 'tal', 'plastique', 'fr', 'quence', 'pile', 'fuselage', 'batteries', 'fer', 'lithium', 'pile', 'commande', 'chapitre', 'aa', 'configuration', 'tension', 'charge', 'distance', 'bateau', 'contr', 'manuel', 'instruction', 'commande']",
#  "['guitare', 'acier', 'inoxydable', 'cuiller', 'cuill', 'arc', 'th', 'outils', 'boire', 'flatware', 'kitchen', 'supplies'] ['guitare', 'acier', 'inoxydable', 'cuiller', 'arc', 'caf', 'cuill', 'th', 'flatware', 'boire', 'outils', 'description', 'guitare', 'acier', 'inoxydable', 'cuiller', 'arc', 'caf', 'cuill', 'th', 'outils', 'flatware', 'drinking', 'apparence', 'cr', 'ative', 'unique', 'mode', 'generous', 'easy', 'nettoyer', 'stockage', 'agr', 'usage', 'quotidien', 'comme', 'gift', 'using', 'lev', 'riau', 'pentatonique', 'formation', 'coloration', 'healthy', 'adopt', 'acier', 'inoxydable', 'durable', 'faible', 'teneur', 'carbone', 'co', 'friendly', 'material', 'acier', 'inoxydable', 'couleur', 'argent', 'multicolore', 'rose', 'bleu', 'noir', 'violet', 'longueur', 'poids', 'gpackage', 'inclus', 'cuill']",
#  "['red', 'steel', 'savage', 'baronies'] ['daring', 'swashbucklers', 'stout', 'mercenaries', 'rugged', 'gauchos', 'arrogant', 'nobles', 'vile', 'monsters', 'savage', 'baronies', 'home', 'accessory', 'red', 'steel', 'campaign', 'holds', 'page', 'sourcebook', 'covers', 'nine', 'savage', 'baronies', 'detail', 'including', 'rulers', 'lands', 'attitudes', 'people', 'effects', 'red', 'curse', 'people', 'also', 'included', 'page', 'adventure', 'set', 'savage', 'baronies', 'surrounding', 'lands', 'goblinoids', 'yazak', 'steppes', 'building', 'another', 'horde', 'invasion', 'imminent', 'player', 'characters', 'stop', 'included', 'adventure', 'handouts', 'pregenerated', 'characters', 'used', 'pcs', 'npcs', 'savage', 'baronies', 'also', 'contains', 'audio', 'cd', 'background', 'music', 'sound', 'effects', 'enhance', 'setting', 'mood', 'danger', 'adventure', 'cd', 'audio', 'adventure', 'gaming', 'aid', 'usable', 'ad', 'game', 'adventure', 'addition', 'full', 'color', 'poster', 'map', 'shows', 'overview', 'savage', 'coast']",
#  ...]

# %%
words = [item for sublist in headlines for item in sublist]
print("Number of unique tokens now: ",len(set(words)))
# Out:
# Number of unique tokens now:  31

# %%
# Text visualization using word clouds (word clouds )

# %%
# WORD CLOUD APRES AJOUT LISTE NETTOYAGE
word_cloud_text = ''.join(headlines)

wordcloud = WordCloud(max_font_size=100, # Maximum font size for the largest word
                      max_words=1000, # The maximum number of words
                      background_color="white", # Background color for the word cloud image
                      scale = 10, # Scaling between computation and drawing
                      width=800, # Width of the canvas
                      height=400 # Height of the canvas
                     ).generate(word_cloud_text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear") # to make the displayed image appear more smoothly
plt.axis("off")
plt.show()

# %%
from collections import Counter
import seaborn as sns 
chaine = ' '.join(i for i in headlines) ###################
dico = Counter(chaine.split())
mots = [m[0] for m in dico.most_common(30)]
freq = [m[1] for m in dico.most_common(30)]

plt.figure(figsize= (30,16))
sns.barplot(x=mots, y=freq)
plt.title('30 mots les plus fréquemment de X_train cleaned');

# %%
###################################################################

# %%
df['designation'] = df['designation'].apply(lambda _: str(_))

# %%
# En comparatif : 
from collections import Counter
import seaborn as sns 
chaine = ' '.join(i for i in df['designation'])
dico = Counter(chaine.split())
mots = [m[0] for m in dico.most_common(40)]
freq = [m[1] for m in dico.most_common(40)]

plt.figure(figsize= (30,12))
sns.barplot(x=mots, y=freq)
plt.title('20 mots les plus fréquemment de X_train cleaned');

# %%
token_lists = [word_tokenize(e) for e in df['designation'].astype(str)] #####
tokens = [item for sublist in token_lists for item in sublist]
print("Number of unique tokens now: ",len(set(tokens)))
# Out:
# Number of unique tokens now:  58256

# %%
df['target'] = target #on rajoute y_train dans X_train temporairement pour simplifier la tache

df.head(1)
# Out:
#                                                                                             designation  \
# 0  ['olivia', 'personalisiertes', 'notizbuch', 'seiten', 'punktraster', 'ca', 'din', 'rosen', 'design']
#
#   description   productid     imageid  target
# 0          []  3804725264  1263597046      10

# %%
newdf = pd.DataFrame({'Features': headlines})

# %%
newdf.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ['olivia', 'personalisiertes', 'notizbuch', 'seiten', 'punktraster', 'ca', 'din', 'rosen', 'design'] []
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ['journal', 'arts', 'art', 'marche', 'salon', 'art', 'asiatique', 'paris', 'jacques', 'barrere', 'francois', 'perrier', 'reforme', 'ventes', 'encheres', 'publiques', 'sna', 'fete', 'cent'] []
# 2  ['grand', 'stylet', 'ergonomique', 'bleu', 'gamepad', 'nintendo', 'wii', 'speedlink', 'pilot', 'style'] ['pilot', 'style', 'touch', 'pen', 'marque', 'speedlink', 'stylet', 'ergonomique', 'gamepad', 'nintendo', 'wii', 'confort', 'optimal', 'cision', 'maximale', 'gamepad', 'wii', 'grand', 'stylet', 'hautement', 'ergonomique', 'seulement', 'parfaitement', 'adapt', 'main', 'aussi', 'gant', 'livr', 'support', 'fixe', 'sans', 'adh', 'sif', 'arri', 'gamepad', 'caract', 'mod', 'speedlink', 'pilot', 'style', 'touch', 'pen', 'couleur', 'bleu', 'ref', 'fabricant', 'sl', 'compatibilit', 'gamepad', 'nintendo', 'wii', 'forme', 'particuli', 'ergonomique', 'excellente', 'tenue', 'main', 'pointe', 'rev', 'tement', 'longue', 'dur', 'ue', 'ab', 'mer', 'cran', 'tactile', 'bonus', 'support', 'inclu', 'gamepad', 'class', 'vga', 'style']
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ['peluche', 'donald', 'europe', 'disneyland', 'marionnette', 'doigt'] []
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ['guerre', 'tuques'] ['luc', 'grandeur', 'veut', 'organiser', 'jeu', 'guerre', 'boules', 'neige', 'arranger', 'ecirc', 'vainqueur', 'incontest', 'sophie', 'ecirc', 'chambarde', 'tous', 'plans']

# %%
from sklearn.model_selection import train_test_split

X= newdf['Features']
y= target['prdtypecode']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, test_size = 0.07, random_state = 0)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (16983,) (5945,)

# %%
print(y_train.shape, y_test.shape)
# Out:
# (16983,) (5945,)

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
# Mettre à jour la valeur de X_train et X_test
X_train = cv.fit_transform(X_train).todense()
X_test = cv.transform(X_test).todense()

# %% [markdown]
# # 1st loop Applying logistic regression

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(C=1.0).fit(X_train, y_train)

y_pred=clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-52-ee7dc5ffada5> in <module>
#       1 from sklearn.linear_model import LogisticRegression
# ----> 2 clf = LogisticRegression(C=1.0).fit(X_train, y_train)
#       3
#       4 y_pred=clf.predict(X_test)
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\envs\tf\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# MemoryError: Unable to allocate 6.69 GiB for an array with shape (16983, 52862) and data type float64

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))   # target_names=target_names
# Out:
#               precision    recall  f1-score   support
#
#           10       0.33      0.63      0.44       288
#           40       0.62      0.55      0.58       269
#           50       0.74      0.72      0.73       165
#           60       0.91      0.88      0.89        90
#         1140       0.78      0.74      0.76       268
#         1160       0.89      0.92      0.90       411
#         1180       0.74      0.46      0.57        80
#         1280       0.60      0.56      0.58       470
#         1281       0.59      0.48      0.53       190
#         1300       0.86      0.83      0.84       524
#         1301       1.00      0.83      0.91        87
#         1302       0.79      0.62      0.69       264
#         1320       0.71      0.70      0.70       306
#         1560       0.80      0.80      0.80       512
#         1920       0.87      0.88      0.88       419
#         1940       0.96      0.78      0.86        64
#         2060       0.76      0.72      0.74       493
#         2220       0.96      0.80      0.87        85
#         2280       0.58      0.72      0.64       502
#         2403       0.70      0.71      0.71       498
#         2462       0.72      0.68      0.70       162
#         2522       0.90      0.86      0.88       518
#         2582       0.74      0.67      0.70       248
#         2583       0.94      0.96      0.95       959
#         2585       0.79      0.70      0.74       282
#         2705       0.72      0.67      0.70       259
#         2905       0.99      0.92      0.95        79
#
#     accuracy                           0.76      8492
#    macro avg       0.78      0.73      0.75      8492
# weighted avg       0.77      0.76      0.76      8492

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

cnf_matrix = confusion_matrix(y_test,y_pred)

classes = range(0,28)# pour améliorer le graph

plt.figure(figsize=(20,20))

plt.imshow(cnf_matrix, interpolation='nearest',cmap='Blues')
plt.title("Matrice de confusion")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
    plt.text(j, i, cnf_matrix[i, j],
             horizontalalignment="center",
             color="white" if cnf_matrix[i, j] > ( cnf_matrix.max() / 2) else "black")

plt.tight_layout()
plt.ylabel('Classe réelle RAKUTENs')
plt.xlabel('Classe prédite RAKUTEN')
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf2 = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1,
    max_depth=3, random_state=0).fit(X_train, y_train)

# %%
y_pred2=clf2.predict(X_test)
